# %% [markdown]
# # **Handling Large Datasets with Pandas**
#
# Pandas makes it incredibly simple to read and write different file formats with its built-in functions. For example, reading a CSV file is as easy as using the pd.read_csv() function. It’s that straightforward!

# %% [markdown]
# # **csv file**
#
#
# A CSV (Comma-Separated Values) file is a simple text file used to store tabular data (rows and columns). Each row is on a new line, and values are separated by commas.
#
# Name,Age,Department
#
# Alice,30,Engineering
#
# Bob,25,Sales
#
# Charlie,35,Marketing

# %% [markdown]
# Download this sample dataset and keep it saved at an organised space in your google drive:
#
# Sample Dataset:
# [Link](https://drive.google.com/file/d/1hSW3BnrsIO_4KuB5Te6EEEI-ctWDEzTy/view?usp=sharing)

# %% [markdown]
# # Import basic libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # **Accessing Files:**

# %%
data = pd.read_csv('/kaggle/input/datasets/fizamal/imdb-dataset/imdb_data.csv')
data.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#   release_date runtime                                   spoken_languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1       8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4       2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
#
# [5 rows x 23 columns]

# %% [markdown]
# **pd.read_csv** method used to load csv file into google colab.

# %% [markdown]
# # **What is Data Wrangling??**
# Data wrangling, also known as data cleaning or data munging, is the process of transforming raw data into a clean and organized format, ready for analysis. This involves identifying and addressing issues within the dataset to make it suitable and reliable for further insights or machine learning models.
#
# **Key Steps in Data Wrangling**
#
# 	1. Data Cleaning: Removing or handling missing values, correcting inconsistencies, and dealing with outliers.
# 	2. Data Structuring: Converting data into a structured format, often by reshaping or reformatting columns and rows.
# 	3. Data Transformation: Changing data types, creating new calculated columns, or encoding categorical variables.
# 	4. Data Filtering and Selection: Selecting specific subsets of data based on conditions or criteria.
# 	5. Data Merging: Combining multiple datasets into a single, cohesive dataset.
#
# **Why Data Wrangling is Important**??
#
# 	• Ensures Data Quality: Improves the accuracy and reliability of data,  which leads to more accurate analysis and insights.
# 	• Prepares for Analysis: Makes data easier to explore, analyze, and visualize by organizing it in a consistent format.
# 	• Increases Efficiency: Reduces time and effort required for analysis by resolving issues in the data early on.
#
# Data wrangling is a critical step in the data science workflow, ensuring that data is clean, organized, and ready for meaningful analysis.

# %% [markdown]
# ## <b>Basic Inspection of a dataframe
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### <b>Shape</b>
# It is used to find number of rows and columns.

# %%
data.shape
# Out:
# (3000, 23)

# %% [markdown]
# **Data has 3000 rows and 23 columns**

# %% [markdown]
# ### <b>Head(n)</b>
# It is used to print first 5 rows by deafult or we can fetch n number of rows by giving different values for n.

# %%
data.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#   release_date runtime                                   spoken_languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1       8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4       2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
#
# [5 rows x 23 columns]

# %%
# fetch first 100 rows
data.head(100)
# Out:
#      id                              belongs_to_collection    budget  \
# 0     1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1     2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2     3                                                NaN   3300000
# 3     4                                                NaN   1200000
# 4     5                                                NaN         0
# ..  ...                                                ...       ...
# 95   96                                                NaN         0
# 96   97                                                NaN   2500000
# 97   98                                                NaN         0
# 98   99                                                NaN  10500000
# 99  100                                                NaN   6000000
#
#                                                genres  \
# 0                      [{'id': 35, 'name': 'Comedy'}]
# 1   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                       [{'id': 18, 'name': 'Drama'}]
# 3   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ..                                                ...
# 95                      [{'id': 18, 'name': 'Drama'}]
# 96  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 97  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 98  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 99  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
#
#                              homepage    imdb_id original_language  \
# 0                                 NaN  tt2637294                en
# 1                                 NaN  tt0368933                en
# 2   http://sonyclassics.com/whiplash/  tt2582802                en
# 3          http://kahaanithefilm.com/  tt1821480                hi
# 4                                 NaN  tt1380152                ko
# ..                                ...        ...               ...
# 95                                NaN  tt2569398                ru
# 96                                NaN  tt1683921                fr
# 97                                NaN  tt1772980                ru
# 98                                NaN  tt1764625                es
# 99                                NaN  tt0094894                en
#
#                               original_title  \
# 0                     Hot Tub Time Machine 2
# 1   The Princess Diaries 2: Royal Engagement
# 2                                   Whiplash
# 3                                    Kahaani
# 4                                       마린보이
# ..                                       ...
# 95                Со мною вот что происходит
# 96                              Nuit Blanche
# 97                                    Mishen
# 98              Las aventuras de Tadeo Jones
# 99                                    Colors
#
#                                              overview  popularity  ...  \
# 0   When Lou, who has become the "father of the In...    6.575393  ...
# 1   Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2   Under the direction of a ruthless instructor, ...   64.299990  ...
# 3   Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4   Marine Boy is the story of a former national s...    1.148070  ...
# ..                                                ...         ...  ...
# 95  December, 31st. Impossible Moscow traffic, an ...    0.181963  ...
# 96  Vincent is a crooked cop whose drug heist goes...    2.942355  ...
# 97  In the year 2020, a group of wealthy Moscovite...    1.042112  ...
# 98  Tad is a celebrity archeologist and adventurer...   11.003515  ...
# 99  A confident young cop is shown the ropes by a ...    5.529808  ...
#
#    release_date runtime                                   spoken_languages  \
# 0       2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1        8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2      10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3        3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4        2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# ..          ...     ...                                                ...
# 95      12/9/12    72.0           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 96     11/14/11    98.0          [{'iso_639_1': 'fr', 'name': 'Français'}]
# 97      6/26/11   158.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 98      8/31/12    90.0  [{'iso_639_1': 'es', 'name': 'Español'}, {'iso...
# 99      4/15/88   120.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#       status                                            tagline  \
# 0   Released  The Laws of Space and Time are About to be Vio...
# 1   Released  It can take a lifetime to find true love; she'...
# 2   Released    The road to greatness can take you to the edge.
# 3   Released                                                NaN
# 4   Released                                                NaN
# ..       ...                                                ...
# 95  Released                                                NaN
# 96  Released                                                NaN
# 97  Released                                                NaN
# 98  Released                         No whip, no gun...All fun!
# 99  Released   70,000 gang members. One million guns. Two cops.
#
#                                        title  \
# 0                     Hot Tub Time Machine 2
# 1   The Princess Diaries 2: Royal Engagement
# 2                                   Whiplash
# 3                                    Kahaani
# 4                                 Marine Boy
# ..                                       ...
# 95         And Here's What's Happening to Me
# 96                           Sleepless Night
# 97                                    Target
# 98                    Tad, the Lost Explorer
# 99                                    Colors
#
#                                              Keywords  \
# 0   [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1   [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2   [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3   [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                 NaN
# ..                                                ...
# 95                                                NaN
# 96                                                NaN
# 97                                                NaN
# 98  [{'id': 720, 'name': 'helicopter'}, {'id': 145...
# 99  [{'id': 796, 'name': 'police brutality'}, {'id...
#
#                                                  cast  \
# 0   [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1   [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2   [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3   [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4   [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# ..                                                ...
# 95  [{'cast_id': 4, 'character': 'Artyom', 'credit...
# 96  [{'cast_id': 1, 'character': 'Vincent', 'credi...
# 97  [{'cast_id': 1001, 'character': 'Victor', 'cre...
# 98  [{'cast_id': 2, 'character': 'Sara', 'credit_i...
# 99  [{'cast_id': 1, 'character': 'Officer Danny Mc...
#
#                                                  crew   revenue
# 0   [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1   [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2   [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3   [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4   [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
# ..                                                ...       ...
# 95  [{'credit_id': '52fe4b199251416c910cfbd9', 'de...     14353
# 96  [{'credit_id': '52fe49c0c3a368484e13dc9b', 'de...      3358
# 97  [{'credit_id': '58cdbad4c3a36850e9011085', 'de...     73000
# 98  [{'credit_id': '52fe4a6bc3a368484e15241f', 'de...  23000000
# 99  [{'credit_id': '52fe432f9251416c75006ac5', 'de...  46616067
#
# [100 rows x 23 columns]

# %% [markdown]
# ### <b>Tail(n)</b>
#
# Prints the last $n$ rows of the dataframe. By default it prints the last 5 rows

# %%
data.tail()
# Out:
#         id belongs_to_collection    budget  \
# 2995  2996                   NaN         0
# 2996  2997                   NaN         0
# 2997  2998                   NaN  65000000
# 2998  2999                   NaN  42000000
# 2999  3000                   NaN  35000000
#
#                                                  genres  \
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                               homepage    imdb_id original_language  \
# 2995                               NaN  tt0109403                en
# 2996                               NaN  tt2364975                sv
# 2997                               NaN  tt0116908                en
# 2998    http://www.alongcamepolly.com/  tt0343135                en
# 2999  http://www.abductionthefilm.com/  tt1600195                en
#
#                original_title  \
# 2995                  Chasers
# 2996              Vi är bäst!
# 2997  The Long Kiss Goodnight
# 2998         Along Came Polly
# 2999                Abduction
#
#                                                overview  popularity  ...  \
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#      release_date runtime                          spoken_languages    status  \
# 2995      4/22/94   102.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2996      3/28/13   102.0  [{'iso_639_1': 'sv', 'name': 'svenska'}]  Released
# 2997     10/11/96   120.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2998      1/16/04    90.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2999      9/22/11   106.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 2995  It was supposed to be a routine prisoner trans...
# 2996                                                NaN
# 2997               What's forgotten is not always gone.
# 2998  For the most cautious man on Earth, life is ab...
# 2999          They stole his life. He's taking it back.
#
#                         title  \
# 2995                  Chasers
# 2996         We Are the Best!
# 2997  The Long Kiss Goodnight
# 2998         Along Came Polly
# 2999                Abduction
#
#                                                Keywords  \
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
# [5 rows x 23 columns]

# %%
# fetch last 50 rows
data.tail(50)
# Out:
#         id                              belongs_to_collection    budget  \
# 2950  2951  [{'id': 9735, 'name': 'Friday the 13th Collect...  30000000
# 2951  2952                                                NaN  13000000
# 2952  2953                                                NaN  25000000
# 2953  2954                                                NaN   8500000
# 2954  2955                                                NaN  60000000
# 2955  2956                                                NaN  17000000
# 2956  2957                                                NaN         0
# 2957  2958                                                NaN  60000000
# 2958  2959                                                NaN  15000000
# 2959  2960                                                NaN   2300000
# 2960  2961                                                NaN   4600000
# 2961  2962  [{'id': 109592, 'name': "Porky's Collection", ...   4000000
# 2962  2963                                                NaN  20000000
# 2963  2964                                                NaN         0
# 2964  2965  [{'id': 173344, 'name': 'Qatsi Collection', 'p...   2500000
# 2965  2966                                                NaN  61000000
# 2966  2967                                                NaN  40000000
# 2967  2968  [{'id': 387219, 'name': 'The Hustler Collectio...   2000000
# 2968  2969  [{'id': 97307, 'name': 'BloodRayne Collection'...  25000000
# 2969  2970                                                NaN  19800000
# 2970  2971                                                NaN  25000000
# 2971  2972                                                NaN  20000000
# 2972  2973                                                NaN         0
# 2973  2974                                                NaN         0
# 2974  2975  [{'id': 149704, 'name': 'Alone in the Dark Col...  20000000
# 2975  2976                                                NaN  45000000
# 2976  2977                                                NaN  16000000
# 2977  2978                                                NaN  53000000
# 2978  2979                                                NaN         0
# 2979  2980                                                NaN  35000000
# 2980  2981                                                NaN    300000
# 2981  2982                                                NaN         0
# 2982  2983                                                NaN    500000
# 2983  2984                                                NaN  35000000
# 2984  2985  [{'id': 221111, 'name': 'S.W.A.T. Collection',...  80000000
# 2985  2986                                                NaN  37665000
# 2986  2987                                                NaN  20000000
# 2987  2988                                                NaN         0
# 2988  2989                                                NaN         0
# 2989  2990                                                NaN         0
# 2990  2991                                                NaN         0
# 2991  2992  [{'id': 107469, 'name': 'Save The Last Dance C...  13000000
# 2992  2993                                                NaN   1135654
# 2993  2994                                                NaN  60000000
# 2994  2995                                                NaN         0
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# 2950                     [{'id': 27, 'name': 'Horror'}]
# 2951  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 2952  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 2953  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 2954                     [{'id': 35, 'name': 'Comedy'}]
# 2955  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 2956  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2957  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2958  [{'id': 10402, 'name': 'Music'}, {'id': 99, 'n...
# 2959  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 2960  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 2961                     [{'id': 35, 'name': 'Comedy'}]
# 2962  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...
# 2963  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 2964  [{'id': 99, 'name': 'Documentary'}, {'id': 18,...
# 2965  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2966  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2967                      [{'id': 18, 'name': 'Drama'}]
# 2968  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2969  [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...
# 2970  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# 2971  [{'id': 14, 'name': 'Fantasy'}, {'id': 35, 'na...
# 2972  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 2973  [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
# 2974  [{'id': 28, 'name': 'Action'}, {'id': 14, 'nam...
# 2975  [{'id': 12, 'name': 'Adventure'}, {'id': 35, '...
# 2976  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 2977  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 2978  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2979  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2980  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2981                      [{'id': 18, 'name': 'Drama'}]
# 2982                      [{'id': 18, 'name': 'Drama'}]
# 2983  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 2984  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 2985  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 2986  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 2987  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 2988                      [{'id': 18, 'name': 'Drama'}]
# 2989  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 2990  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2991  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 2992  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2993  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2994                      [{'id': 18, 'name': 'Drama'}]
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                                homepage    imdb_id  \
# 2950                                                NaN  tt0329101
# 2951                                                NaN  tt2057392
# 2952                    http://theageofadalinemovie.com  tt1655441
# 2953                                                NaN  tt0202677
# 2954                                                NaN  tt0375173
# 2955                                                NaN  tt1210042
# 2956                                                NaN  tt0091055
# 2957                                                NaN  tt0113845
# 2958                          http://www.u23dmovie.com/  tt0892375
# 2959                                                NaN  tt1093370
# 2960                                                NaN  tt1514041
# 2961                                                NaN  tt0084522
# 2962                          http://www.theshack.movie  tt2872518
# 2963                        http://www.koizora-movie.jp  tt1194664
# 2964                                                NaN  tt0095895
# 2965                   http://www.lesmiserablesfilm.com  tt1707386
# 2966                                                NaN  tt0120177
# 2967                                                NaN  tt0054997
# 2968  http://www.bloodrayne-themovie.com/main/index....  tt0383222
# 2969                                                NaN  tt0280707
# 2970                                                NaN  tt0103855
# 2971                                                NaN  tt0100201
# 2972                                                NaN  tt0482930
# 2973                                                NaN  tt0089652
# 2974                                                NaN  tt0369226
# 2975              http://www.aliensintheatticmovie.com/  tt0775552
# 2976                                                NaN  tt0186045
# 2977  http://angeleyesmovie.warnerbros.com/index_nof...  tt0225071
# 2978                                                NaN  tt0120879
# 2979                     http://www.theback-upplan.com/  tt1212436
# 2980           https://www.facebook.com/Actionherobiju/  tt5320514
# 2981                                                NaN  tt4158876
# 2982                                                NaN  tt2063781
# 2983                                                NaN  tt0118623
# 2984        http://www.sonypictures.com/homevideo/swat/  tt0257076
# 2985  http://www.sonypictures.com/homevideo/freedoml...  tt0349467
# 2986                                                NaN  tt0338325
# 2987                                                NaN  tt0096246
# 2988                                                NaN  tt0301978
# 2989                                                NaN  tt0206367
# 2990                                                NaN  tt0118663
# 2991                                                NaN  tt0206275
# 2992                                                NaN  tt0015400
# 2993               http://www.theterminal-themovie.com/  tt0362227
# 2994                                                NaN  tt0105327
# 2995                                                NaN  tt0109403
# 2996                                                NaN  tt2364975
# 2997                                                NaN  tt0116908
# 2998                     http://www.alongcamepolly.com/  tt0343135
# 2999                   http://www.abductionthefilm.com/  tt1600195
#
#      original_language           original_title  \
# 2950                en         Freddy vs. Jason
# 2951                en           Eye in the Sky
# 2952                en       The Age of Adaline
# 2953                en       The Way of the Gun
# 2954                en                    Alfie
# 2955                en        Brooklyn's Finest
# 2956                en               Firewalker
# 2957                en              Money Train
# 2958                en                    U2 3D
# 2959                hi               Jab We Met
# 2960                en                  4.3.2.1
# 2961                en                  Porky's
# 2962                en                The Shack
# 2963                ja                       恋空
# 2964                en               Powaqqatsi
# 2965                en           Les Misérables
# 2966                en                    Spawn
# 2967                en              The Hustler
# 2968                en               BloodRayne
# 2969                en             Gosford Park
# 2970                en            The Bodyguard
# 2971                en              Mr. Destiny
# 2972                cn                      龍虎門
# 2973                en       My Science Project
# 2974                en        Alone in the Dark
# 2975                en      Aliens in the Attic
# 2976                en            Drowning Mona
# 2977                en               Angel Eyes
# 2978                en          Velvet Goldmine
# 2979                en         The Back-Up Plan
# 2980                ml          ആക്ഷൻ ഹീറോ ബിജു
# 2981                en             Other People
# 2982                en                  Smashed
# 2983                en            Anna Karenina
# 2984                en                 S.W.A.T.
# 2985                en              Freedomland
# 2986                en                Paparazzi
# 2987                en        The Terror Within
# 2988                fa                       ده
# 2989                en  The Trumpet Of The Swan
# 2990                en                 B.A.P.S.
# 2991                en      Save the Last Dance
# 2992                en      The Thief of Bagdad
# 2993                en             The Terminal
# 2994                en              School Ties
# 2995                en                  Chasers
# 2996                sv              Vi är bäst!
# 2997                en  The Long Kiss Goodnight
# 2998                en         Along Came Polly
# 2999                en                Abduction
#
#                                                overview  popularity  ...  \
# 2950  Evil dream-demon Freddy Krueger devises a plan...   14.015739  ...
# 2951  A military officer in command of a drone opera...   10.564701  ...
# 2952  After 29-year-old Adaline recovers from a near...   10.542026  ...
# 2953  Parker and Longbaugh are a pair of low-level p...    6.036330  ...
# 2954  In Manhattan, the British limousine driver Alf...   10.411608  ...
# 2955  Enforcing the law within the notoriously rough...   12.504220  ...
# 2956  A pair of adventurers try to track down an anc...    3.150899  ...
# 2957  A vengeful New York transit cop decides to ste...    7.337906  ...
# 2958  A 3-D presentation of U2's global "Vertigo" to...    0.900864  ...
# 2959  Depressed after the passing of his father, Dha...    3.959411  ...
# 2960  Jo is chained down in a dead end supermarket j...    5.805666  ...
# 2961  Set in 1954, a group of Florida high schoolers...   12.650546  ...
# 2962  After suffering a family tragedy, Mack Phillip...   16.392712  ...
# 2963  During her freshman year in high school, Mika ...    1.718237  ...
# 2964  An exploration of technologically developing n...    2.726061  ...
# 2965  An adaptation of the successful stage musical ...   13.524080  ...
# 2966  After being murdered by corrupt colleagues in ...   11.366417  ...
# 2967  Fast Eddie Felson is a small-time pool hustler...    9.333533  ...
# 2968  In eighteenth century Romania, Rayne, a dhampi...    6.514132  ...
# 2969  Multiple storylined drama set in 1932, showing...   14.101101  ...
# 2970  A former Secret Service agent grudgingly takes...    9.805017  ...
# 2971  Larry Burrows is unhappy and feels powerless o...    4.414928  ...
# 2972  Dragon Tiger Gate is a 2006 Hong Kong martial ...    4.154861  ...
# 2973  Michael and Ellie break into a military junkya...    3.868014  ...
# 2974  Edward Carnby is a private investigator specia...    5.871243  ...
# 2975  It's summer vacation, but the Pearson family k...   11.618472  ...
# 2976  The recently deceased Mona Dearly (Bette Midle...    4.372616  ...
# 2977  A story about a seemingly unlikely couple who ...    5.396200  ...
# 2978  Almost a decade has elapsed since Bowiesque gl...   16.529300  ...
# 2979  When Zoe tires of looking for Mr. Right, she d...    6.629999  ...
# 2980  Biju is an honest policeman who fights the inj...    0.350207  ...
# 2981  David, a struggling comedy writer fresh off fr...    3.069108  ...
# 2982  Kate and Charlie like to have a good time. The...    4.893812  ...
# 2983  Anna (Marceau) is a wife and mother who has an...    5.660835  ...
# 2984  Hondo Harrelson recruits Jim Street to join an...   13.334952  ...
# 2985  A black police detective must solve a strange ...    5.388535  ...
# 2986  A rising Hollywood actor decides to take perso...   12.553403  ...
# 2987  Experiments in biological warfare have destroy...    1.292125  ...
# 2988  A visual social examination in the form of ten...    0.984515  ...
# 2989  The adventures of a young Trumpeter swan who c...    0.851599  ...
# 2990  Can two clueless Georgia homegirls with big he...    1.560980  ...
# 2991  A white midwestern girl moves to Chicago, wher...    4.794088  ...
# 2992  A recalcitrant thief vies with a duplicitous M...    3.878515  ...
# 2993  Viktor Navorski is a man without a country; hi...   14.092373  ...
# 2994  When David Greene receives a football scholars...    7.438381  ...
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#      release_date runtime                                   spoken_languages  \
# 2950      8/15/03    97.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2951      9/11/15   102.0  [{'iso_639_1': 'so', 'name': 'Somali'}, {'iso_...
# 2952      4/16/15   112.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2953       9/8/00   119.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2954     10/22/04   103.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2955      1/16/09   133.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2956     11/21/86   104.0  [{'iso_639_1': 'hu', 'name': 'Magyar'}, {'iso_...
# 2957     11/21/95   103.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2958      5/19/07    85.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2959     10/26/07   145.0  [{'iso_639_1': 'hi', 'name': 'हिन्दी'}, {'iso_...
# 2960       6/2/10   117.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2961     11/13/81    94.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2962       3/3/17   132.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2963      11/3/07   129.0               [{'iso_639_1': 'ja', 'name': '日本語'}]
# 2964      4/29/88    99.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2965     12/18/12   157.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2966      7/31/97    96.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2967      9/25/61   134.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2968     10/22/05    95.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2969      11/7/01   137.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2970     11/25/92   129.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2971     10/12/90   110.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2972      7/27/06    94.0         [{'iso_639_1': 'cn', 'name': '广州话 / 廣州話'}]
# 2973       8/9/85    94.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2974      1/28/05    96.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2975      7/31/09    86.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2976       3/3/00    96.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2977      5/15/01   102.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2978     10/23/98   119.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2979      4/23/10   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2980       2/4/16   144.0                  [{'iso_639_1': 'ml', 'name': ''}]
# 2981       9/9/16    97.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2982      9/12/12    85.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2983       4/4/97   108.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2984       8/8/03   117.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2985      2/17/06   113.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2986       9/3/04    84.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2987      1/20/89    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2988      5/20/02    94.0             [{'iso_639_1': 'fa', 'name': 'فارسی'}]
# 2989      5/11/01    75.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2990      3/28/97    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2991      1/12/01   112.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2992      3/18/24   149.0       [{'iso_639_1': 'xx', 'name': 'No Language'}]
# 2993      6/17/04   128.0  [{'iso_639_1': 'bg', 'name': 'български език'}...
# 2994      9/18/92   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2995      4/22/94   102.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2996      3/28/13   102.0           [{'iso_639_1': 'sv', 'name': 'svenska'}]
# 2997     10/11/96   120.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2998      1/16/04    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2999      9/22/11   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#         status                                            tagline  \
# 2950  Released                              Evil Will Battle Evil
# 2951  Released                      Welcome to the new front line
# 2952  Released                                  Love is timeless.
# 2953  Released                                                NaN
# 2954  Released   Meet a man who never met a woman he didn't love.
# 2955  Released                     This is War. This is Brooklyn.
# 2956  Released  A pair of down-and-out fortune hunters cash in...
# 2957  Released                        Get on, or GET OUT THE WAY!
# 2958  Released                                Hear See Experience
# 2959  Released                                                NaN
# 2960  Released           4 Girls, 3 Days, 2 Cities, 1 Chance.....
# 2961  Released  Keep an eye out for the funniest movie about g...
# 2962  Released                You're never as alone as you think.
# 2963  Released                                                NaN
# 2964  Released                                                NaN
# 2965  Released                          Fight. Dream. Hope. Love.
# 2966  Released                Born in darkness. Sworn to justice.
# 2967  Released  They called him Fast Eddie. He was a winner. H...
# 2968  Released                     Revenge never tasted so sweet.
# 2969  Released  Tea at four. Dinner at eight. Murder at midnight.
# 2970  Released  Never let her out of your sight. Never let you...
# 2971  Released  Larry Burrows Wished For It All... Until All T...
# 2972  Released                                                NaN
# 2973  Released                     We must not destroy the world.
# 2974  Released  Can mankind defeat the army of darkness unleas...
# 2975  Released                        The aliens vs. the Pearsons
# 2976  Released  The death of Mona Dearly wasn't so much a whod...
# 2977  Released       The deeper you look, the more you will find.
# 2978  Released       Style matters. Even when it comes to murder.
# 2979  Released  Fall in love, get married, have a baby. Not ne...
# 2980  Released                       A ride with a police officer
# 2981  Released                                                NaN
# 2982  Released                                                NaN
# 2983  Released  In a world of power and privilege, one woman d...
# 2984  Released              You're either S.W.A.T. or you're not.
# 2985  Released    The Truth Is Hiding Where No One Dares To Look.
# 2986  Released                    One good shot deserves another.
# 2987  Released                               It Wants To Get Out!
# 2988  Released                                                NaN
# 2989  Released  Sometimes being different helps you to find yo...
# 2990  Released                These Pretty Women... Are Clueless!
# 2991  Released        The Only Person You Need To Be Is Yourself.
# 2992  Released                         "Happiness Must Be Earned"
# 2993  Released                                   Life is waiting.
# 2994  Released  Just because you’re accepted doesn’t mean you ...
# 2995  Released  It was supposed to be a routine prisoner trans...
# 2996  Released                                                NaN
# 2997  Released               What's forgotten is not always gone.
# 2998  Released  For the most cautious man on Earth, life is ab...
# 2999  Released          They stole his life. He's taking it back.
#
#                         title  \
# 2950         Freddy vs. Jason
# 2951           Eye in the Sky
# 2952       The Age of Adaline
# 2953       The Way of the Gun
# 2954                    Alfie
# 2955        Brooklyn's Finest
# 2956               Firewalker
# 2957              Money Train
# 2958                    U2 3D
# 2959               Jab We Met
# 2960                  4.3.2.1
# 2961                  Porky's
# 2962                The Shack
# 2963              Sky Of Love
# 2964               Powaqqatsi
# 2965           Les Misérables
# 2966                    Spawn
# 2967              The Hustler
# 2968               BloodRayne
# 2969             Gosford Park
# 2970            The Bodyguard
# 2971              Mr. Destiny
# 2972        Dragon Tiger Gate
# 2973       My Science Project
# 2974        Alone in the Dark
# 2975      Aliens in the Attic
# 2976            Drowning Mona
# 2977               Angel Eyes
# 2978          Velvet Goldmine
# 2979         The Back-Up Plan
# 2980         Action Hero Biju
# 2981             Other People
# 2982                  Smashed
# 2983            Anna Karenina
# 2984                 S.W.A.T.
# 2985              Freedomland
# 2986                Paparazzi
# 2987        The Terror Within
# 2988                      Ten
# 2989  The Trumpet Of The Swan
# 2990                 B.A.P.S.
# 2991      Save the Last Dance
# 2992      The Thief of Bagdad
# 2993             The Terminal
# 2994              School Ties
# 2995                  Chasers
# 2996         We Are the Best!
# 2997  The Long Kiss Goodnight
# 2998         Along Came Polly
# 2999                Abduction
#
#                                                Keywords  \
# 2950  [{'id': 9826, 'name': 'murder'}, {'id': 10776,...
# 2951  [{'id': 949, 'name': 'terrorist'}, {'id': 1193...
# 2952  [{'id': 582, 'name': 'san francisco'}, {'id': ...
# 2953  [{'id': 75, 'name': 'gunslinger'}, {'id': 534,...
# 2954  [{'id': 242, 'name': 'new york'}, {'id': 1332,...
# 2955  [{'id': 255, 'name': 'male nudity'}, {'id': 29...
# 2956  [{'id': 352, 'name': 'secret passage'}, {'id':...
# 2957  [{'id': 380, 'name': 'brother brother relation...
# 2958                                                NaN
# 2959  [{'id': 2038, 'name': "love of one's life"}, {...
# 2960                                                NaN
# 2961  [{'id': 255, 'name': 'male nudity'}, {'id': 29...
# 2962  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 2963  [{'id': 6270, 'name': 'high school'}, {'id': 9...
# 2964        [{'id': 10183, 'name': 'independent film'}]
# 2965  [{'id': 254, 'name': 'france'}, {'id': 642, 'n...
# 2966  [{'id': 2095, 'name': 'anti hero'}, {'id': 428...
# 2967  [{'id': 236, 'name': 'suicide'}, {'id': 395, '...
# 2968  [{'id': 3133, 'name': 'vampire'}, {'id': 9259,...
# 2969  [{'id': 964, 'name': 'servant'}, {'id': 10594,...
# 2970  [{'id': 1156, 'name': 'sister sister relations...
# 2971                     [{'id': 4896, 'name': 'wish'}]
# 2972                   [{'id': 780, 'name': 'kung fu'}]
# 2973  [{'id': 4379, 'name': 'time travel'}, {'id': 1...
# 2974  [{'id': 703, 'name': 'detective'}, {'id': 1299...
# 2975  [{'id': 9951, 'name': 'alien'}, {'id': 10267, ...
# 2976  [{'id': 3301, 'name': 'suspicion'}, {'id': 387...
# 2977  [{'id': 9844, 'name': 'car crash'}, {'id': 150...
# 2978  [{'id': 237, 'name': 'gay'}, {'id': 1025, 'nam...
# 2979  [{'id': 5091, 'name': 'kiss'}, {'id': 5098, 'n...
# 2980  [{'id': 1252, 'name': 'suicide attempt'}, {'id...
# 2981                [{'id': 234102, 'name': 'misfits'}]
# 2982                                                NaN
# 2983                                                NaN
# 2984  [{'id': 2434, 'name': 'liberation'}, {'id': 35...
# 2985  [{'id': 577, 'name': 'black people'}, {'id': 5...
# 2986        [{'id': 10183, 'name': 'independent film'}]
# 2987  [{'id': 1299, 'name': 'monster'}, {'id': 1852,...
# 2988  [{'id': 1156, 'name': 'sister sister relations...
# 2989  [{'id': 6653, 'name': 'trumpet'}, {'id': 10407...
# 2990  [{'id': 1437, 'name': 'burglar'}, {'id': 1946,...
# 2991  [{'id': 4118, 'name': 'ballet dancer'}, {'id':...
# 2992  [{'id': 255, 'name': 'male nudity'}, {'id': 14...
# 2993  [{'id': 242, 'name': 'new york'}, {'id': 822, ...
# 2994  [{'id': 6075, 'name': 'sport'}, {'id': 10144, ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 2950  [{'cast_id': 1, 'character': 'Freddy Krueger',...
# 2951  [{'cast_id': 4, 'character': 'Colonel Katherin...
# 2952  [{'cast_id': 0, 'character': 'Adaline Bowman',...
# 2953  [{'cast_id': 1, 'character': 'Mr. Longbaugh', ...
# 2954  [{'cast_id': 1, 'character': 'Alfie', 'credit_...
# 2955  [{'cast_id': 3, 'character': 'Eddie Dugan', 'c...
# 2956  [{'cast_id': 1, 'character': 'Max Donigan', 'c...
# 2957  [{'cast_id': 1, 'character': 'John', 'credit_i...
# 2958  [{'cast_id': 0, 'character': 'Himself', 'credi...
# 2959  [{'cast_id': 9, 'character': 'Aditya Kashyap',...
# 2960  [{'cast_id': 6, 'character': 'Joanne', 'credit...
# 2961  [{'cast_id': 1, 'character': 'Pee Wee', 'credi...
# 2962  [{'cast_id': 0, 'character': 'Mack Phillips', ...
# 2963  [{'cast_id': 1, 'character': 'Tahara Mika', 'c...
# 2964                                                 []
# 2965                                                NaN
# 2966  [{'cast_id': 9, 'character': 'Al Simmons', 'cr...
# 2967  [{'cast_id': 15, 'character': 'Eddie Felson', ...
# 2968  [{'cast_id': 3, 'character': 'Rayne', 'credit_...
# 2969  [{'cast_id': 2, 'character': 'Mrs. Wilson', 'c...
# 2970  [{'cast_id': 17, 'character': 'Rachel Marron',...
# 2971  [{'cast_id': 1, 'character': 'Larry Burrows', ...
# 2972  [{'cast_id': 1, 'character': 'Dragon Wong', 'c...
# 2973  [{'cast_id': 1, 'character': "Michael 'Mike' H...
# 2974  [{'cast_id': 12, 'character': 'Edward Carnby',...
# 2975  [{'cast_id': 4, 'character': 'Tom Pearson', 'c...
# 2976  [{'cast_id': 1, 'character': 'Chief Wyatt Rash...
# 2977  [{'cast_id': 1, 'character': 'Sharon Pogue', '...
# 2978  [{'cast_id': 2, 'character': 'Curt Wild', 'cre...
# 2979  [{'cast_id': 22, 'character': 'Zoe', 'credit_i...
# 2980  [{'cast_id': 1, 'character': 'Sub-Inspector Bi...
# 2981  [{'cast_id': 0, 'character': 'David', 'credit_...
# 2982  [{'cast_id': 1001, 'character': 'Kate Hannah',...
# 2983  [{'cast_id': 1, 'character': 'Anna Karenina', ...
# 2984  [{'cast_id': 25, 'character': "Sgt. Dan 'Hondo...
# 2985  [{'cast_id': 13, 'character': 'Lorenzo Council...
# 2986  [{'cast_id': 1, 'character': 'Bo Laramie', 'cr...
# 2987  [{'cast_id': 4, 'character': 'Hal', 'credit_id...
# 2988  [{'cast_id': 2, 'character': 'Driver', 'credit...
# 2989  [{'cast_id': 1, 'character': 'Father', 'credit...
# 2990  [{'cast_id': 3, 'character': 'Nisi', 'credit_i...
# 2991  [{'cast_id': 18, 'character': 'Sara Johnson', ...
# 2992  [{'cast_id': 3, 'character': 'The Thief of Bag...
# 2993  [{'cast_id': 4, 'character': 'Viktor Navorski'...
# 2994  [{'cast_id': 2, 'character': 'David Greene', '...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue
# 2950  [{'credit_id': '52fe4453c3a36847f808f4a5', 'de...  114908830
# 2951  [{'credit_id': '55186708c3a36862f6004623', 'de...   18704595
# 2952  [{'credit_id': '54721093c3a3686792002bc5', 'de...   65663276
# 2953  [{'credit_id': '52fe4305c3a36847f8034691', 'de...   19125401
# 2954  [{'credit_id': '562643e89251413ded006a07', 'de...   13395939
# 2955  [{'credit_id': '52fe4500c3a368484e042e7b', 'de...   29536299
# 2956  [{'credit_id': '52fe45199251416c7504bbf7', 'de...   11949484
# 2957  [{'credit_id': '52fe44509251416c750305a1', 'de...   35431113
# 2958  [{'credit_id': '57bfd2089251414b1500001e', 'de...   22730842
# 2959  [{'credit_id': '537ef0d8c3a36805a1002844', 'de...    4600000
# 2960  [{'credit_id': '52fe46a1c3a36847f810975b', 'de...    1163967
# 2961  [{'credit_id': '575f47279251415e1f00012e', 'de...  125728258
# 2962  [{'credit_id': '591ed967c3a368799b03016c', 'de...   57330873
# 2963  [{'credit_id': '52fe459fc3a36847f80d161b', 'de...   44038000
# 2964  [{'credit_id': '52fe4491c3a368484e02a2c3', 'de...     589244
# 2965                                                NaN  441809770
# 2966  [{'credit_id': '52fe435b9251416c7500d4d5', 'de...   87840042
# 2967  [{'credit_id': '52fe4297c3a36847f802a989', 'de...    7600000
# 2968  [{'credit_id': '52fe4cd4c3a36847f82407f7', 'de...    2405420
# 2969  [{'credit_id': '52fe4401c3a36847f807ceab', 'de...   87754044
# 2970  [{'credit_id': '52fe425ec3a36847f8019133', 'de...  411006740
# 2971  [{'credit_id': '52fe4360c3a36847f804f873', 'de...   15379253
# 2972  [{'credit_id': '52fe46869251416c7507b08f', 'de...    8685526
# 2973  [{'credit_id': '52fe476e9251416c75099025', 'de...    4122748
# 2974  [{'credit_id': '52fe44bd9251416c7503f4f1', 'de...   10442808
# 2975  [{'credit_id': '537830e40e0a261425003dca', 'de...   57881056
# 2976  [{'credit_id': '52fe44bbc3a368484e033ccf', 'de...   15427192
# 2977  [{'credit_id': '52fe4427c3a36847f8085447', 'de...   29700000
# 2978  [{'credit_id': '52fe4316c3a36847f803946d', 'de...    1053788
# 2979  [{'credit_id': '52fe457e9251416c91034559', 'de...   77477008
# 2980  [{'credit_id': '56b4d47f92514112b90045f6', 'de...    2500000
# 2981  [{'credit_id': '57d923309251415959005090', 'de...      93000
# 2982  [{'credit_id': '557455c1c3a3686b7d003df7', 'de...     376597
# 2983  [{'credit_id': '52fe47cac3a36847f81484f7', 'de...     791830
# 2984  [{'credit_id': '5379d4980e0a261431006f58', 'de...  116643346
# 2985  [{'credit_id': '52fe4551c3a36847f80c76e7', 'de...   14655628
# 2986  [{'credit_id': '5678044292514179dd008c37', 'de...   16605763
# 2987  [{'credit_id': '52fe45d9c3a368484e072511', 'de...     858591
# 2988  [{'credit_id': '52fe460a9251416c7506b0a7', 'de...     105656
# 2989  [{'credit_id': '58bc9d609251416084044b0e', 'de...     100202
# 2990  [{'credit_id': '52fe477b9251416c7509af57', 'de...    7240837
# 2991  [{'credit_id': '52fe4533c3a36847f80c1c6b', 'de...   91038276
# 2992  [{'credit_id': '52fe45bec3a368484e06c70b', 'de...    1213880
# 2993  [{'credit_id': '52fe4259c3a36847f8017699', 'de...  219417255
# 2994  [{'credit_id': '5637777ac3a3681b4d01f9f5', 'de...   14715067
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
# [50 rows x 23 columns]

# %% [markdown]
# ### <b>Columns</b>
# Prints the list of columns in a dataframe

# %%
data.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
list(data.columns)
# Out:
# ['id',
#  'belongs_to_collection',
#  'budget',
#  'genres',
#  'homepage',
#  'imdb_id',
#  'original_language',
#  'original_title',
#  'overview',
#  'popularity',
#  'poster_path',
#  'production_companies',
#  'production_countries',
#  'release_date',
#  'runtime',
#  'spoken_languages',
#  'status',
#  'tagline',
#  'title',
#  'Keywords',
#  'cast',
#  'crew',
#  'revenue']

# %% [markdown]
# ### <b>Dtypes</b>
# It is used to find data type of each column

# %%
data.dtypes
# Out:
# id                         int64
# belongs_to_collection     object
# budget                     int64
# genres                    object
# homepage                  object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity               float64
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# Keywords                  object
# cast                      object
# crew                      object
# revenue                    int64
# dtype: object

# %%
data['id'].dtypes
# Out:
# dtype('int64')

# %% [markdown]
# ### <b>Select_dtypes</b>
# The select_dtypes method in Pandas is used to select columns based on their data type(s). It allows you to filter a DataFrame to include only specific data types, making it easy to work with subsets of data, like numerical or categorical columns.
# * Numerical columns : int64 , float64
# * categorical columns : object

# %%
num_data = data.select_dtypes(include = ['int64', 'float64'])
num_data
# Out:
#         id    budget  popularity  runtime    revenue
# 0        1  14000000    6.575393     93.0   12314651
# 1        2  40000000    8.248895    113.0   95149435
# 2        3   3300000   64.299990    105.0   13092000
# 3        4   1200000    3.174936    122.0   16000000
# 4        5         0    1.148070    118.0    3923970
# ...    ...       ...         ...      ...        ...
# 2995  2996         0    9.853270    102.0    1596687
# 2996  2997         0    3.727996    102.0     180590
# 2997  2998  65000000   14.482345    120.0   89456761
# 2998  2999  42000000   15.725542     90.0  171963386
# 2999  3000  35000000   10.512109    106.0   82087155
#
# [3000 rows x 5 columns]

# %%
# fetch categorical columns(object)
cat_data=data.select_dtypes(include=['object'])
cat_data.columns
# Out:
# Index(['belongs_to_collection', 'genres', 'homepage', 'imdb_id',
#        'original_language', 'original_title', 'overview', 'poster_path',
#        'production_companies', 'production_countries', 'release_date',
#        'spoken_languages', 'status', 'tagline', 'title', 'Keywords', 'cast',
#        'crew'],
#       dtype='object')

# %% [markdown]
# ### <b>Info()</b>
#
# Prints the basic information about our dataframe

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
#  14  runtime                2998 non-null   float64
#  15  spoken_languages       2980 non-null   object
#  16  status                 3000 non-null   object
#  17  tagline                2403 non-null   object
#  18  title                  3000 non-null   object
#  19  Keywords               2724 non-null   object
#  20  cast                   2987 non-null   object
#  21  crew                   2984 non-null   object
#  22  revenue                3000 non-null   int64
# dtypes: float64(2), int64(3), object(18)
# memory usage: 539.2+ KB

# %% [markdown]
# **The data.info() method in Pandas provides a quick overview of a DataFrame's structure:**
#
# 1. Index Info: Type and range of the index.
# 2. Column Info: Names, data types, and non-null counts for each column.
# 3. Memory Usage: Approximate memory used by the DataFrame.

# %% [markdown]
# ### <b> Describe </b>
# Pandas describe() gives a quick statistical summary of your dataset.
#
# It shows:
#
# **count** → number of non-null values
#
# **mean** → average value
#
# **std** → standard deviation (spread of data)
#
# **min** → smallest value
#
# **25%** → first quartile
#
# **50%** → median
#
# **75%** → third quartile
#
# **max** → largest value
#
# ✅ Ignores NaN values automatically
#
# ✅ Helps find patterns, spread, and possible outliers fast

# %%
# Numerical statistical report
data.describe()
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %%
# categorical statistics report for all text columns
data.describe(include='object')
# Out:
#                                     belongs_to_collection  \
# count                                                 604
# unique                                                422
# top     [{'id': 645, 'name': 'James Bond Collection', ...
# freq                                                   16
#
#                                genres                           homepage  \
# count                            2993                                946
# unique                            872                                941
# top     [{'id': 18, 'name': 'Drama'}]  http://www.transformersmovie.com/
# freq                              266                                  4
#
#           imdb_id original_language original_title  \
# count        3000              3000           3000
# unique       3000                36           2975
# top     tt1600195                en  Casino Royale
# freq            1              2575              2
#
#                                                  overview  \
# count                                                2992
# unique                                               2992
# top     Anna (Marceau) is a wife and mother who has an...
# freq                                                    1
#
#                              poster_path  \
# count                               2999
# unique                              2999
# top     /cUT6NQP5LAJpmUoStGtXmvNt4zA.jpg
# freq                                   1
#
#                              production_companies  \
# count                                        2844
# unique                                       2383
# top     [{'name': 'Paramount Pictures', 'id': 4}]
# freq                                           51
#
#                                      production_countries release_date  \
# count                                                2945         3000
# unique                                                321         2398
# top     [{'iso_3166_1': 'US', 'name': 'United States o...      9/10/15
# freq                                                 1752            5
#
#                                 spoken_languages    status  \
# count                                       2980      3000
# unique                                       401         2
# top     [{'iso_639_1': 'en', 'name': 'English'}]  Released
# freq                                        1817      2996
#
#                        tagline          title  \
# count                     2403           3000
# unique                    2400           2969
# top     Based on a true story.  Loose Cannons
# freq                         3              2
#
#                                            Keywords  cast  \
# count                                          2724  2987
# unique                                         2648  2975
# top     [{'id': 10183, 'name': 'independent film'}]    []
# freq                                             27    13
#
#                                                      crew
# count                                                2984
# unique                                               2984
# top     [{'credit_id': '5391990d0e0a260fb5001629', 'de...
# freq                                                    1

# %% [markdown]
# ### <b>Check Missing Values</b>
# Missing values are empty or undefined values within a dataset, often represented as NA, None, Null, or NaN. These values indicate gaps in the data that need to be handled before analysis, as they can affect calculations and model performance.

# %%
data.isnull()
# Out:
#          id  belongs_to_collection  budget  genres  homepage  imdb_id  \
# 0     False                  False   False   False      True    False
# 1     False                  False   False   False      True    False
# 2     False                   True   False   False     False    False
# 3     False                   True   False   False     False    False
# 4     False                   True   False   False      True    False
# ...     ...                    ...     ...     ...       ...      ...
# 2995  False                   True   False   False      True    False
# 2996  False                   True   False   False      True    False
# 2997  False                   True   False   False      True    False
# 2998  False                   True   False   False     False    False
# 2999  False                   True   False   False     False    False
#
#       original_language  original_title  overview  popularity  ...  \
# 0                 False           False     False       False  ...
# 1                 False           False     False       False  ...
# 2                 False           False     False       False  ...
# 3                 False           False     False       False  ...
# 4                 False           False     False       False  ...
# ...                 ...             ...       ...         ...  ...
# 2995              False           False     False       False  ...
# 2996              False           False     False       False  ...
# 2997              False           False     False       False  ...
# 2998              False           False     False       False  ...
# 2999              False           False     False       False  ...
#
#       release_date  runtime  spoken_languages  status  tagline  title  \
# 0            False    False             False   False    False  False
# 1            False    False             False   False    False  False
# 2            False    False             False   False    False  False
# 3            False    False             False   False     True  False
# 4            False    False             False   False     True  False
# ...            ...      ...               ...     ...      ...    ...
# 2995         False    False             False   False    False  False
# 2996         False    False             False   False     True  False
# 2997         False    False             False   False    False  False
# 2998         False    False             False   False    False  False
# 2999         False    False             False   False    False  False
#
#       Keywords   cast   crew  revenue
# 0        False  False  False    False
# 1        False  False  False    False
# 2        False  False  False    False
# 3        False  False  False    False
# 4         True  False  False    False
# ...        ...    ...    ...      ...
# 2995     False  False  False    False
# 2996     False  False  False    False
# 2997     False  False  False    False
# 2998     False  False  False    False
# 2999     False  False  False    False
#
# [3000 rows x 23 columns]

# %%
data.isnull().sum()
# This code gives us the total count of missing values in each column
# Out:
# id                          0
# belongs_to_collection    2396
# budget                      0
# genres                      7
# homepage                 2054
# imdb_id                     0
# original_language           0
# original_title              0
# overview                    8
# popularity                  0
# poster_path                 1
# production_companies      156
# production_countries       55
# release_date                0
# runtime                     2
# spoken_languages           20
# status                      0
# tagline                   597
# title                       0
# Keywords                  276
# cast                       13
# crew                       16
# revenue                     0
# dtype: int64

# %% [markdown]
# ## **How to drop missing values**

# %%
data.dropna(inplace=True)

# %% [markdown]
# **dropna** is a method in pandas used to drop missing values(May be NA , NULL, None)

# %%
data.shape
# Out:
# (203, 23)

# %% [markdown]
# **Note:**
#
# ### **To replace missing values with mean use below code**
#
# `data.loc[:,column].fillna(value=data.loc[:,column].mean(),inplace=True)`
#
# * data[:,column].mean() used to find average of column
# * inplace=True is used to do changes permanently in original dataframe

# %% [markdown]
# ### **Points to remember**
# - `df.isnull()` - Returns `True` for missing values.
# - `df.isnull().sum()` - Counts missing values for each column.
# - `df.dropna()` - Removes rows with missing values.
# - `df.fillna(value)` - Fills missing values with a specified value.

# %% [markdown]
# ### <b>Checking for Duplicates</b>
# Duplicates in a dataset refer to rows that contain identical data across all columns or selected columns. Detecting and managing duplicates is essential to ensure data accuracy and quality, especially for analysis and modeling.

# %%
# Use the duplicated() function to identify duplicates.
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### **How to drop duplicates**

# %%
data.drop_duplicates()
# Out:
#         id                              belongs_to_collection     budget  \
# 22      23  [{'id': 207621, 'name': 'V/H/S Collection', 'p...          0
# 40      41  [{'id': 376970, 'name': 'Cocaine Cowboys', 'po...          0
# 46      47  [{'id': 8354, 'name': 'Ice Age Collection', 'p...   80000000
# 60      61  [{'id': 645, 'name': 'James Bond Collection', ...  150000000
# 69      70  [{'id': 9485, 'name': 'The Fast and the Furiou...   85000000
# ...    ...                                                ...        ...
# 2904  2905  [{'id': 424202, 'name': 'Trainspotting Collect...    4000000
# 2927  2928  [{'id': 645, 'name': 'James Bond Collection', ...  140000000
# 2938  2939  [{'id': 135416, 'name': 'Prometheus Collection...  130000000
# 2968  2969  [{'id': 97307, 'name': 'BloodRayne Collection'...   25000000
# 2984  2985  [{'id': 221111, 'name': 'S.W.A.T. Collection',...   80000000
#
#                                                  genres  \
# 22    [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 40    [{'id': 28, 'name': 'Action'}, {'id': 99, 'nam...
# 46    [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 60    [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 69    [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# ...                                                 ...
# 2904  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 2927  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 2938  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 2968  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2984  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                                                homepage    imdb_id  \
# 22                  http://www.magnetreleasing.com/vhs/  tt2105044
# 40    http://www.magpictures.com/profile.aspx?id=983...  tt0380268
# 46    http://www.iceagemovies.com/films/ice-age-the-...  tt0438097
# 60    http://www.mgm.com/#/our-titles/233/Casino-Roy...  tt0381061
# 69                http://www.thefastandthefurious3.com/  tt0463985
# ...                                                 ...        ...
# 2904        http://www.miramax.com/movie/trainspotting/  tt0117951
# 2927  http://www.mgm.com/view/movie/232/Die-Another-...  tt0246460
# 2938                  http://www.projectprometheus.com/  tt1446714
# 2968  http://www.bloodrayne-themovie.com/main/index....  tt0383222
# 2984        http://www.sonypictures.com/homevideo/swat/  tt0257076
#
#      original_language                         original_title  \
# 22                  en                                  V/H/S
# 40                  en                        Cocaine Cowboys
# 46                  en                  Ice Age: The Meltdown
# 60                  en                          Casino Royale
# 69                  en  The Fast and the Furious: Tokyo Drift
# ...                ...                                    ...
# 2904                en                          Trainspotting
# 2927                en                        Die Another Day
# 2938                en                             Prometheus
# 2968                en                             BloodRayne
# 2984                en                               S.W.A.T.
#
#                                                overview  popularity  ...  \
# 22    When a group of misfits is hired by an unknown...    7.820787  ...
# 40    In the 1980s, ruthless Colombian cocaine baron...    2.941626  ...
# 46    Diego, Manny and Sid return in this sequel to ...   16.646029  ...
# 60    Le Chiffre, a banker to the world's terrorists...   23.065078  ...
# 69    In order to avoid a jail sentence, Sean Boswel...    2.238808  ...
# ...                                                 ...         ...  ...
# 2904  Renton, deeply immersed in the Edinburgh drug ...   19.348466  ...
# 2927  Bond takes on a North Korean leader who underg...   12.996474  ...
# 2938  A team of explorers discover a clue to the ori...   16.624854  ...
# 2968  In eighteenth century Romania, Rayne, a dhampi...    6.514132  ...
# 2984  Hondo Harrelson recruits Jim Street to join an...   13.334952  ...
#
#      release_date runtime                                   spoken_languages  \
# 22        7/28/12   116.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 40        4/26/06   118.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 46        3/23/06    91.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 60       11/14/06   144.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 69         6/3/06   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# ...           ...     ...                                                ...
# 2904      2/23/96    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2927     11/17/02   133.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2938      5/30/12   124.0  [{'iso_639_1': 'gd', 'name': ''}, {'iso_639_1'...
# 2968     10/22/05    95.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2984       8/8/03   117.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#         status                                            tagline  \
# 22    Released                         This collection is killer.
# 40    Released  How Miami became the cocaine capital of the Un...
# 46    Released                       The Ice age is melting away.
# 60    Released  Everyone has a past. Every legend has a beginn...
# 69    Released  On the streets of Tokyo, speed needs no transl...
# ...        ...                                                ...
# 2904  Released                                       Choose life.
# 2927  Released                            He’s never been cooler.
# 2938  Released  The Search for Our Beginning Could Lead to Our...
# 2968  Released                     Revenge never tasted so sweet.
# 2984  Released              You're either S.W.A.T. or you're not.
#
#                                       title  \
# 22                                    V/H/S
# 40                          Cocaine Cowboys
# 46                    Ice Age: The Meltdown
# 60                            Casino Royale
# 69    The Fast and the Furious: Tokyo Drift
# ...                                     ...
# 2904                          Trainspotting
# 2927                        Die Another Day
# 2938                             Prometheus
# 2968                             BloodRayne
# 2984                               S.W.A.T.
#
#                                                Keywords  \
# 22    [{'id': 6435, 'name': 'webcam'}, {'id': 9706, ...
# 40    [{'id': 2150, 'name': 'cocaine'}, {'id': 2231,...
# 46    [{'id': 2078, 'name': 'mammoth'}, {'id': 2079,...
# 60    [{'id': 131, 'name': 'italy'}, {'id': 383, 'na...
# 69    [{'id': 830, 'name': 'car race'}, {'id': 1926,...
# ...                                                 ...
# 2904  [{'id': 212, 'name': 'london england'}, {'id':...
# 2927  [{'id': 3290, 'name': 'laser'}, {'id': 156095,...
# 2938  [{'id': 803, 'name': 'android'}, {'id': 4565, ...
# 2968  [{'id': 3133, 'name': 'vampire'}, {'id': 9259,...
# 2984  [{'id': 2434, 'name': 'liberation'}, {'id': 35...
#
#                                                    cast  \
# 22    [{'cast_id': 1, 'character': 'Gary', 'credit_i...
# 40    [{'cast_id': 2, 'character': 'Himself', 'credi...
# 46    [{'cast_id': 1, 'character': 'Manny (voice)', ...
# 60    [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 69    [{'cast_id': 12, 'character': 'Sean Boswell', ...
# ...                                                 ...
# 2904  [{'cast_id': 17, 'character': 'Mark Renton', '...
# 2927  [{'cast_id': 20, 'character': 'James Bond', 'c...
# 2938  [{'cast_id': 5, 'character': 'Dr. Elizabeth Sh...
# 2968  [{'cast_id': 3, 'character': 'Rayne', 'credit_...
# 2984  [{'cast_id': 25, 'character': "Sgt. Dan 'Hondo...
#
#                                                    crew    revenue
# 22    [{'credit_id': '52fe48ee9251416c9109d113', 'de...     100345
# 40    [{'credit_id': '52fe46179251416c7506cc15', 'de...     163000
# 46    [{'credit_id': '52fe4292c3a36847f80292c9', 'de...  660940780
# 60    [{'credit_id': '53ac1fd7c3a3684bc8001908', 'de...  599045960
# 69    [{'credit_id': '56784ed792514111900002c8', 'de...  158468292
# ...                                                 ...        ...
# 2904  [{'credit_id': '52fe4260c3a36847f80198c1', 'de...   16491080
# 2927  [{'credit_id': '52fe45ff9251416c91045a7f', 'de...  431971116
# 2938  [{'credit_id': '52fe481dc3a368484e0e9db7', 'de...  403170142
# 2968  [{'credit_id': '52fe4cd4c3a36847f82407f7', 'de...    2405420
# 2984  [{'credit_id': '5379d4980e0a261431006f58', 'de...  116643346
#
# [203 rows x 23 columns]

# %% [markdown]
# The **drop_duplicates()** function in Pandas is used to remove duplicate rows from a DataFrame or Series. This is especially helpful for cleaning data and ensuring uniqueness.

# %% [markdown]
# ### **fetch single column**

# %%
# fetch budget column
data[['budget']]
# It fetches single column , but this method not much used in the real world
# Out:
#          budget
# 22            0
# 40            0
# 46     80000000
# 60    150000000
# 69     85000000
# ...         ...
# 2904    4000000
# 2927  140000000
# 2938  130000000
# 2968   25000000
# 2984   80000000
#
# [203 rows x 1 columns]

# %% [markdown]
# ### **fetch multiple columns**

# %%
# fetch 'original_language', 'original_title', 'overview','popularity'
data[['original_language', 'original_title', 'overview','popularity']]
# Out:
#      original_language                         original_title  \
# 22                  en                                  V/H/S
# 40                  en                        Cocaine Cowboys
# 46                  en                  Ice Age: The Meltdown
# 60                  en                          Casino Royale
# 69                  en  The Fast and the Furious: Tokyo Drift
# ...                ...                                    ...
# 2904                en                          Trainspotting
# 2927                en                        Die Another Day
# 2938                en                             Prometheus
# 2968                en                             BloodRayne
# 2984                en                               S.W.A.T.
#
#                                                overview  popularity
# 22    When a group of misfits is hired by an unknown...    7.820787
# 40    In the 1980s, ruthless Colombian cocaine baron...    2.941626
# 46    Diego, Manny and Sid return in this sequel to ...   16.646029
# 60    Le Chiffre, a banker to the world's terrorists...   23.065078
# 69    In order to avoid a jail sentence, Sean Boswel...    2.238808
# ...                                                 ...         ...
# 2904  Renton, deeply immersed in the Edinburgh drug ...   19.348466
# 2927  Bond takes on a North Korean leader who underg...   12.996474
# 2938  A team of explorers discover a clue to the ori...   16.624854
# 2968  In eighteenth century Romania, Rayne, a dhampi...    6.514132
# 2984  Hondo Harrelson recruits Jim Street to join an...   13.334952
#
# [203 rows x 4 columns]

# %% [markdown]
# # **LOC and ILOC**

# %% [markdown]
# In Pandas, indexing and slicing are essential for selecting and accessing subsets of data within a DataFrame or Series. Here are some common methods for indexing and slicing:
#
# 1. Indexing with .loc[] and .iloc[]

# %% [markdown]
# **loc[ ] - Label-based Indexing**
#
# 	• Used for selecting rows and columns by labels (names) instead of positions.
# 	• Supports label slicing for ranges.

# %% [markdown]
# **data.loc[row_idx , col_idx]**

# %%
data.head(2)
# Out:
#     id                              belongs_to_collection  budget  \
# 22  23  [{'id': 207621, 'name': 'V/H/S Collection', 'p...       0
# 40  41  [{'id': 376970, 'name': 'Cocaine Cowboys', 'po...       0
#
#                                                genres  \
# 22  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 40  [{'id': 28, 'name': 'Action'}, {'id': 99, 'nam...
#
#                                              homepage    imdb_id  \
# 22                http://www.magnetreleasing.com/vhs/  tt2105044
# 40  http://www.magpictures.com/profile.aspx?id=983...  tt0380268
#
#    original_language   original_title  \
# 22                en            V/H/S
# 40                en  Cocaine Cowboys
#
#                                              overview  popularity  ...  \
# 22  When a group of misfits is hired by an unknown...    7.820787  ...
# 40  In the 1980s, ruthless Colombian cocaine baron...    2.941626  ...
#
#    release_date runtime                          spoken_languages    status  \
# 22      7/28/12   116.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 40      4/26/06   118.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                               tagline            title  \
# 22                         This collection is killer.            V/H/S
# 40  How Miami became the cocaine capital of the Un...  Cocaine Cowboys
#
#                                              Keywords  \
# 22  [{'id': 6435, 'name': 'webcam'}, {'id': 9706, ...
# 40  [{'id': 2150, 'name': 'cocaine'}, {'id': 2231,...
#
#                                                  cast  \
# 22  [{'cast_id': 1, 'character': 'Gary', 'credit_i...
# 40  [{'cast_id': 2, 'character': 'Himself', 'credi...
#
#                                                  crew revenue
# 22  [{'credit_id': '52fe48ee9251416c9109d113', 'de...  100345
# 40  [{'credit_id': '52fe46179251416c7506cc15', 'de...  163000
#
# [2 rows x 23 columns]

# %%
# fetch budget column
data.loc[:,'budget']
# Out:
# 22              0
# 40              0
# 46       80000000
# 60      150000000
# 69       85000000
#           ...
# 2904      4000000
# 2927    140000000
# 2938    130000000
# 2968     25000000
# 2984     80000000
# Name: budget, Length: 203, dtype: int64

# %%
# fetch genres
data.loc[:,'genres']
# Out:
# 22      [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 40      [{'id': 28, 'name': 'Action'}, {'id': 99, 'nam...
# 46      [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 60      [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 69      [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
#                               ...
# 2904    [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 2927    [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 2938    [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 2968    [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2984    [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# Name: genres, Length: 203, dtype: object

# %%
# fetch 'original_language', 'original_title', 'overview','popularity'
data.loc[:,['original_language', 'original_title', 'overview','popularity']]
# Out:
#      original_language                         original_title  \
# 22                  en                                  V/H/S
# 40                  en                        Cocaine Cowboys
# 46                  en                  Ice Age: The Meltdown
# 60                  en                          Casino Royale
# 69                  en  The Fast and the Furious: Tokyo Drift
# ...                ...                                    ...
# 2904                en                          Trainspotting
# 2927                en                        Die Another Day
# 2938                en                             Prometheus
# 2968                en                             BloodRayne
# 2984                en                               S.W.A.T.
#
#                                                overview  popularity
# 22    When a group of misfits is hired by an unknown...    7.820787
# 40    In the 1980s, ruthless Colombian cocaine baron...    2.941626
# 46    Diego, Manny and Sid return in this sequel to ...   16.646029
# 60    Le Chiffre, a banker to the world's terrorists...   23.065078
# 69    In order to avoid a jail sentence, Sean Boswel...    2.238808
# ...                                                 ...         ...
# 2904  Renton, deeply immersed in the Edinburgh drug ...   19.348466
# 2927  Bond takes on a North Korean leader who underg...   12.996474
# 2938  A team of explorers discover a clue to the ori...   16.624854
# 2968  In eighteenth century Romania, Rayne, a dhampi...    6.514132
# 2984  Hondo Harrelson recruits Jim Street to join an...   13.334952
#
# [203 rows x 4 columns]

# %%
#'original_language', 'original_title', 'overview','popularity', 'poster_path', 'production_companies'
data.loc[: , 'original_language':'production_companies']
# Out:
#      original_language                         original_title  \
# 22                  en                                  V/H/S
# 40                  en                        Cocaine Cowboys
# 46                  en                  Ice Age: The Meltdown
# 60                  en                          Casino Royale
# 69                  en  The Fast and the Furious: Tokyo Drift
# ...                ...                                    ...
# 2904                en                          Trainspotting
# 2927                en                        Die Another Day
# 2938                en                             Prometheus
# 2968                en                             BloodRayne
# 2984                en                               S.W.A.T.
#
#                                                overview  popularity  \
# 22    When a group of misfits is hired by an unknown...    7.820787
# 40    In the 1980s, ruthless Colombian cocaine baron...    2.941626
# 46    Diego, Manny and Sid return in this sequel to ...   16.646029
# 60    Le Chiffre, a banker to the world's terrorists...   23.065078
# 69    In order to avoid a jail sentence, Sean Boswel...    2.238808
# ...                                                 ...         ...
# 2904  Renton, deeply immersed in the Edinburgh drug ...   19.348466
# 2927  Bond takes on a North Korean leader who underg...   12.996474
# 2938  A team of explorers discover a clue to the ori...   16.624854
# 2968  In eighteenth century Romania, Rayne, a dhampi...    6.514132
# 2984  Hondo Harrelson recruits Jim Street to join an...   13.334952
#
#                            poster_path  \
# 22    /yo49x6Jhr1ecCjy1ByFqwAbtARJ.jpg
# 40    /1Kqwllyvr4n3rLMvH2K17bavxT3.jpg
# 46    /isRuztu5Ch7FJdtSBLcG8QSOpEI.jpg
# 60    /zlWBxz2pTA9p45kUTrI8AQiKrHm.jpg
# 69    /f9V0iTSYwnxW6tPIjSE7jrGC7eP.jpg
# ...                                ...
# 2904  /p1O3eFsdb0GEIYu87xlwV7P4jM1.jpg
# 2927  /1iUZqUXS7x5FcGM5J0u01xuObWC.jpg
# 2938  /ng8ALjSDhUmwLl7vtjUWIZNQSlt.jpg
# 2968  /qCrvpGxWjOh7tVLxyqWLR65ZuWX.jpg
# 2984  /AgwobKKS20WRaQCHj5ut2R4KyHa.jpg
#
#                                    production_companies
# 22    [{'name': 'The Collective', 'id': 15156}, {'na...
# 40                   [{'name': 'Rakontur', 'id': 6303}]
# 46    [{'name': 'Blue Sky Studios', 'id': 9383}, {'n...
# 60    [{'name': 'Eon Productions', 'id': 7576}, {'na...
# 69           [{'name': 'Universal Pictures', 'id': 33}]
# ...                                                 ...
# 2904  [{'name': 'Miramax Films', 'id': 14}, {'name':...
# 2927          [{'name': 'Eon Productions', 'id': 7576}]
# 2938  [{'name': 'Twentieth Century Fox Film Corporat...
# 2968                 [{'name': 'Boll KG', 'id': 15127}]
# 2984  [{'name': 'Original Film', 'id': 333}, {'name'...
#
# [203 rows x 6 columns]

# %%
# fetch first row
data.iloc[[0],:]
# Out:
#     id                              belongs_to_collection  budget  \
# 22  23  [{'id': 207621, 'name': 'V/H/S Collection', 'p...       0
#
#                                                genres  \
# 22  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
#
#                                homepage    imdb_id original_language  \
# 22  http://www.magnetreleasing.com/vhs/  tt2105044                en
#
#    original_title                                           overview  \
# 22          V/H/S  When a group of misfits is hired by an unknown...
#
#     popularity  ... release_date runtime  \
# 22    7.820787  ...      7/28/12   116.0
#
#                             spoken_languages    status  \
# 22  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                        tagline  title  \
# 22  This collection is killer.  V/H/S
#
#                                              Keywords  \
# 22  [{'id': 6435, 'name': 'webcam'}, {'id': 9706, ...
#
#                                                  cast  \
# 22  [{'cast_id': 1, 'character': 'Gary', 'credit_i...
#
#                                                  crew revenue
# 22  [{'credit_id': '52fe48ee9251416c9109d113', 'de...  100345
#
# [1 rows x 23 columns]

# %% [markdown]
# **iloc[] - Position-based Indexing**
#
# 	•	Used for selecting rows and columns by their integer positions.
# 	•	Supports integer slicing for ranges.

# %%
# fetch budget column using iloc
# index of budget is 2
data.iloc[:,2]
# Out:
# 22              0
# 40              0
# 46       80000000
# 60      150000000
# 69       85000000
#           ...
# 2904      4000000
# 2927    140000000
# 2938    130000000
# 2968     25000000
# 2984     80000000
# Name: budget, Length: 203, dtype: int64

# %%
# fetch 'homepage' , 'imdb_id', 'original_language' using iloc
data.iloc[: ,[4,5,6]]
# index of homepage is 4 , index of imdb_id is 5 and index of original_language is 6
# Out:
#                                                homepage    imdb_id  \
# 22                  http://www.magnetreleasing.com/vhs/  tt2105044
# 40    http://www.magpictures.com/profile.aspx?id=983...  tt0380268
# 46    http://www.iceagemovies.com/films/ice-age-the-...  tt0438097
# 60    http://www.mgm.com/#/our-titles/233/Casino-Roy...  tt0381061
# 69                http://www.thefastandthefurious3.com/  tt0463985
# ...                                                 ...        ...
# 2904        http://www.miramax.com/movie/trainspotting/  tt0117951
# 2927  http://www.mgm.com/view/movie/232/Die-Another-...  tt0246460
# 2938                  http://www.projectprometheus.com/  tt1446714
# 2968  http://www.bloodrayne-themovie.com/main/index....  tt0383222
# 2984        http://www.sonypictures.com/homevideo/swat/  tt0257076
#
#      original_language
# 22                  en
# 40                  en
# 46                  en
# 60                  en
# 69                  en
# ...                ...
# 2904                en
# 2927                en
# 2938                en
# 2968                en
# 2984                en
#
# [203 rows x 3 columns]

# %%
"""fetch 'popularity', 'poster_path', 'production_companies',
       'production_countries', 'release_date', 'runtime' """
data.iloc[:,9:15]
# In iloc end value is not included during slicing
# In loc end value is included during slicing
# Out:
#       popularity                       poster_path  \
# 22      7.820787  /yo49x6Jhr1ecCjy1ByFqwAbtARJ.jpg
# 40      2.941626  /1Kqwllyvr4n3rLMvH2K17bavxT3.jpg
# 46     16.646029  /isRuztu5Ch7FJdtSBLcG8QSOpEI.jpg
# 60     23.065078  /zlWBxz2pTA9p45kUTrI8AQiKrHm.jpg
# 69      2.238808  /f9V0iTSYwnxW6tPIjSE7jrGC7eP.jpg
# ...          ...                               ...
# 2904   19.348466  /p1O3eFsdb0GEIYu87xlwV7P4jM1.jpg
# 2927   12.996474  /1iUZqUXS7x5FcGM5J0u01xuObWC.jpg
# 2938   16.624854  /ng8ALjSDhUmwLl7vtjUWIZNQSlt.jpg
# 2968    6.514132  /qCrvpGxWjOh7tVLxyqWLR65ZuWX.jpg
# 2984   13.334952  /AgwobKKS20WRaQCHj5ut2R4KyHa.jpg
#
#                                    production_companies  \
# 22    [{'name': 'The Collective', 'id': 15156}, {'na...
# 40                   [{'name': 'Rakontur', 'id': 6303}]
# 46    [{'name': 'Blue Sky Studios', 'id': 9383}, {'n...
# 60    [{'name': 'Eon Productions', 'id': 7576}, {'na...
# 69           [{'name': 'Universal Pictures', 'id': 33}]
# ...                                                 ...
# 2904  [{'name': 'Miramax Films', 'id': 14}, {'name':...
# 2927          [{'name': 'Eon Productions', 'id': 7576}]
# 2938  [{'name': 'Twentieth Century Fox Film Corporat...
# 2968                 [{'name': 'Boll KG', 'id': 15127}]
# 2984  [{'name': 'Original Film', 'id': 333}, {'name'...
#
#                                    production_countries release_date  runtime
# 22    [{'iso_3166_1': 'US', 'name': 'United States o...      7/28/12    116.0
# 40    [{'iso_3166_1': 'US', 'name': 'United States o...      4/26/06    118.0
# 46    [{'iso_3166_1': 'US', 'name': 'United States o...      3/23/06     91.0
# 60    [{'iso_3166_1': 'IT', 'name': 'Italy'}, {'iso_...     11/14/06    144.0
# 69    [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...       6/3/06    104.0
# ...                                                 ...          ...      ...
# 2904   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]      2/23/96     93.0
# 2927  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...     11/17/02    133.0
# 2938  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...      5/30/12    124.0
# 2968  [{'iso_3166_1': 'US', 'name': 'United States o...     10/22/05     95.0
# 2984  [{'iso_3166_1': 'US', 'name': 'United States o...       8/8/03    117.0
#
# [203 rows x 6 columns]

# %%
data.iloc[:,9:15]
# Out:
#       popularity                       poster_path  \
# 22      7.820787  /yo49x6Jhr1ecCjy1ByFqwAbtARJ.jpg
# 40      2.941626  /1Kqwllyvr4n3rLMvH2K17bavxT3.jpg
# 46     16.646029  /isRuztu5Ch7FJdtSBLcG8QSOpEI.jpg
# 60     23.065078  /zlWBxz2pTA9p45kUTrI8AQiKrHm.jpg
# 69      2.238808  /f9V0iTSYwnxW6tPIjSE7jrGC7eP.jpg
# ...          ...                               ...
# 2904   19.348466  /p1O3eFsdb0GEIYu87xlwV7P4jM1.jpg
# 2927   12.996474  /1iUZqUXS7x5FcGM5J0u01xuObWC.jpg
# 2938   16.624854  /ng8ALjSDhUmwLl7vtjUWIZNQSlt.jpg
# 2968    6.514132  /qCrvpGxWjOh7tVLxyqWLR65ZuWX.jpg
# 2984   13.334952  /AgwobKKS20WRaQCHj5ut2R4KyHa.jpg
#
#                                    production_companies  \
# 22    [{'name': 'The Collective', 'id': 15156}, {'na...
# 40                   [{'name': 'Rakontur', 'id': 6303}]
# 46    [{'name': 'Blue Sky Studios', 'id': 9383}, {'n...
# 60    [{'name': 'Eon Productions', 'id': 7576}, {'na...
# 69           [{'name': 'Universal Pictures', 'id': 33}]
# ...                                                 ...
# 2904  [{'name': 'Miramax Films', 'id': 14}, {'name':...
# 2927          [{'name': 'Eon Productions', 'id': 7576}]
# 2938  [{'name': 'Twentieth Century Fox Film Corporat...
# 2968                 [{'name': 'Boll KG', 'id': 15127}]
# 2984  [{'name': 'Original Film', 'id': 333}, {'name'...
#
#                                    production_countries release_date  runtime
# 22    [{'iso_3166_1': 'US', 'name': 'United States o...      7/28/12    116.0
# 40    [{'iso_3166_1': 'US', 'name': 'United States o...      4/26/06    118.0
# 46    [{'iso_3166_1': 'US', 'name': 'United States o...      3/23/06     91.0
# 60    [{'iso_3166_1': 'IT', 'name': 'Italy'}, {'iso_...     11/14/06    144.0
# 69    [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...       6/3/06    104.0
# ...                                                 ...          ...      ...
# 2904   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]      2/23/96     93.0
# 2927  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...     11/17/02    133.0
# 2938  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...      5/30/12    124.0
# 2968  [{'iso_3166_1': 'US', 'name': 'United States o...     10/22/05     95.0
# 2984  [{'iso_3166_1': 'US', 'name': 'United States o...       8/8/03    117.0
#
# [203 rows x 6 columns]

# %%
# fetch first row using iloc
data.iloc[[0],:]
# Out:
#     id                              belongs_to_collection  budget  \
# 22  23  [{'id': 207621, 'name': 'V/H/S Collection', 'p...       0
#
#                                                genres  \
# 22  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
#
#                                homepage    imdb_id original_language  \
# 22  http://www.magnetreleasing.com/vhs/  tt2105044                en
#
#    original_title                                           overview  \
# 22          V/H/S  When a group of misfits is hired by an unknown...
#
#     popularity  ... release_date runtime  \
# 22    7.820787  ...      7/28/12   116.0
#
#                             spoken_languages    status  \
# 22  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                        tagline  title  \
# 22  This collection is killer.  V/H/S
#
#                                              Keywords  \
# 22  [{'id': 6435, 'name': 'webcam'}, {'id': 9706, ...
#
#                                                  cast  \
# 22  [{'cast_id': 1, 'character': 'Gary', 'credit_i...
#
#                                                  crew revenue
# 22  [{'credit_id': '52fe48ee9251416c9109d113', 'de...  100345
#
# [1 rows x 23 columns]

# %%
# fetch first 10 rows using iloc
data.iloc[0:9 , :]
# Out:
#       id                              belongs_to_collection     budget  \
# 22    23  [{'id': 207621, 'name': 'V/H/S Collection', 'p...          0
# 40    41  [{'id': 376970, 'name': 'Cocaine Cowboys', 'po...          0
# 46    47  [{'id': 8354, 'name': 'Ice Age Collection', 'p...   80000000
# 60    61  [{'id': 645, 'name': 'James Bond Collection', ...  150000000
# 69    70  [{'id': 9485, 'name': 'The Fast and the Furiou...   85000000
# 75    76  [{'id': 230161, 'name': 'Fright Night (Reboot)...   17000000
# 90    91  [{'id': 2883, 'name': 'Kill Bill Collection', ...   30000000
# 114  115  [{'id': 119, 'name': 'The Lord of the Rings Co...   93000000
# 121  122  [{'id': 106768, 'name': 'Tarzan (Animation) Co...  150000000
#
#                                                 genres  \
# 22   [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 40   [{'id': 28, 'name': 'Action'}, {'id': 99, 'nam...
# 46   [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 60   [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 69   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 75   [{'id': 27, 'name': 'Horror'}, {'id': 35, 'nam...
# 90   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 114  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 121  [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
#
#                                               homepage    imdb_id  \
# 22                 http://www.magnetreleasing.com/vhs/  tt2105044
# 40   http://www.magpictures.com/profile.aspx?id=983...  tt0380268
# 46   http://www.iceagemovies.com/films/ice-age-the-...  tt0438097
# 60   http://www.mgm.com/#/our-titles/233/Casino-Roy...  tt0381061
# 69               http://www.thefastandthefurious3.com/  tt0463985
# 75                 http://www.welcometofrightnight.com  tt1438176
# 90    http://www.miramax.com/movie/kill-bill-volume-1/  tt0266697
# 114                     http://www.lordoftherings.net/  tt0120737
# 121  http://disneydvd.disney.go.com/tarzanr-special...  tt0120855
#
#     original_language                                     original_title  \
# 22                 en                                              V/H/S
# 40                 en                                    Cocaine Cowboys
# 46                 en                              Ice Age: The Meltdown
# 60                 en                                      Casino Royale
# 69                 en              The Fast and the Furious: Tokyo Drift
# 75                 en                                       Fright Night
# 90                 en                                  Kill Bill: Vol. 1
# 114                en  The Lord of the Rings: The Fellowship of the Ring
# 121                en                                             Tarzan
#
#                                               overview  popularity  ...  \
# 22   When a group of misfits is hired by an unknown...    7.820787  ...
# 40   In the 1980s, ruthless Colombian cocaine baron...    2.941626  ...
# 46   Diego, Manny and Sid return in this sequel to ...   16.646029  ...
# 60   Le Chiffre, a banker to the world's terrorists...   23.065078  ...
# 69   In order to avoid a jail sentence, Sean Boswel...    2.238808  ...
# 75   A teenager suspects his new neighbour is a vam...    9.665251  ...
# 90   An assassin is shot at the altar by her ruthle...   25.261865  ...
# 114  Young hobbit Frodo Baggins, after inheriting a...   32.070725  ...
# 121  Tarzan was a small orphan who was raised by an...   12.453452  ...
#
#     release_date runtime                                   spoken_languages  \
# 22       7/28/12   116.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 40       4/26/06   118.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 46       3/23/06    91.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 60      11/14/06   144.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 69        6/3/06   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 75       8/18/11   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 90      10/10/03   111.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 114     12/18/01   178.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 121      6/18/99    88.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#        status                                            tagline  \
# 22   Released                         This collection is killer.
# 40   Released  How Miami became the cocaine capital of the Un...
# 46   Released                       The Ice age is melting away.
# 60   Released  Everyone has a past. Every legend has a beginn...
# 69   Released  On the streets of Tokyo, speed needs no transl...
# 75   Released   You can't run from evil when it lives next door.
# 90   Released                                   Go for the kill.
# 114  Released                          One ring to rule them all
# 121  Released       An immortal legend. As you've only imagined.
#
#                                                  title  \
# 22                                               V/H/S
# 40                                     Cocaine Cowboys
# 46                               Ice Age: The Meltdown
# 60                                       Casino Royale
# 69               The Fast and the Furious: Tokyo Drift
# 75                                        Fright Night
# 90                                   Kill Bill: Vol. 1
# 114  The Lord of the Rings: The Fellowship of the Ring
# 121                                             Tarzan
#
#                                               Keywords  \
# 22   [{'id': 6435, 'name': 'webcam'}, {'id': 9706, ...
# 40   [{'id': 2150, 'name': 'cocaine'}, {'id': 2231,...
# 46   [{'id': 2078, 'name': 'mammoth'}, {'id': 2079,...
# 60   [{'id': 131, 'name': 'italy'}, {'id': 383, 'na...
# 69   [{'id': 830, 'name': 'car race'}, {'id': 1926,...
# 75   [{'id': 813, 'name': 'sunrise'}, {'id': 3133, ...
# 90   [{'id': 233, 'name': 'japan'}, {'id': 732, 'na...
# 114  [{'id': 603, 'name': 'elves'}, {'id': 604, 'na...
# 121  [{'id': 690, 'name': 'gorilla'}, {'id': 1009, ...
#
#                                                   cast  \
# 22   [{'cast_id': 1, 'character': 'Gary', 'credit_i...
# 40   [{'cast_id': 2, 'character': 'Himself', 'credi...
# 46   [{'cast_id': 1, 'character': 'Manny (voice)', ...
# 60   [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 69   [{'cast_id': 12, 'character': 'Sean Boswell', ...
# 75   [{'cast_id': 9, 'character': 'Charley Brewster...
# 90   [{'cast_id': 3, 'character': "Beatrix 'The Bri...
# 114  [{'cast_id': 28, 'character': 'Frodo Baggins',...
# 121  [{'cast_id': 9, 'character': 'Tarzan', 'credit...
#
#                                                   crew    revenue
# 22   [{'credit_id': '52fe48ee9251416c9109d113', 'de...     100345
# 40   [{'credit_id': '52fe46179251416c7506cc15', 'de...     163000
# 46   [{'credit_id': '52fe4292c3a36847f80292c9', 'de...  660940780
# 60   [{'credit_id': '53ac1fd7c3a3684bc8001908', 'de...  599045960
# 69   [{'credit_id': '56784ed792514111900002c8', 'de...  158468292
# 75   [{'credit_id': '52fe4956c3a36847f8194f53', 'de...   24922237
# 90   [{'credit_id': '52fe4210c3a36847f8001049', 'de...  180949000
# 114  [{'credit_id': '52fe421ac3a36847f80043ef', 'de...  871368364
# 121  [{'credit_id': '5912c9a19251414e8005140a', 'de...  448000000
#
# [9 rows x 23 columns]

# %%
# fetch first 3rd , 4th and 6th row
data.iloc[[2,3,5],:]
# Out:
#     id                              belongs_to_collection     budget  \
# 46  47  [{'id': 8354, 'name': 'Ice Age Collection', 'p...   80000000
# 60  61  [{'id': 645, 'name': 'James Bond Collection', ...  150000000
# 75  76  [{'id': 230161, 'name': 'Fright Night (Reboot)...   17000000
#
#                                                genres  \
# 46  [{'id': 16, 'name': 'Animation'}, {'id': 10751...
# 60  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 75  [{'id': 27, 'name': 'Horror'}, {'id': 35, 'nam...
#
#                                              homepage    imdb_id  \
# 46  http://www.iceagemovies.com/films/ice-age-the-...  tt0438097
# 60  http://www.mgm.com/#/our-titles/233/Casino-Roy...  tt0381061
# 75                http://www.welcometofrightnight.com  tt1438176
#
#    original_language         original_title  \
# 46                en  Ice Age: The Meltdown
# 60                en          Casino Royale
# 75                en           Fright Night
#
#                                              overview  popularity  ...  \
# 46  Diego, Manny and Sid return in this sequel to ...   16.646029  ...
# 60  Le Chiffre, a banker to the world's terrorists...   23.065078  ...
# 75  A teenager suspects his new neighbour is a vam...    9.665251  ...
#
#    release_date runtime                                   spoken_languages  \
# 46      3/23/06    91.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 60     11/14/06   144.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 75      8/18/11   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#       status                                            tagline  \
# 46  Released                       The Ice age is melting away.
# 60  Released  Everyone has a past. Every legend has a beginn...
# 75  Released   You can't run from evil when it lives next door.
#
#                     title                                           Keywords  \
# 46  Ice Age: The Meltdown  [{'id': 2078, 'name': 'mammoth'}, {'id': 2079,...
# 60          Casino Royale  [{'id': 131, 'name': 'italy'}, {'id': 383, 'na...
# 75           Fright Night  [{'id': 813, 'name': 'sunrise'}, {'id': 3133, ...
#
#                                                  cast  \
# 46  [{'cast_id': 1, 'character': 'Manny (voice)', ...
# 60  [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 75  [{'cast_id': 9, 'character': 'Charley Brewster...
#
#                                                  crew    revenue
# 46  [{'credit_id': '52fe4292c3a36847f80292c9', 'de...  660940780
# 60  [{'credit_id': '53ac1fd7c3a3684bc8001908', 'de...  599045960
# 75  [{'credit_id': '52fe4956c3a36847f8194f53', 'de...   24922237
#
# [3 rows x 23 columns]

# %%
# fetch 1st , 2nd , 3rd row and budget , genre columns
data.iloc[0:2 ,2:4]
# Out:
#     budget                                             genres
# 22       0  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 40       0  [{'id': 28, 'name': 'Action'}, {'id': 99, 'nam...

# %% [markdown]
# ### **Unique**
# unique() is a function used to identify and return the distinct values within a Series or a DataFrame column. It provides a quick way to see all unique entries.

# %%
# find distinct original_languages
data.loc[:,'original_language'].unique()
# Out:
# array(['en', 'ja', 'es', 'fr', 'no', 'ko', 'zh', 'sv', 'cn', 'ru', 'id'],
#       dtype=object)

# %%
# find distinct values in status
data.loc[:,'status'].unique()
# Out:
# array(['Released'], dtype=object)

# %% [markdown]
# # **Value_counts**
# Counts the occurrences of each unique value in a Series or DataFrame column, returning a Series with values and their counts in descending order.

# %%
# find count of movies w.r.t to each original_langauge
data.loc[:,'original_language'].value_counts()
# Out:
# original_language
# en    186
# ja      5
# es      3
# no      2
# fr      1
# ko      1
# zh      1
# sv      1
# cn      1
# ru      1
# id      1
# Name: count, dtype: int64

# %%
# find count of categories in status
data.loc[:,'status'].value_counts()
# Out:
# status
# Released    203
# Name: count, dtype: int64

# %%
'''What are the counts of unique combinations of 'original_language'
 and 'status' in the DataFrame?'''

data.loc[:,['original_language','status']].value_counts()
# Out:
# original_language  status
# en                 Released    186
# ja                 Released      5
# es                 Released      3
# no                 Released      2
# cn                 Released      1
# id                 Released      1
# fr                 Released      1
# ko                 Released      1
# ru                 Released      1
# sv                 Released      1
# zh                 Released      1
# Name: count, dtype: int64

# %%
# check type
type(data.loc[:,'status'].value_counts())
# Type of this output is series
# Out:
# pandas.core.series.Series

# %%
# how to convert series output into dataframe
data.loc[:,'status'].value_counts().reset_index()
#If you want to convert this Series back into a clean DataFrame, reset_index() comes in handy.
# Out:
#      status  count
# 0  Released    203

# %%
type(data.loc[:, 'status'].value_counts().reset_index())
# Out:
# pandas.core.frame.DataFrame

# %%
'''What are the counts of unique combinations of 'production_countries'
 and 'status'''
type(data.loc[:,['production_countries','status']].value_counts())
# Out:
# pandas.core.series.Series

# %%
'''What are the counts of unique combinations of 'popularity'
 and 'status'''
data.loc[:,['popularity','status']].value_counts().reset_index()
# Columns to be considered for Value_counts() should be Categorical | Object Dtype
# Out:
#      popularity    status  count
# 0      0.452934  Released      1
# 1      0.749665  Released      1
# 2      0.948759  Released      1
# 3      1.456541  Released      1
# 4      1.498902  Released      1
# ..          ...       ...    ...
# 198   89.887648  Released      1
# 199  123.167259  Released      1
# 200  146.161786  Released      1
# 201  185.330992  Released      1
# 202  187.860492  Released      1
#
# [203 rows x 3 columns]

# %% [markdown]
# # **Sort**
# Sorting is the process of arranging data in a specific order, typically ascending or descending. In data analysis, sorting helps organize data by one or more criteria, making it easier to view, analyze, and find specific information.
#
# ### **syntax**
# DataFrame.sort_values(by='column_name', ascending=True)
# *  by: The column(s) to sort by.
# * ascending: Sort order; True for ascending (default) and False for descending.

# %% [markdown]
# **Sort data in increasing order of revenue**

# %%
data.sort_values('revenue')
# By default it will sort in increasing order which is not permanent change
# By default ascending=True which sorts in increasing order
# Out:
#         id                              belongs_to_collection     budget  \
# 665    666  [{'id': 86668, 'name': 'Elektra Luxx Collectio...          0
# 1563  1564  [{'id': 87186, 'name': 'The Boondock Saints Co...    6000000
# 1499  1500  [{'id': 473843, 'name': 'Stake Land Collection...     650000
# 2276  2277  [{'id': 286038, 'name': 'Dead Snow Collection'...          0
# 514    515  [{'id': 206559, 'name': 'StreetDance Collectio...          0
# ...    ...                                                ...        ...
# 2135  2136  [{'id': 295, 'name': 'Pirates of the Caribbean...  380000000
# 2322  2323  [{'id': 8650, 'name': 'Transformers Collection...  195000000
# 2770  2771  [{'id': 86311, 'name': 'The Avengers Collectio...  280000000
# 1761  1762  [{'id': 9485, 'name': 'The Fast and the Furiou...  190000000
# 1126  1127  [{'id': 86311, 'name': 'The Avengers Collectio...  220000000
#
#                                                  genres  \
# 665   [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 1563  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 1499  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 2276  [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
# 514   [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# ...                                                 ...
# 2135  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 2322  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 2770  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 1761                     [{'id': 28, 'name': 'Action'}]
# 1126  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
#
#                                                homepage    imdb_id  \
# 665                   http://www.elektraluxx-movie.com/  tt1340773
# 1563                   http://www.theboondocksaints.com  tt0144117
# 1499                   http://www.stakelandthefilm.com/  tt1464580
# 2276                           http://www.deadsnow.com/  tt2832470
# 514                  http://www.highstrungthemovie.com/  tt3451230
# ...                                                 ...        ...
# 2135  http://disney.go.com/pirates/index-on-stranger...  tt1298650
# 2322                  http://www.transformersmovie.com/  tt1399103
# 2770  http://marvel.com/movies/movie/193/avengers_ag...  tt2395427
# 1761                           http://www.furious7.com/  tt2820852
# 1126                  http://marvel.com/avengers_movie/  tt0848228
#
#      original_language                               original_title  \
# 665                 en                                 Elektra Luxx
# 1563                en                          The Boondock Saints
# 1499                en                                   Stake Land
# 2276                no                                    Død Snø 2
# 514                 en                                  High Strung
# ...                ...                                          ...
# 2135                en  Pirates of the Caribbean: On Stranger Tides
# 2322                en               Transformers: Dark of the Moon
# 2770                en                      Avengers: Age of Ultron
# 1761                en                                    Furious 7
# 1126                en                                 The Avengers
#
#                                                overview  popularity  ...  \
# 665   A favor for a woman from her past throws the l...    4.118699  ...
# 1563  With a God-inspired moral obligation to act ag...   12.457908  ...
# 1499  Martin was a normal teenage boy before the cou...    7.814255  ...
# 2276  The gruesome Nazi Zombies are back to finish t...   10.287127  ...
# 514   When a hip hop violinist busking in the New Yo...    6.625607  ...
# ...                                                 ...         ...  ...
# 2135  Captain Jack Sparrow crosses paths with a woma...   27.887720  ...
# 2322  Sam Witwicky takes his first tenuous steps int...    4.503505  ...
# 2770  When Tony Stark tries to jumpstart a dormant p...   37.379420  ...
# 1761  Deckard Shaw seeks revenge against Dominic Tor...   27.275687  ...
# 1126  When an unexpected enemy emerges and threatens...   89.887648  ...
#
#      release_date runtime                                   spoken_languages  \
# 665       3/14/10    98.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1563      1/22/99   108.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 1499      9/30/10    98.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2276      2/12/14   100.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 514        4/8/16    96.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ...           ...     ...                                                ...
# 2135      5/14/11   136.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2322      6/28/11   154.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2770      4/22/15   141.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1761       4/1/15   137.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1126      4/25/12   143.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#         status                                            tagline  \
# 665   Released         From adult film star to functioning adult.
# 1563  Released                Thy Kingdom Come. Thy Will Be Done.
# 1499  Released           The Most Dangerous Thing Is To Be Alive.
# 2276  Released                            Heads up. They're back.
# 514   Released                     See the music. Hear the dance.
# ...        ...                                                ...
# 2135  Released                        Live Forever Or Die Trying.
# 2322  Released  The invasion we always feared. An enemy we nev...
# 2770  Released                                A New Age Has Come.
# 1761  Released                                Vengeance Hits Home
# 1126  Released                            Some assembly required.
#
#                                             title  \
# 665                                  Elektra Luxx
# 1563                          The Boondock Saints
# 1499                                   Stake Land
# 2276                    Dead Snow 2: Red vs. Dead
# 514                                   High Strung
# ...                                           ...
# 2135  Pirates of the Caribbean: On Stranger Tides
# 2322               Transformers: Dark of the Moon
# 2770                      Avengers: Age of Ultron
# 1761                                    Furious 7
# 1126                                 The Avengers
#
#                                                Keywords  \
# 665   [{'id': 10183, 'name': 'independent film'}, {'...
# 1563  [{'id': 1679, 'name': 'arbitrary law'}, {'id':...
# 1499  [{'id': 255, 'name': 'male nudity'}, {'id': 13...
# 2276  [{'id': 2652, 'name': 'nazis'}, {'id': 9663, '...
# 514   [{'id': 1691, 'name': 'dance'}, {'id': 4721, '...
# ...                                                 ...
# 2135  [{'id': 658, 'name': 'sea'}, {'id': 1316, 'nam...
# 2322  [{'id': 305, 'name': 'moon'}, {'id': 1612, 'na...
# 2770  [{'id': 8828, 'name': 'marvel comic'}, {'id': ...
# 1761  [{'id': 830, 'name': 'car race'}, {'id': 3428,...
# 1126  [{'id': 242, 'name': 'new york'}, {'id': 5539,...
#
#                                                    cast  \
# 665   [{'cast_id': 3, 'character': 'Elektra Luxx', '...
# 1563  [{'cast_id': 1, 'character': 'Paul Smecker', '...
# 1499  [{'cast_id': 2, 'character': 'Belle', 'credit_...
# 2276  [{'cast_id': 19, 'character': 'Martin', 'credi...
# 514   [{'cast_id': 3, 'character': 'Ruby', 'credit_i...
# ...                                                 ...
# 2135  [{'cast_id': 15, 'character': 'Captain Jack Sp...
# 2322  [{'cast_id': 3, 'character': 'Sam Witwicky', '...
# 2770  [{'cast_id': 76, 'character': 'Tony Stark / Ir...
# 1761  [{'cast_id': 17, 'character': 'Dominic Toretto...
# 1126  [{'cast_id': 46, 'character': 'Tony Stark / Ir...
#
#                                                    crew     revenue
# 665   [{'credit_id': '52fe48f6c3a36847f818264f', 'de...          10
# 1563  [{'credit_id': '52fe44a3c3a36847f80a1a91', 'de...       30471
# 1499  [{'credit_id': '537483fcc3a36815180026ee', 'de...       33245
# 2276  [{'credit_id': '52fe4ebfc3a36847f82a57f3', 'de...       37473
# 514   [{'credit_id': '56be2f489251417359004545', 'de...       53447
# ...                                                 ...         ...
# 2135  [{'credit_id': '566b4f54c3a3683f56005151', 'de...  1045713802
# 2322  [{'credit_id': '537f0b740e0a2624b40044d0', 'de...  1123746996
# 2770  [{'credit_id': '55d5f7d4c3a3683e7e0016eb', 'de...  1405403694
# 1761  [{'credit_id': '52fe4cc8c3a36847f823e681', 'de...  1506249360
# 1126  [{'credit_id': '52fe4495c3a368484e02b1cf', 'de...  1519557910
#
# [203 rows x 23 columns]

# %% [markdown]
# **Sort data in decreasing order of revenue**

# %%
data.sort_values('revenue',ascending=False)
# By default ascending=True which sorts in increasing order
# Set ascending=False to sort in decreasing order
# Out:
#         id                              belongs_to_collection     budget  \
# 1126  1127  [{'id': 86311, 'name': 'The Avengers Collectio...  220000000
# 1761  1762  [{'id': 9485, 'name': 'The Fast and the Furiou...  190000000
# 2770  2771  [{'id': 86311, 'name': 'The Avengers Collectio...  280000000
# 2322  2323  [{'id': 8650, 'name': 'Transformers Collection...  195000000
# 2135  2136  [{'id': 295, 'name': 'Pirates of the Caribbean...  380000000
# ...    ...                                                ...        ...
# 514    515  [{'id': 206559, 'name': 'StreetDance Collectio...          0
# 2276  2277  [{'id': 286038, 'name': 'Dead Snow Collection'...          0
# 1499  1500  [{'id': 473843, 'name': 'Stake Land Collection...     650000
# 1563  1564  [{'id': 87186, 'name': 'The Boondock Saints Co...    6000000
# 665    666  [{'id': 86668, 'name': 'Elektra Luxx Collectio...          0
#
#                                                  genres  \
# 1126  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1761                     [{'id': 28, 'name': 'Action'}]
# 2770  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2322  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 2135  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# ...                                                 ...
# 514   [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2276  [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
# 1499  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 1563  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 665   [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
#
#                                                homepage    imdb_id  \
# 1126                  http://marvel.com/avengers_movie/  tt0848228
# 1761                           http://www.furious7.com/  tt2820852
# 2770  http://marvel.com/movies/movie/193/avengers_ag...  tt2395427
# 2322                  http://www.transformersmovie.com/  tt1399103
# 2135  http://disney.go.com/pirates/index-on-stranger...  tt1298650
# ...                                                 ...        ...
# 514                  http://www.highstrungthemovie.com/  tt3451230
# 2276                           http://www.deadsnow.com/  tt2832470
# 1499                   http://www.stakelandthefilm.com/  tt1464580
# 1563                   http://www.theboondocksaints.com  tt0144117
# 665                   http://www.elektraluxx-movie.com/  tt1340773
#
#      original_language                               original_title  \
# 1126                en                                 The Avengers
# 1761                en                                    Furious 7
# 2770                en                      Avengers: Age of Ultron
# 2322                en               Transformers: Dark of the Moon
# 2135                en  Pirates of the Caribbean: On Stranger Tides
# ...                ...                                          ...
# 514                 en                                  High Strung
# 2276                no                                    Død Snø 2
# 1499                en                                   Stake Land
# 1563                en                          The Boondock Saints
# 665                 en                                 Elektra Luxx
#
#                                                overview  popularity  ...  \
# 1126  When an unexpected enemy emerges and threatens...   89.887648  ...
# 1761  Deckard Shaw seeks revenge against Dominic Tor...   27.275687  ...
# 2770  When Tony Stark tries to jumpstart a dormant p...   37.379420  ...
# 2322  Sam Witwicky takes his first tenuous steps int...    4.503505  ...
# 2135  Captain Jack Sparrow crosses paths with a woma...   27.887720  ...
# ...                                                 ...         ...  ...
# 514   When a hip hop violinist busking in the New Yo...    6.625607  ...
# 2276  The gruesome Nazi Zombies are back to finish t...   10.287127  ...
# 1499  Martin was a normal teenage boy before the cou...    7.814255  ...
# 1563  With a God-inspired moral obligation to act ag...   12.457908  ...
# 665   A favor for a woman from her past throws the l...    4.118699  ...
#
#      release_date runtime                                   spoken_languages  \
# 1126      4/25/12   143.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1761       4/1/15   137.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2770      4/22/15   141.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2322      6/28/11   154.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2135      5/14/11   136.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# ...           ...     ...                                                ...
# 514        4/8/16    96.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2276      2/12/14   100.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 1499      9/30/10    98.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1563      1/22/99   108.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 665       3/14/10    98.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#         status                                            tagline  \
# 1126  Released                            Some assembly required.
# 1761  Released                                Vengeance Hits Home
# 2770  Released                                A New Age Has Come.
# 2322  Released  The invasion we always feared. An enemy we nev...
# 2135  Released                        Live Forever Or Die Trying.
# ...        ...                                                ...
# 514   Released                     See the music. Hear the dance.
# 2276  Released                            Heads up. They're back.
# 1499  Released           The Most Dangerous Thing Is To Be Alive.
# 1563  Released                Thy Kingdom Come. Thy Will Be Done.
# 665   Released         From adult film star to functioning adult.
#
#                                             title  \
# 1126                                 The Avengers
# 1761                                    Furious 7
# 2770                      Avengers: Age of Ultron
# 2322               Transformers: Dark of the Moon
# 2135  Pirates of the Caribbean: On Stranger Tides
# ...                                           ...
# 514                                   High Strung
# 2276                    Dead Snow 2: Red vs. Dead
# 1499                                   Stake Land
# 1563                          The Boondock Saints
# 665                                  Elektra Luxx
#
#                                                Keywords  \
# 1126  [{'id': 242, 'name': 'new york'}, {'id': 5539,...
# 1761  [{'id': 830, 'name': 'car race'}, {'id': 3428,...
# 2770  [{'id': 8828, 'name': 'marvel comic'}, {'id': ...
# 2322  [{'id': 305, 'name': 'moon'}, {'id': 1612, 'na...
# 2135  [{'id': 658, 'name': 'sea'}, {'id': 1316, 'nam...
# ...                                                 ...
# 514   [{'id': 1691, 'name': 'dance'}, {'id': 4721, '...
# 2276  [{'id': 2652, 'name': 'nazis'}, {'id': 9663, '...
# 1499  [{'id': 255, 'name': 'male nudity'}, {'id': 13...
# 1563  [{'id': 1679, 'name': 'arbitrary law'}, {'id':...
# 665   [{'id': 10183, 'name': 'independent film'}, {'...
#
#                                                    cast  \
# 1126  [{'cast_id': 46, 'character': 'Tony Stark / Ir...
# 1761  [{'cast_id': 17, 'character': 'Dominic Toretto...
# 2770  [{'cast_id': 76, 'character': 'Tony Stark / Ir...
# 2322  [{'cast_id': 3, 'character': 'Sam Witwicky', '...
# 2135  [{'cast_id': 15, 'character': 'Captain Jack Sp...
# ...                                                 ...
# 514   [{'cast_id': 3, 'character': 'Ruby', 'credit_i...
# 2276  [{'cast_id': 19, 'character': 'Martin', 'credi...
# 1499  [{'cast_id': 2, 'character': 'Belle', 'credit_...
# 1563  [{'cast_id': 1, 'character': 'Paul Smecker', '...
# 665   [{'cast_id': 3, 'character': 'Elektra Luxx', '...
#
#                                                    crew     revenue
# 1126  [{'credit_id': '52fe4495c3a368484e02b1cf', 'de...  1519557910
# 1761  [{'credit_id': '52fe4cc8c3a36847f823e681', 'de...  1506249360
# 2770  [{'credit_id': '55d5f7d4c3a3683e7e0016eb', 'de...  1405403694
# 2322  [{'credit_id': '537f0b740e0a2624b40044d0', 'de...  1123746996
# 2135  [{'credit_id': '566b4f54c3a3683f56005151', 'de...  1045713802
# ...                                                 ...         ...
# 514   [{'credit_id': '56be2f489251417359004545', 'de...       53447
# 2276  [{'credit_id': '52fe4ebfc3a36847f82a57f3', 'de...       37473
# 1499  [{'credit_id': '537483fcc3a36815180026ee', 'de...       33245
# 1563  [{'credit_id': '52fe44a3c3a36847f80a1a91', 'de...       30471
# 665   [{'credit_id': '52fe48f6c3a36847f818264f', 'de...          10
#
# [203 rows x 23 columns]

# %%
# sort data according revennue in ascending
data.sort_values('revenue',ignore_index=True)
# ignore_index=True  : It will not change index values
# Out:
#        id                              belongs_to_collection     budget  \
# 0     666  [{'id': 86668, 'name': 'Elektra Luxx Collectio...          0
# 1    1564  [{'id': 87186, 'name': 'The Boondock Saints Co...    6000000
# 2    1500  [{'id': 473843, 'name': 'Stake Land Collection...     650000
# 3    2277  [{'id': 286038, 'name': 'Dead Snow Collection'...          0
# 4     515  [{'id': 206559, 'name': 'StreetDance Collectio...          0
# ..    ...                                                ...        ...
# 198  2136  [{'id': 295, 'name': 'Pirates of the Caribbean...  380000000
# 199  2323  [{'id': 8650, 'name': 'Transformers Collection...  195000000
# 200  2771  [{'id': 86311, 'name': 'The Avengers Collectio...  280000000
# 201  1762  [{'id': 9485, 'name': 'The Fast and the Furiou...  190000000
# 202  1127  [{'id': 86311, 'name': 'The Avengers Collectio...  220000000
#
#                                                 genres  \
# 0    [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 1    [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 2    [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 3    [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
# 4    [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# ..                                                 ...
# 198  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 199  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 200  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 201                     [{'id': 28, 'name': 'Action'}]
# 202  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
#
#                                               homepage    imdb_id  \
# 0                    http://www.elektraluxx-movie.com/  tt1340773
# 1                     http://www.theboondocksaints.com  tt0144117
# 2                     http://www.stakelandthefilm.com/  tt1464580
# 3                             http://www.deadsnow.com/  tt2832470
# 4                   http://www.highstrungthemovie.com/  tt3451230
# ..                                                 ...        ...
# 198  http://disney.go.com/pirates/index-on-stranger...  tt1298650
# 199                  http://www.transformersmovie.com/  tt1399103
# 200  http://marvel.com/movies/movie/193/avengers_ag...  tt2395427
# 201                           http://www.furious7.com/  tt2820852
# 202                  http://marvel.com/avengers_movie/  tt0848228
#
#     original_language                               original_title  \
# 0                  en                                 Elektra Luxx
# 1                  en                          The Boondock Saints
# 2                  en                                   Stake Land
# 3                  no                                    Død Snø 2
# 4                  en                                  High Strung
# ..                ...                                          ...
# 198                en  Pirates of the Caribbean: On Stranger Tides
# 199                en               Transformers: Dark of the Moon
# 200                en                      Avengers: Age of Ultron
# 201                en                                    Furious 7
# 202                en                                 The Avengers
#
#                                               overview  popularity  ...  \
# 0    A favor for a woman from her past throws the l...    4.118699  ...
# 1    With a God-inspired moral obligation to act ag...   12.457908  ...
# 2    Martin was a normal teenage boy before the cou...    7.814255  ...
# 3    The gruesome Nazi Zombies are back to finish t...   10.287127  ...
# 4    When a hip hop violinist busking in the New Yo...    6.625607  ...
# ..                                                 ...         ...  ...
# 198  Captain Jack Sparrow crosses paths with a woma...   27.887720  ...
# 199  Sam Witwicky takes his first tenuous steps int...    4.503505  ...
# 200  When Tony Stark tries to jumpstart a dormant p...   37.379420  ...
# 201  Deckard Shaw seeks revenge against Dominic Tor...   27.275687  ...
# 202  When an unexpected enemy emerges and threatens...   89.887648  ...
#
#     release_date runtime                                   spoken_languages  \
# 0        3/14/10    98.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1        1/22/99   108.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2        9/30/10    98.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3        2/12/14   100.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 4         4/8/16    96.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ..           ...     ...                                                ...
# 198      5/14/11   136.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 199      6/28/11   154.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 200      4/22/15   141.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 201       4/1/15   137.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 202      4/25/12   143.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#        status                                            tagline  \
# 0    Released         From adult film star to functioning adult.
# 1    Released                Thy Kingdom Come. Thy Will Be Done.
# 2    Released           The Most Dangerous Thing Is To Be Alive.
# 3    Released                            Heads up. They're back.
# 4    Released                     See the music. Hear the dance.
# ..        ...                                                ...
# 198  Released                        Live Forever Or Die Trying.
# 199  Released  The invasion we always feared. An enemy we nev...
# 200  Released                                A New Age Has Come.
# 201  Released                                Vengeance Hits Home
# 202  Released                            Some assembly required.
#
#                                            title  \
# 0                                   Elektra Luxx
# 1                            The Boondock Saints
# 2                                     Stake Land
# 3                      Dead Snow 2: Red vs. Dead
# 4                                    High Strung
# ..                                           ...
# 198  Pirates of the Caribbean: On Stranger Tides
# 199               Transformers: Dark of the Moon
# 200                      Avengers: Age of Ultron
# 201                                    Furious 7
# 202                                 The Avengers
#
#                                               Keywords  \
# 0    [{'id': 10183, 'name': 'independent film'}, {'...
# 1    [{'id': 1679, 'name': 'arbitrary law'}, {'id':...
# 2    [{'id': 255, 'name': 'male nudity'}, {'id': 13...
# 3    [{'id': 2652, 'name': 'nazis'}, {'id': 9663, '...
# 4    [{'id': 1691, 'name': 'dance'}, {'id': 4721, '...
# ..                                                 ...
# 198  [{'id': 658, 'name': 'sea'}, {'id': 1316, 'nam...
# 199  [{'id': 305, 'name': 'moon'}, {'id': 1612, 'na...
# 200  [{'id': 8828, 'name': 'marvel comic'}, {'id': ...
# 201  [{'id': 830, 'name': 'car race'}, {'id': 3428,...
# 202  [{'id': 242, 'name': 'new york'}, {'id': 5539,...
#
#                                                   cast  \
# 0    [{'cast_id': 3, 'character': 'Elektra Luxx', '...
# 1    [{'cast_id': 1, 'character': 'Paul Smecker', '...
# 2    [{'cast_id': 2, 'character': 'Belle', 'credit_...
# 3    [{'cast_id': 19, 'character': 'Martin', 'credi...
# 4    [{'cast_id': 3, 'character': 'Ruby', 'credit_i...
# ..                                                 ...
# 198  [{'cast_id': 15, 'character': 'Captain Jack Sp...
# 199  [{'cast_id': 3, 'character': 'Sam Witwicky', '...
# 200  [{'cast_id': 76, 'character': 'Tony Stark / Ir...
# 201  [{'cast_id': 17, 'character': 'Dominic Toretto...
# 202  [{'cast_id': 46, 'character': 'Tony Stark / Ir...
#
#                                                   crew     revenue
# 0    [{'credit_id': '52fe48f6c3a36847f818264f', 'de...          10
# 1    [{'credit_id': '52fe44a3c3a36847f80a1a91', 'de...       30471
# 2    [{'credit_id': '537483fcc3a36815180026ee', 'de...       33245
# 3    [{'credit_id': '52fe4ebfc3a36847f82a57f3', 'de...       37473
# 4    [{'credit_id': '56be2f489251417359004545', 'de...       53447
# ..                                                 ...         ...
# 198  [{'credit_id': '566b4f54c3a3683f56005151', 'de...  1045713802
# 199  [{'credit_id': '537f0b740e0a2624b40044d0', 'de...  1123746996
# 200  [{'credit_id': '55d5f7d4c3a3683e7e0016eb', 'de...  1405403694
# 201  [{'credit_id': '52fe4cc8c3a36847f823e681', 'de...  1506249360
# 202  [{'credit_id': '52fe4495c3a368484e02b1cf', 'de...  1519557910
#
# [203 rows x 23 columns]

# %%
# sort data according revennue in descending
data.sort_values('revenue',ascending=False,ignore_index=True)
# Out:
#        id                              belongs_to_collection     budget  \
# 0    1127  [{'id': 86311, 'name': 'The Avengers Collectio...  220000000
# 1    1762  [{'id': 9485, 'name': 'The Fast and the Furiou...  190000000
# 2    2771  [{'id': 86311, 'name': 'The Avengers Collectio...  280000000
# 3    2323  [{'id': 8650, 'name': 'Transformers Collection...  195000000
# 4    2136  [{'id': 295, 'name': 'Pirates of the Caribbean...  380000000
# ..    ...                                                ...        ...
# 198   515  [{'id': 206559, 'name': 'StreetDance Collectio...          0
# 199  2277  [{'id': 286038, 'name': 'Dead Snow Collection'...          0
# 200  1500  [{'id': 473843, 'name': 'Stake Land Collection...     650000
# 201  1564  [{'id': 87186, 'name': 'The Boondock Saints Co...    6000000
# 202   666  [{'id': 86668, 'name': 'Elektra Luxx Collectio...          0
#
#                                                 genres  \
# 0    [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1                       [{'id': 28, 'name': 'Action'}]
# 2    [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3    [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 4    [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# ..                                                 ...
# 198  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 199  [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
# 200  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 201  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 202  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
#
#                                               homepage    imdb_id  \
# 0                    http://marvel.com/avengers_movie/  tt0848228
# 1                             http://www.furious7.com/  tt2820852
# 2    http://marvel.com/movies/movie/193/avengers_ag...  tt2395427
# 3                    http://www.transformersmovie.com/  tt1399103
# 4    http://disney.go.com/pirates/index-on-stranger...  tt1298650
# ..                                                 ...        ...
# 198                 http://www.highstrungthemovie.com/  tt3451230
# 199                           http://www.deadsnow.com/  tt2832470
# 200                   http://www.stakelandthefilm.com/  tt1464580
# 201                   http://www.theboondocksaints.com  tt0144117
# 202                  http://www.elektraluxx-movie.com/  tt1340773
#
#     original_language                               original_title  \
# 0                  en                                 The Avengers
# 1                  en                                    Furious 7
# 2                  en                      Avengers: Age of Ultron
# 3                  en               Transformers: Dark of the Moon
# 4                  en  Pirates of the Caribbean: On Stranger Tides
# ..                ...                                          ...
# 198                en                                  High Strung
# 199                no                                    Død Snø 2
# 200                en                                   Stake Land
# 201                en                          The Boondock Saints
# 202                en                                 Elektra Luxx
#
#                                               overview  popularity  ...  \
# 0    When an unexpected enemy emerges and threatens...   89.887648  ...
# 1    Deckard Shaw seeks revenge against Dominic Tor...   27.275687  ...
# 2    When Tony Stark tries to jumpstart a dormant p...   37.379420  ...
# 3    Sam Witwicky takes his first tenuous steps int...    4.503505  ...
# 4    Captain Jack Sparrow crosses paths with a woma...   27.887720  ...
# ..                                                 ...         ...  ...
# 198  When a hip hop violinist busking in the New Yo...    6.625607  ...
# 199  The gruesome Nazi Zombies are back to finish t...   10.287127  ...
# 200  Martin was a normal teenage boy before the cou...    7.814255  ...
# 201  With a God-inspired moral obligation to act ag...   12.457908  ...
# 202  A favor for a woman from her past throws the l...    4.118699  ...
#
#     release_date runtime                                   spoken_languages  \
# 0        4/25/12   143.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1         4/1/15   137.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2        4/22/15   141.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3        6/28/11   154.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4        5/14/11   136.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# ..           ...     ...                                                ...
# 198       4/8/16    96.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 199      2/12/14   100.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 200      9/30/10    98.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 201      1/22/99   108.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 202      3/14/10    98.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#        status                                            tagline  \
# 0    Released                            Some assembly required.
# 1    Released                                Vengeance Hits Home
# 2    Released                                A New Age Has Come.
# 3    Released  The invasion we always feared. An enemy we nev...
# 4    Released                        Live Forever Or Die Trying.
# ..        ...                                                ...
# 198  Released                     See the music. Hear the dance.
# 199  Released                            Heads up. They're back.
# 200  Released           The Most Dangerous Thing Is To Be Alive.
# 201  Released                Thy Kingdom Come. Thy Will Be Done.
# 202  Released         From adult film star to functioning adult.
#
#                                            title  \
# 0                                   The Avengers
# 1                                      Furious 7
# 2                        Avengers: Age of Ultron
# 3                 Transformers: Dark of the Moon
# 4    Pirates of the Caribbean: On Stranger Tides
# ..                                           ...
# 198                                  High Strung
# 199                    Dead Snow 2: Red vs. Dead
# 200                                   Stake Land
# 201                          The Boondock Saints
# 202                                 Elektra Luxx
#
#                                               Keywords  \
# 0    [{'id': 242, 'name': 'new york'}, {'id': 5539,...
# 1    [{'id': 830, 'name': 'car race'}, {'id': 3428,...
# 2    [{'id': 8828, 'name': 'marvel comic'}, {'id': ...
# 3    [{'id': 305, 'name': 'moon'}, {'id': 1612, 'na...
# 4    [{'id': 658, 'name': 'sea'}, {'id': 1316, 'nam...
# ..                                                 ...
# 198  [{'id': 1691, 'name': 'dance'}, {'id': 4721, '...
# 199  [{'id': 2652, 'name': 'nazis'}, {'id': 9663, '...
# 200  [{'id': 255, 'name': 'male nudity'}, {'id': 13...
# 201  [{'id': 1679, 'name': 'arbitrary law'}, {'id':...
# 202  [{'id': 10183, 'name': 'independent film'}, {'...
#
#                                                   cast  \
# 0    [{'cast_id': 46, 'character': 'Tony Stark / Ir...
# 1    [{'cast_id': 17, 'character': 'Dominic Toretto...
# 2    [{'cast_id': 76, 'character': 'Tony Stark / Ir...
# 3    [{'cast_id': 3, 'character': 'Sam Witwicky', '...
# 4    [{'cast_id': 15, 'character': 'Captain Jack Sp...
# ..                                                 ...
# 198  [{'cast_id': 3, 'character': 'Ruby', 'credit_i...
# 199  [{'cast_id': 19, 'character': 'Martin', 'credi...
# 200  [{'cast_id': 2, 'character': 'Belle', 'credit_...
# 201  [{'cast_id': 1, 'character': 'Paul Smecker', '...
# 202  [{'cast_id': 3, 'character': 'Elektra Luxx', '...
#
#                                                   crew     revenue
# 0    [{'credit_id': '52fe4495c3a368484e02b1cf', 'de...  1519557910
# 1    [{'credit_id': '52fe4cc8c3a36847f823e681', 'de...  1506249360
# 2    [{'credit_id': '55d5f7d4c3a3683e7e0016eb', 'de...  1405403694
# 3    [{'credit_id': '537f0b740e0a2624b40044d0', 'de...  1123746996
# 4    [{'credit_id': '566b4f54c3a3683f56005151', 'de...  1045713802
# ..                                                 ...         ...
# 198  [{'credit_id': '56be2f489251417359004545', 'de...       53447
# 199  [{'credit_id': '52fe4ebfc3a36847f82a57f3', 'de...       37473
# 200  [{'credit_id': '537483fcc3a36815180026ee', 'de...       33245
# 201  [{'credit_id': '52fe44a3c3a36847f80a1a91', 'de...       30471
# 202  [{'credit_id': '52fe48f6c3a36847f818264f', 'de...          10
#
# [203 rows x 23 columns]

# %%
# sort data according revennue in descending
data.sort_values('revenue',ascending=False,ignore_index=True)
# Out:
#        id                              belongs_to_collection     budget  \
# 0    1127  [{'id': 86311, 'name': 'The Avengers Collectio...  220000000
# 1    1762  [{'id': 9485, 'name': 'The Fast and the Furiou...  190000000
# 2    2771  [{'id': 86311, 'name': 'The Avengers Collectio...  280000000
# 3    2323  [{'id': 8650, 'name': 'Transformers Collection...  195000000
# 4    2136  [{'id': 295, 'name': 'Pirates of the Caribbean...  380000000
# ..    ...                                                ...        ...
# 198   515  [{'id': 206559, 'name': 'StreetDance Collectio...          0
# 199  2277  [{'id': 286038, 'name': 'Dead Snow Collection'...          0
# 200  1500  [{'id': 473843, 'name': 'Stake Land Collection...     650000
# 201  1564  [{'id': 87186, 'name': 'The Boondock Saints Co...    6000000
# 202   666  [{'id': 86668, 'name': 'Elektra Luxx Collectio...          0
#
#                                                 genres  \
# 0    [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1                       [{'id': 28, 'name': 'Action'}]
# 2    [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3    [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 4    [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# ..                                                 ...
# 198  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 199  [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
# 200  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 201  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 202  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
#
#                                               homepage    imdb_id  \
# 0                    http://marvel.com/avengers_movie/  tt0848228
# 1                             http://www.furious7.com/  tt2820852
# 2    http://marvel.com/movies/movie/193/avengers_ag...  tt2395427
# 3                    http://www.transformersmovie.com/  tt1399103
# 4    http://disney.go.com/pirates/index-on-stranger...  tt1298650
# ..                                                 ...        ...
# 198                 http://www.highstrungthemovie.com/  tt3451230
# 199                           http://www.deadsnow.com/  tt2832470
# 200                   http://www.stakelandthefilm.com/  tt1464580
# 201                   http://www.theboondocksaints.com  tt0144117
# 202                  http://www.elektraluxx-movie.com/  tt1340773
#
#     original_language                               original_title  \
# 0                  en                                 The Avengers
# 1                  en                                    Furious 7
# 2                  en                      Avengers: Age of Ultron
# 3                  en               Transformers: Dark of the Moon
# 4                  en  Pirates of the Caribbean: On Stranger Tides
# ..                ...                                          ...
# 198                en                                  High Strung
# 199                no                                    Død Snø 2
# 200                en                                   Stake Land
# 201                en                          The Boondock Saints
# 202                en                                 Elektra Luxx
#
#                                               overview  popularity  ...  \
# 0    When an unexpected enemy emerges and threatens...   89.887648  ...
# 1    Deckard Shaw seeks revenge against Dominic Tor...   27.275687  ...
# 2    When Tony Stark tries to jumpstart a dormant p...   37.379420  ...
# 3    Sam Witwicky takes his first tenuous steps int...    4.503505  ...
# 4    Captain Jack Sparrow crosses paths with a woma...   27.887720  ...
# ..                                                 ...         ...  ...
# 198  When a hip hop violinist busking in the New Yo...    6.625607  ...
# 199  The gruesome Nazi Zombies are back to finish t...   10.287127  ...
# 200  Martin was a normal teenage boy before the cou...    7.814255  ...
# 201  With a God-inspired moral obligation to act ag...   12.457908  ...
# 202  A favor for a woman from her past throws the l...    4.118699  ...
#
#     release_date runtime                                   spoken_languages  \
# 0        4/25/12   143.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1         4/1/15   137.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2        4/22/15   141.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3        6/28/11   154.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4        5/14/11   136.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# ..           ...     ...                                                ...
# 198       4/8/16    96.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 199      2/12/14   100.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 200      9/30/10    98.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 201      1/22/99   108.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 202      3/14/10    98.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#        status                                            tagline  \
# 0    Released                            Some assembly required.
# 1    Released                                Vengeance Hits Home
# 2    Released                                A New Age Has Come.
# 3    Released  The invasion we always feared. An enemy we nev...
# 4    Released                        Live Forever Or Die Trying.
# ..        ...                                                ...
# 198  Released                     See the music. Hear the dance.
# 199  Released                            Heads up. They're back.
# 200  Released           The Most Dangerous Thing Is To Be Alive.
# 201  Released                Thy Kingdom Come. Thy Will Be Done.
# 202  Released         From adult film star to functioning adult.
#
#                                            title  \
# 0                                   The Avengers
# 1                                      Furious 7
# 2                        Avengers: Age of Ultron
# 3                 Transformers: Dark of the Moon
# 4    Pirates of the Caribbean: On Stranger Tides
# ..                                           ...
# 198                                  High Strung
# 199                    Dead Snow 2: Red vs. Dead
# 200                                   Stake Land
# 201                          The Boondock Saints
# 202                                 Elektra Luxx
#
#                                               Keywords  \
# 0    [{'id': 242, 'name': 'new york'}, {'id': 5539,...
# 1    [{'id': 830, 'name': 'car race'}, {'id': 3428,...
# 2    [{'id': 8828, 'name': 'marvel comic'}, {'id': ...
# 3    [{'id': 305, 'name': 'moon'}, {'id': 1612, 'na...
# 4    [{'id': 658, 'name': 'sea'}, {'id': 1316, 'nam...
# ..                                                 ...
# 198  [{'id': 1691, 'name': 'dance'}, {'id': 4721, '...
# 199  [{'id': 2652, 'name': 'nazis'}, {'id': 9663, '...
# 200  [{'id': 255, 'name': 'male nudity'}, {'id': 13...
# 201  [{'id': 1679, 'name': 'arbitrary law'}, {'id':...
# 202  [{'id': 10183, 'name': 'independent film'}, {'...
#
#                                                   cast  \
# 0    [{'cast_id': 46, 'character': 'Tony Stark / Ir...
# 1    [{'cast_id': 17, 'character': 'Dominic Toretto...
# 2    [{'cast_id': 76, 'character': 'Tony Stark / Ir...
# 3    [{'cast_id': 3, 'character': 'Sam Witwicky', '...
# 4    [{'cast_id': 15, 'character': 'Captain Jack Sp...
# ..                                                 ...
# 198  [{'cast_id': 3, 'character': 'Ruby', 'credit_i...
# 199  [{'cast_id': 19, 'character': 'Martin', 'credi...
# 200  [{'cast_id': 2, 'character': 'Belle', 'credit_...
# 201  [{'cast_id': 1, 'character': 'Paul Smecker', '...
# 202  [{'cast_id': 3, 'character': 'Elektra Luxx', '...
#
#                                                   crew     revenue
# 0    [{'credit_id': '52fe4495c3a368484e02b1cf', 'de...  1519557910
# 1    [{'credit_id': '52fe4cc8c3a36847f823e681', 'de...  1506249360
# 2    [{'credit_id': '55d5f7d4c3a3683e7e0016eb', 'de...  1405403694
# 3    [{'credit_id': '537f0b740e0a2624b40044d0', 'de...  1123746996
# 4    [{'credit_id': '566b4f54c3a3683f56005151', 'de...  1045713802
# ..                                                 ...         ...
# 198  [{'credit_id': '56be2f489251417359004545', 'de...       53447
# 199  [{'credit_id': '52fe4ebfc3a36847f82a57f3', 'de...       37473
# 200  [{'credit_id': '537483fcc3a36815180026ee', 'de...       33245
# 201  [{'credit_id': '52fe44a3c3a36847f80a1a91', 'de...       30471
# 202  [{'credit_id': '52fe48f6c3a36847f818264f', 'de...          10
#
# [203 rows x 23 columns]

# %% [markdown]
# When using **ignore_index=True** in the sort_values() method in pandas, it ensures that the resulting DataFrame has its index reset to a default integer index after sorting. This is particularly useful when you no longer need the original index after sorting.

# %% [markdown]
# **Temporary changes**

# %%
data.sort_values('revenue',ignore_index=True)
# This code sorts data in increasing order of revenue but changes is not seen in original dataframe
# Out:
#        id                              belongs_to_collection     budget  \
# 0     666  [{'id': 86668, 'name': 'Elektra Luxx Collectio...          0
# 1    1564  [{'id': 87186, 'name': 'The Boondock Saints Co...    6000000
# 2    1500  [{'id': 473843, 'name': 'Stake Land Collection...     650000
# 3    2277  [{'id': 286038, 'name': 'Dead Snow Collection'...          0
# 4     515  [{'id': 206559, 'name': 'StreetDance Collectio...          0
# ..    ...                                                ...        ...
# 198  2136  [{'id': 295, 'name': 'Pirates of the Caribbean...  380000000
# 199  2323  [{'id': 8650, 'name': 'Transformers Collection...  195000000
# 200  2771  [{'id': 86311, 'name': 'The Avengers Collectio...  280000000
# 201  1762  [{'id': 9485, 'name': 'The Fast and the Furiou...  190000000
# 202  1127  [{'id': 86311, 'name': 'The Avengers Collectio...  220000000
#
#                                                 genres  \
# 0    [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 1    [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 2    [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 3    [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
# 4    [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# ..                                                 ...
# 198  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 199  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 200  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 201                     [{'id': 28, 'name': 'Action'}]
# 202  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
#
#                                               homepage    imdb_id  \
# 0                    http://www.elektraluxx-movie.com/  tt1340773
# 1                     http://www.theboondocksaints.com  tt0144117
# 2                     http://www.stakelandthefilm.com/  tt1464580
# 3                             http://www.deadsnow.com/  tt2832470
# 4                   http://www.highstrungthemovie.com/  tt3451230
# ..                                                 ...        ...
# 198  http://disney.go.com/pirates/index-on-stranger...  tt1298650
# 199                  http://www.transformersmovie.com/  tt1399103
# 200  http://marvel.com/movies/movie/193/avengers_ag...  tt2395427
# 201                           http://www.furious7.com/  tt2820852
# 202                  http://marvel.com/avengers_movie/  tt0848228
#
#     original_language                               original_title  \
# 0                  en                                 Elektra Luxx
# 1                  en                          The Boondock Saints
# 2                  en                                   Stake Land
# 3                  no                                    Død Snø 2
# 4                  en                                  High Strung
# ..                ...                                          ...
# 198                en  Pirates of the Caribbean: On Stranger Tides
# 199                en               Transformers: Dark of the Moon
# 200                en                      Avengers: Age of Ultron
# 201                en                                    Furious 7
# 202                en                                 The Avengers
#
#                                               overview  popularity  ...  \
# 0    A favor for a woman from her past throws the l...    4.118699  ...
# 1    With a God-inspired moral obligation to act ag...   12.457908  ...
# 2    Martin was a normal teenage boy before the cou...    7.814255  ...
# 3    The gruesome Nazi Zombies are back to finish t...   10.287127  ...
# 4    When a hip hop violinist busking in the New Yo...    6.625607  ...
# ..                                                 ...         ...  ...
# 198  Captain Jack Sparrow crosses paths with a woma...   27.887720  ...
# 199  Sam Witwicky takes his first tenuous steps int...    4.503505  ...
# 200  When Tony Stark tries to jumpstart a dormant p...   37.379420  ...
# 201  Deckard Shaw seeks revenge against Dominic Tor...   27.275687  ...
# 202  When an unexpected enemy emerges and threatens...   89.887648  ...
#
#     release_date runtime                                   spoken_languages  \
# 0        3/14/10    98.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1        1/22/99   108.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2        9/30/10    98.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3        2/12/14   100.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 4         4/8/16    96.0           [{'iso_639_1': 'en', 'name': 'English'}]
# ..           ...     ...                                                ...
# 198      5/14/11   136.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 199      6/28/11   154.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 200      4/22/15   141.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 201       4/1/15   137.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 202      4/25/12   143.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#        status                                            tagline  \
# 0    Released         From adult film star to functioning adult.
# 1    Released                Thy Kingdom Come. Thy Will Be Done.
# 2    Released           The Most Dangerous Thing Is To Be Alive.
# 3    Released                            Heads up. They're back.
# 4    Released                     See the music. Hear the dance.
# ..        ...                                                ...
# 198  Released                        Live Forever Or Die Trying.
# 199  Released  The invasion we always feared. An enemy we nev...
# 200  Released                                A New Age Has Come.
# 201  Released                                Vengeance Hits Home
# 202  Released                            Some assembly required.
#
#                                            title  \
# 0                                   Elektra Luxx
# 1                            The Boondock Saints
# 2                                     Stake Land
# 3                      Dead Snow 2: Red vs. Dead
# 4                                    High Strung
# ..                                           ...
# 198  Pirates of the Caribbean: On Stranger Tides
# 199               Transformers: Dark of the Moon
# 200                      Avengers: Age of Ultron
# 201                                    Furious 7
# 202                                 The Avengers
#
#                                               Keywords  \
# 0    [{'id': 10183, 'name': 'independent film'}, {'...
# 1    [{'id': 1679, 'name': 'arbitrary law'}, {'id':...
# 2    [{'id': 255, 'name': 'male nudity'}, {'id': 13...
# 3    [{'id': 2652, 'name': 'nazis'}, {'id': 9663, '...
# 4    [{'id': 1691, 'name': 'dance'}, {'id': 4721, '...
# ..                                                 ...
# 198  [{'id': 658, 'name': 'sea'}, {'id': 1316, 'nam...
# 199  [{'id': 305, 'name': 'moon'}, {'id': 1612, 'na...
# 200  [{'id': 8828, 'name': 'marvel comic'}, {'id': ...
# 201  [{'id': 830, 'name': 'car race'}, {'id': 3428,...
# 202  [{'id': 242, 'name': 'new york'}, {'id': 5539,...
#
#                                                   cast  \
# 0    [{'cast_id': 3, 'character': 'Elektra Luxx', '...
# 1    [{'cast_id': 1, 'character': 'Paul Smecker', '...
# 2    [{'cast_id': 2, 'character': 'Belle', 'credit_...
# 3    [{'cast_id': 19, 'character': 'Martin', 'credi...
# 4    [{'cast_id': 3, 'character': 'Ruby', 'credit_i...
# ..                                                 ...
# 198  [{'cast_id': 15, 'character': 'Captain Jack Sp...
# 199  [{'cast_id': 3, 'character': 'Sam Witwicky', '...
# 200  [{'cast_id': 76, 'character': 'Tony Stark / Ir...
# 201  [{'cast_id': 17, 'character': 'Dominic Toretto...
# 202  [{'cast_id': 46, 'character': 'Tony Stark / Ir...
#
#                                                   crew     revenue
# 0    [{'credit_id': '52fe48f6c3a36847f818264f', 'de...          10
# 1    [{'credit_id': '52fe44a3c3a36847f80a1a91', 'de...       30471
# 2    [{'credit_id': '537483fcc3a36815180026ee', 'de...       33245
# 3    [{'credit_id': '52fe4ebfc3a36847f82a57f3', 'de...       37473
# 4    [{'credit_id': '56be2f489251417359004545', 'de...       53447
# ..                                                 ...         ...
# 198  [{'credit_id': '566b4f54c3a3683f56005151', 'de...  1045713802
# 199  [{'credit_id': '537f0b740e0a2624b40044d0', 'de...  1123746996
# 200  [{'credit_id': '55d5f7d4c3a3683e7e0016eb', 'de...  1405403694
# 201  [{'credit_id': '52fe4cc8c3a36847f823e681', 'de...  1506249360
# 202  [{'credit_id': '52fe4495c3a368484e02b1cf', 'de...  1519557910
#
# [203 rows x 23 columns]

# %% [markdown]
# **How to make permanent changes**

# %%
# Method 1: Assign sorted results to a new variable(not much recommended)
df =data.sort_values('revenue',ignore_index=True)

# %%
# Method 2:Changes can be done in original dataframe by using inplace=True
data.sort_values('revenue',ascending=False,ignore_index=True,inplace=True)
# inplace=True is used make changes in original dataframe

# %%
data
# Out:
#        id                              belongs_to_collection     budget  \
# 0    1127  [{'id': 86311, 'name': 'The Avengers Collectio...  220000000
# 1    1762  [{'id': 9485, 'name': 'The Fast and the Furiou...  190000000
# 2    2771  [{'id': 86311, 'name': 'The Avengers Collectio...  280000000
# 3    2323  [{'id': 8650, 'name': 'Transformers Collection...  195000000
# 4    2136  [{'id': 295, 'name': 'Pirates of the Caribbean...  380000000
# ..    ...                                                ...        ...
# 198   515  [{'id': 206559, 'name': 'StreetDance Collectio...          0
# 199  2277  [{'id': 286038, 'name': 'Dead Snow Collection'...          0
# 200  1500  [{'id': 473843, 'name': 'Stake Land Collection...     650000
# 201  1564  [{'id': 87186, 'name': 'The Boondock Saints Co...    6000000
# 202   666  [{'id': 86668, 'name': 'Elektra Luxx Collectio...          0
#
#                                                 genres  \
# 0    [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1                       [{'id': 28, 'name': 'Action'}]
# 2    [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3    [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 4    [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# ..                                                 ...
# 198  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 199  [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
# 200  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 201  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 202  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
#
#                                               homepage    imdb_id  \
# 0                    http://marvel.com/avengers_movie/  tt0848228
# 1                             http://www.furious7.com/  tt2820852
# 2    http://marvel.com/movies/movie/193/avengers_ag...  tt2395427
# 3                    http://www.transformersmovie.com/  tt1399103
# 4    http://disney.go.com/pirates/index-on-stranger...  tt1298650
# ..                                                 ...        ...
# 198                 http://www.highstrungthemovie.com/  tt3451230
# 199                           http://www.deadsnow.com/  tt2832470
# 200                   http://www.stakelandthefilm.com/  tt1464580
# 201                   http://www.theboondocksaints.com  tt0144117
# 202                  http://www.elektraluxx-movie.com/  tt1340773
#
#     original_language                               original_title  \
# 0                  en                                 The Avengers
# 1                  en                                    Furious 7
# 2                  en                      Avengers: Age of Ultron
# 3                  en               Transformers: Dark of the Moon
# 4                  en  Pirates of the Caribbean: On Stranger Tides
# ..                ...                                          ...
# 198                en                                  High Strung
# 199                no                                    Død Snø 2
# 200                en                                   Stake Land
# 201                en                          The Boondock Saints
# 202                en                                 Elektra Luxx
#
#                                               overview  popularity  ...  \
# 0    When an unexpected enemy emerges and threatens...   89.887648  ...
# 1    Deckard Shaw seeks revenge against Dominic Tor...   27.275687  ...
# 2    When Tony Stark tries to jumpstart a dormant p...   37.379420  ...
# 3    Sam Witwicky takes his first tenuous steps int...    4.503505  ...
# 4    Captain Jack Sparrow crosses paths with a woma...   27.887720  ...
# ..                                                 ...         ...  ...
# 198  When a hip hop violinist busking in the New Yo...    6.625607  ...
# 199  The gruesome Nazi Zombies are back to finish t...   10.287127  ...
# 200  Martin was a normal teenage boy before the cou...    7.814255  ...
# 201  With a God-inspired moral obligation to act ag...   12.457908  ...
# 202  A favor for a woman from her past throws the l...    4.118699  ...
#
#     release_date runtime                                   spoken_languages  \
# 0        4/25/12   143.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1         4/1/15   137.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2        4/22/15   141.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3        6/28/11   154.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4        5/14/11   136.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# ..           ...     ...                                                ...
# 198       4/8/16    96.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 199      2/12/14   100.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 200      9/30/10    98.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 201      1/22/99   108.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 202      3/14/10    98.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#        status                                            tagline  \
# 0    Released                            Some assembly required.
# 1    Released                                Vengeance Hits Home
# 2    Released                                A New Age Has Come.
# 3    Released  The invasion we always feared. An enemy we nev...
# 4    Released                        Live Forever Or Die Trying.
# ..        ...                                                ...
# 198  Released                     See the music. Hear the dance.
# 199  Released                            Heads up. They're back.
# 200  Released           The Most Dangerous Thing Is To Be Alive.
# 201  Released                Thy Kingdom Come. Thy Will Be Done.
# 202  Released         From adult film star to functioning adult.
#
#                                            title  \
# 0                                   The Avengers
# 1                                      Furious 7
# 2                        Avengers: Age of Ultron
# 3                 Transformers: Dark of the Moon
# 4    Pirates of the Caribbean: On Stranger Tides
# ..                                           ...
# 198                                  High Strung
# 199                    Dead Snow 2: Red vs. Dead
# 200                                   Stake Land
# 201                          The Boondock Saints
# 202                                 Elektra Luxx
#
#                                               Keywords  \
# 0    [{'id': 242, 'name': 'new york'}, {'id': 5539,...
# 1    [{'id': 830, 'name': 'car race'}, {'id': 3428,...
# 2    [{'id': 8828, 'name': 'marvel comic'}, {'id': ...
# 3    [{'id': 305, 'name': 'moon'}, {'id': 1612, 'na...
# 4    [{'id': 658, 'name': 'sea'}, {'id': 1316, 'nam...
# ..                                                 ...
# 198  [{'id': 1691, 'name': 'dance'}, {'id': 4721, '...
# 199  [{'id': 2652, 'name': 'nazis'}, {'id': 9663, '...
# 200  [{'id': 255, 'name': 'male nudity'}, {'id': 13...
# 201  [{'id': 1679, 'name': 'arbitrary law'}, {'id':...
# 202  [{'id': 10183, 'name': 'independent film'}, {'...
#
#                                                   cast  \
# 0    [{'cast_id': 46, 'character': 'Tony Stark / Ir...
# 1    [{'cast_id': 17, 'character': 'Dominic Toretto...
# 2    [{'cast_id': 76, 'character': 'Tony Stark / Ir...
# 3    [{'cast_id': 3, 'character': 'Sam Witwicky', '...
# 4    [{'cast_id': 15, 'character': 'Captain Jack Sp...
# ..                                                 ...
# 198  [{'cast_id': 3, 'character': 'Ruby', 'credit_i...
# 199  [{'cast_id': 19, 'character': 'Martin', 'credi...
# 200  [{'cast_id': 2, 'character': 'Belle', 'credit_...
# 201  [{'cast_id': 1, 'character': 'Paul Smecker', '...
# 202  [{'cast_id': 3, 'character': 'Elektra Luxx', '...
#
#                                                   crew     revenue
# 0    [{'credit_id': '52fe4495c3a368484e02b1cf', 'de...  1519557910
# 1    [{'credit_id': '52fe4cc8c3a36847f823e681', 'de...  1506249360
# 2    [{'credit_id': '55d5f7d4c3a3683e7e0016eb', 'de...  1405403694
# 3    [{'credit_id': '537f0b740e0a2624b40044d0', 'de...  1123746996
# 4    [{'credit_id': '566b4f54c3a3683f56005151', 'de...  1045713802
# ..                                                 ...         ...
# 198  [{'credit_id': '56be2f489251417359004545', 'de...       53447
# 199  [{'credit_id': '52fe4ebfc3a36847f82a57f3', 'de...       37473
# 200  [{'credit_id': '537483fcc3a36815180026ee', 'de...       33245
# 201  [{'credit_id': '52fe44a3c3a36847f80a1a91', 'de...       30471
# 202  [{'credit_id': '52fe48f6c3a36847f818264f', 'de...          10
#
# [203 rows x 23 columns]

# %% [markdown]
# **ignore_index:**
# * When combining, sorting, or resetting the index in a DataFrame, setting **ignore_index=True** reassigns a new integer index to the result, starting from 0, and discards the existing index.

# %% [markdown]
# **inplace=True**:
#
# * inplace=True in Pandas is a parameter that allows you to perform an operation directly on the original DataFrame, modifying it “in place” without creating or returning a new copy of the DataFrame. This can be useful for saving memory and keeping the code concise.
# * When inplace=True is used, the original DataFrame is altered, and the method does not return anything (it returns None).

# %% [markdown]
# **ascending=False in Pandas**
# In Pandas, the ascending parameter is used in sorting functions like sort_values() to specify whether the data should be sorted in ascending or descending order.
#
# * ascending=True: Sorts the data in ascending order (default behavior).
# * ascending=False: Sorts the data in descending order.

# %% [markdown]
# ### **rename**
# rename() allows you to specify new names for one or multiple columns (or index labels) and returns a DataFrame with updated names. You can use it to make column names more descriptive, standardized, or easier to work with.
#
# **syntax**
#
# * **dataframe.rename({col1:new_col1 , col2:new_col2},axis=1,inplace=True)**
# * axis=1 specifies that the operation should be applied to columns.
# * axis=1 is typically used when you want to modify, drop, or perform actions on columns (whereas axis=0 applies to rows).

# %%
# rename original_language as orig_lang
data.rename({'original_language':'orig_lang'},axis=1,inplace=True)

# %%
data
# Out:
#        id                              belongs_to_collection     budget  \
# 0    1127  [{'id': 86311, 'name': 'The Avengers Collectio...  220000000
# 1    1762  [{'id': 9485, 'name': 'The Fast and the Furiou...  190000000
# 2    2771  [{'id': 86311, 'name': 'The Avengers Collectio...  280000000
# 3    2323  [{'id': 8650, 'name': 'Transformers Collection...  195000000
# 4    2136  [{'id': 295, 'name': 'Pirates of the Caribbean...  380000000
# ..    ...                                                ...        ...
# 198   515  [{'id': 206559, 'name': 'StreetDance Collectio...          0
# 199  2277  [{'id': 286038, 'name': 'Dead Snow Collection'...          0
# 200  1500  [{'id': 473843, 'name': 'Stake Land Collection...     650000
# 201  1564  [{'id': 87186, 'name': 'The Boondock Saints Co...    6000000
# 202   666  [{'id': 86668, 'name': 'Elektra Luxx Collectio...          0
#
#                                                 genres  \
# 0    [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1                       [{'id': 28, 'name': 'Action'}]
# 2    [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3    [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 4    [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# ..                                                 ...
# 198  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 199  [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
# 200  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 201  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 202  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
#
#                                               homepage    imdb_id orig_lang  \
# 0                    http://marvel.com/avengers_movie/  tt0848228        en
# 1                             http://www.furious7.com/  tt2820852        en
# 2    http://marvel.com/movies/movie/193/avengers_ag...  tt2395427        en
# 3                    http://www.transformersmovie.com/  tt1399103        en
# 4    http://disney.go.com/pirates/index-on-stranger...  tt1298650        en
# ..                                                 ...        ...       ...
# 198                 http://www.highstrungthemovie.com/  tt3451230        en
# 199                           http://www.deadsnow.com/  tt2832470        no
# 200                   http://www.stakelandthefilm.com/  tt1464580        en
# 201                   http://www.theboondocksaints.com  tt0144117        en
# 202                  http://www.elektraluxx-movie.com/  tt1340773        en
#
#                                   original_title  \
# 0                                   The Avengers
# 1                                      Furious 7
# 2                        Avengers: Age of Ultron
# 3                 Transformers: Dark of the Moon
# 4    Pirates of the Caribbean: On Stranger Tides
# ..                                           ...
# 198                                  High Strung
# 199                                    Død Snø 2
# 200                                   Stake Land
# 201                          The Boondock Saints
# 202                                 Elektra Luxx
#
#                                               overview  popularity  ...  \
# 0    When an unexpected enemy emerges and threatens...   89.887648  ...
# 1    Deckard Shaw seeks revenge against Dominic Tor...   27.275687  ...
# 2    When Tony Stark tries to jumpstart a dormant p...   37.379420  ...
# 3    Sam Witwicky takes his first tenuous steps int...    4.503505  ...
# 4    Captain Jack Sparrow crosses paths with a woma...   27.887720  ...
# ..                                                 ...         ...  ...
# 198  When a hip hop violinist busking in the New Yo...    6.625607  ...
# 199  The gruesome Nazi Zombies are back to finish t...   10.287127  ...
# 200  Martin was a normal teenage boy before the cou...    7.814255  ...
# 201  With a God-inspired moral obligation to act ag...   12.457908  ...
# 202  A favor for a woman from her past throws the l...    4.118699  ...
#
#     release_date runtime                                   spoken_languages  \
# 0        4/25/12   143.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1         4/1/15   137.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2        4/22/15   141.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3        6/28/11   154.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4        5/14/11   136.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# ..           ...     ...                                                ...
# 198       4/8/16    96.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 199      2/12/14   100.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 200      9/30/10    98.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 201      1/22/99   108.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 202      3/14/10    98.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#        status                                            tagline  \
# 0    Released                            Some assembly required.
# 1    Released                                Vengeance Hits Home
# 2    Released                                A New Age Has Come.
# 3    Released  The invasion we always feared. An enemy we nev...
# 4    Released                        Live Forever Or Die Trying.
# ..        ...                                                ...
# 198  Released                     See the music. Hear the dance.
# 199  Released                            Heads up. They're back.
# 200  Released           The Most Dangerous Thing Is To Be Alive.
# 201  Released                Thy Kingdom Come. Thy Will Be Done.
# 202  Released         From adult film star to functioning adult.
#
#                                            title  \
# 0                                   The Avengers
# 1                                      Furious 7
# 2                        Avengers: Age of Ultron
# 3                 Transformers: Dark of the Moon
# 4    Pirates of the Caribbean: On Stranger Tides
# ..                                           ...
# 198                                  High Strung
# 199                    Dead Snow 2: Red vs. Dead
# 200                                   Stake Land
# 201                          The Boondock Saints
# 202                                 Elektra Luxx
#
#                                               Keywords  \
# 0    [{'id': 242, 'name': 'new york'}, {'id': 5539,...
# 1    [{'id': 830, 'name': 'car race'}, {'id': 3428,...
# 2    [{'id': 8828, 'name': 'marvel comic'}, {'id': ...
# 3    [{'id': 305, 'name': 'moon'}, {'id': 1612, 'na...
# 4    [{'id': 658, 'name': 'sea'}, {'id': 1316, 'nam...
# ..                                                 ...
# 198  [{'id': 1691, 'name': 'dance'}, {'id': 4721, '...
# 199  [{'id': 2652, 'name': 'nazis'}, {'id': 9663, '...
# 200  [{'id': 255, 'name': 'male nudity'}, {'id': 13...
# 201  [{'id': 1679, 'name': 'arbitrary law'}, {'id':...
# 202  [{'id': 10183, 'name': 'independent film'}, {'...
#
#                                                   cast  \
# 0    [{'cast_id': 46, 'character': 'Tony Stark / Ir...
# 1    [{'cast_id': 17, 'character': 'Dominic Toretto...
# 2    [{'cast_id': 76, 'character': 'Tony Stark / Ir...
# 3    [{'cast_id': 3, 'character': 'Sam Witwicky', '...
# 4    [{'cast_id': 15, 'character': 'Captain Jack Sp...
# ..                                                 ...
# 198  [{'cast_id': 3, 'character': 'Ruby', 'credit_i...
# 199  [{'cast_id': 19, 'character': 'Martin', 'credi...
# 200  [{'cast_id': 2, 'character': 'Belle', 'credit_...
# 201  [{'cast_id': 1, 'character': 'Paul Smecker', '...
# 202  [{'cast_id': 3, 'character': 'Elektra Luxx', '...
#
#                                                   crew     revenue
# 0    [{'credit_id': '52fe4495c3a368484e02b1cf', 'de...  1519557910
# 1    [{'credit_id': '52fe4cc8c3a36847f823e681', 'de...  1506249360
# 2    [{'credit_id': '55d5f7d4c3a3683e7e0016eb', 'de...  1405403694
# 3    [{'credit_id': '537f0b740e0a2624b40044d0', 'de...  1123746996
# 4    [{'credit_id': '566b4f54c3a3683f56005151', 'de...  1045713802
# ..                                                 ...         ...
# 198  [{'credit_id': '56be2f489251417359004545', 'de...       53447
# 199  [{'credit_id': '52fe4ebfc3a36847f82a57f3', 'de...       37473
# 200  [{'credit_id': '537483fcc3a36815180026ee', 'de...       33245
# 201  [{'credit_id': '52fe44a3c3a36847f80a1a91', 'de...       30471
# 202  [{'credit_id': '52fe48f6c3a36847f818264f', 'de...          10
#
# [203 rows x 23 columns]

# %%
# rename 'production_companies' as companies ,'production_countries' as countries
data.rename({'production_companies':'companies','production_countries':'countries'},axis=1,inplace=True)

# %% [markdown]
# In Pandas, **axis=1** is commonly used in functions to specify that the operation should be applied across columns (horizontally), rather than rows (vertically).

# %% [markdown]
# **In pandas, axis=0 and axis=1 refer to the direction in which an operation is performed:**
#
# 1. axis=0: Refers to the rows (vertical axis).
#
# Operations act along rows or apply to rows.
#
# Commonly used for index-based operations (default behavior).
#
# 2. axis=1: Refers to the columns (horizontal axis).
#
# Operations act along columns or apply to columns.

# %% [markdown]
# # **drop()**
#
# In Pandas, drop() is used to remove rows or columns from a DataFrame.
#
# dataframe.drop('column_name', axis=1, inplace=True)
#
# dataframe.drop([col1, col2], axis=1, inplace=True)
#
# **Note:**
#
# axis=0 → remove rows
#
# axis=1 → remove columns
#
# inplace=True → updates the original DataFrame directly

# %%
# Drop belongs_to_collection column
data.drop('belongs_to_collection',axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['id', 'budget', 'genres', 'homepage', 'imdb_id', 'orig_lang',
#        'original_title', 'overview', 'popularity', 'poster_path', 'companies',
#        'countries', 'release_date', 'runtime', 'spoken_languages', 'status',
#        'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
# drop homepage , poster_path
data.drop(['homepage', 'poster_path'], axis = 1, inplace =  True)

# %%
data.columns
# Out:
# Index(['id', 'budget', 'genres', 'imdb_id', 'orig_lang', 'original_title',
#        'overview', 'popularity', 'companies', 'countries', 'release_date',
#        'runtime', 'spoken_languages', 'status', 'tagline', 'title', 'Keywords',
#        'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
# drop 1st and 6th row
data.drop([0,5],axis=0)
# Index of first row is 0 and 6th row is 5
# axis=0 because we are dropping rows
# Out:
#        id     budget                                             genres  \
# 1    1762  190000000                     [{'id': 28, 'name': 'Action'}]
# 2    2771  280000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3    2323  195000000  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 4    2136  380000000  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 6     882  200000000  [{'id': 10751, 'name': 'Family'}, {'id': 14, '...
# ..    ...        ...                                                ...
# 198   515          0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 199  2277          0  [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
# 200  1500     650000  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 201  1564    6000000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 202   666          0  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
#
#        imdb_id orig_lang                               original_title  \
# 1    tt2820852        en                                    Furious 7
# 2    tt2395427        en                      Avengers: Age of Ultron
# 3    tt1399103        en               Transformers: Dark of the Moon
# 4    tt1298650        en  Pirates of the Caribbean: On Stranger Tides
# 6    tt1014759        en                          Alice in Wonderland
# ..         ...       ...                                          ...
# 198  tt3451230        en                                  High Strung
# 199  tt2832470        no                                    Død Snø 2
# 200  tt1464580        en                                   Stake Land
# 201  tt0144117        en                          The Boondock Saints
# 202  tt1340773        en                                 Elektra Luxx
#
#                                               overview  popularity  \
# 1    Deckard Shaw seeks revenge against Dominic Tor...   27.275687
# 2    When Tony Stark tries to jumpstart a dormant p...   37.379420
# 3    Sam Witwicky takes his first tenuous steps int...    4.503505
# 4    Captain Jack Sparrow crosses paths with a woma...   27.887720
# 6    Alice, an unpretentious and individual 19-year...   17.285093
# ..                                                 ...         ...
# 198  When a hip hop violinist busking in the New Yo...    6.625607
# 199  The gruesome Nazi Zombies are back to finish t...   10.287127
# 200  Martin was a normal teenage boy before the cou...    7.814255
# 201  With a God-inspired moral obligation to act ag...   12.457908
# 202  A favor for a woman from her past throws the l...    4.118699
#
#                                              companies  \
# 1    [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 2    [{'name': 'Marvel Studios', 'id': 420}, {'name...
# 3    [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 4    [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
# 6    [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
# ..                                                 ...
# 198  [{'name': 'Castel Film Studio', 'id': 4573}, {...
# 199  [{'name': 'Saga Film', 'id': 859}, {'name': 'T...
# 200  [{'name': 'Glass Eye Pix', 'id': 1360}, {'name...
# 201  [{'name': 'Franchise Pictures', 'id': 1403}, {...
# 202         [{'name': 'Gato Negro Films', 'id': 5295}]
#
#                                              countries release_date  runtime  \
# 1    [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...       4/1/15    137.0
# 2    [{'iso_3166_1': 'US', 'name': 'United States o...      4/22/15    141.0
# 3    [{'iso_3166_1': 'US', 'name': 'United States o...      6/28/11    154.0
# 4    [{'iso_3166_1': 'US', 'name': 'United States o...      5/14/11    136.0
# 6    [{'iso_3166_1': 'US', 'name': 'United States o...       3/3/10    108.0
# ..                                                 ...          ...      ...
# 198  [{'iso_3166_1': 'RO', 'name': 'Romania'}, {'is...       4/8/16     96.0
# 199           [{'iso_3166_1': 'NO', 'name': 'Norway'}]      2/12/14    100.0
# 200  [{'iso_3166_1': 'US', 'name': 'United States o...      9/30/10     98.0
# 201  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...      1/22/99    108.0
# 202  [{'iso_3166_1': 'US', 'name': 'United States o...      3/14/10     98.0
#
#                                       spoken_languages    status  \
# 1             [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2             [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3             [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4    [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 6             [{'iso_639_1': 'en', 'name': 'English'}]  Released
# ..                                                 ...       ...
# 198           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 199  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...  Released
# 200           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 201  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 202           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                tagline  \
# 1                                  Vengeance Hits Home
# 2                                  A New Age Has Come.
# 3    The invasion we always feared. An enemy we nev...
# 4                          Live Forever Or Die Trying.
# 6             You're invited to a very important date.
# ..                                                 ...
# 198                     See the music. Hear the dance.
# 199                            Heads up. They're back.
# 200           The Most Dangerous Thing Is To Be Alive.
# 201                Thy Kingdom Come. Thy Will Be Done.
# 202         From adult film star to functioning adult.
#
#                                            title  \
# 1                                      Furious 7
# 2                        Avengers: Age of Ultron
# 3                 Transformers: Dark of the Moon
# 4    Pirates of the Caribbean: On Stranger Tides
# 6                            Alice in Wonderland
# ..                                           ...
# 198                                  High Strung
# 199                    Dead Snow 2: Red vs. Dead
# 200                                   Stake Land
# 201                          The Boondock Saints
# 202                                 Elektra Luxx
#
#                                               Keywords  \
# 1    [{'id': 830, 'name': 'car race'}, {'id': 3428,...
# 2    [{'id': 8828, 'name': 'marvel comic'}, {'id': ...
# 3    [{'id': 305, 'name': 'moon'}, {'id': 1612, 'na...
# 4    [{'id': 658, 'name': 'sea'}, {'id': 1316, 'nam...
# 6    [{'id': 818, 'name': 'based on novel'}, {'id':...
# ..                                                 ...
# 198  [{'id': 1691, 'name': 'dance'}, {'id': 4721, '...
# 199  [{'id': 2652, 'name': 'nazis'}, {'id': 9663, '...
# 200  [{'id': 255, 'name': 'male nudity'}, {'id': 13...
# 201  [{'id': 1679, 'name': 'arbitrary law'}, {'id':...
# 202  [{'id': 10183, 'name': 'independent film'}, {'...
#
#                                                   cast  \
# 1    [{'cast_id': 17, 'character': 'Dominic Toretto...
# 2    [{'cast_id': 76, 'character': 'Tony Stark / Ir...
# 3    [{'cast_id': 3, 'character': 'Sam Witwicky', '...
# 4    [{'cast_id': 15, 'character': 'Captain Jack Sp...
# 6    [{'cast_id': 7, 'character': 'Alice Kingsleigh...
# ..                                                 ...
# 198  [{'cast_id': 3, 'character': 'Ruby', 'credit_i...
# 199  [{'cast_id': 19, 'character': 'Martin', 'credi...
# 200  [{'cast_id': 2, 'character': 'Belle', 'credit_...
# 201  [{'cast_id': 1, 'character': 'Paul Smecker', '...
# 202  [{'cast_id': 3, 'character': 'Elektra Luxx', '...
#
#                                                   crew     revenue
# 1    [{'credit_id': '52fe4cc8c3a36847f823e681', 'de...  1506249360
# 2    [{'credit_id': '55d5f7d4c3a3683e7e0016eb', 'de...  1405403694
# 3    [{'credit_id': '537f0b740e0a2624b40044d0', 'de...  1123746996
# 4    [{'credit_id': '566b4f54c3a3683f56005151', 'de...  1045713802
# 6    [{'credit_id': '52fe44c09251416c7503fbc3', 'de...  1025491110
# ..                                                 ...         ...
# 198  [{'credit_id': '56be2f489251417359004545', 'de...       53447
# 199  [{'credit_id': '52fe4ebfc3a36847f82a57f3', 'de...       37473
# 200  [{'credit_id': '537483fcc3a36815180026ee', 'de...       33245
# 201  [{'credit_id': '52fe44a3c3a36847f80a1a91', 'de...       30471
# 202  [{'credit_id': '52fe48f6c3a36847f818264f', 'de...          10
#
# [201 rows x 20 columns]

# %% [markdown]
# **The drop() function in pandas is used to remove rows or columns from a DataFrame. The behavior of the drop() function depends on the axis parameter:**
#
# 1. axis=0 (default): Drop rows (along the vertical axis).
# 2. axis=1: Drop columns (along the horizontal axis)

# %% [markdown]
# # **How to create new column**

# %% [markdown]
# **Create profit column**

# %%
# create profit column
# profit = revenue-budget
data.loc[:,'profit']=data.loc[:,'revenue']-data.loc[:,'budget']

# %% [markdown]
# The code calculates the profit for each row by subtracting the budget from the revenue and stores the result in a new column called profit in the DataFrame.
# 1. **data.loc[:, 'revenue']**: Accesses the revenue column.
# 2. **data.loc[:, 'budget']**: Accesses the budget column.

# %%
data.head()
# Out:
#      id     budget                                             genres  \
# 0  1127  220000000  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1  1762  190000000                     [{'id': 28, 'name': 'Action'}]
# 2  2771  280000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3  2323  195000000  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 4  2136  380000000  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
#
#      imdb_id orig_lang                               original_title  \
# 0  tt0848228        en                                 The Avengers
# 1  tt2820852        en                                    Furious 7
# 2  tt2395427        en                      Avengers: Age of Ultron
# 3  tt1399103        en               Transformers: Dark of the Moon
# 4  tt1298650        en  Pirates of the Caribbean: On Stranger Tides
#
#                                             overview  popularity  \
# 0  When an unexpected enemy emerges and threatens...   89.887648
# 1  Deckard Shaw seeks revenge against Dominic Tor...   27.275687
# 2  When Tony Stark tries to jumpstart a dormant p...   37.379420
# 3  Sam Witwicky takes his first tenuous steps int...    4.503505
# 4  Captain Jack Sparrow crosses paths with a woma...   27.887720
#
#                                            companies  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1  [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 2  [{'name': 'Marvel Studios', 'id': 420}, {'name...
# 3  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 4  [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
#
#                                            countries  ... runtime  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...  ...   143.0
# 1  [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...  ...   137.0
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...  ...   141.0
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...  ...   154.0
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...  ...   136.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                              tagline  \
# 0                            Some assembly required.
# 1                                Vengeance Hits Home
# 2                                A New Age Has Come.
# 3  The invasion we always feared. An enemy we nev...
# 4                        Live Forever Or Die Trying.
#
#                                          title  \
# 0                                 The Avengers
# 1                                    Furious 7
# 2                      Avengers: Age of Ultron
# 3               Transformers: Dark of the Moon
# 4  Pirates of the Caribbean: On Stranger Tides
#
#                                             Keywords  \
# 0  [{'id': 242, 'name': 'new york'}, {'id': 5539,...
# 1  [{'id': 830, 'name': 'car race'}, {'id': 3428,...
# 2  [{'id': 8828, 'name': 'marvel comic'}, {'id': ...
# 3  [{'id': 305, 'name': 'moon'}, {'id': 1612, 'na...
# 4  [{'id': 658, 'name': 'sea'}, {'id': 1316, 'nam...
#
#                                                 cast  \
# 0  [{'cast_id': 46, 'character': 'Tony Stark / Ir...
# 1  [{'cast_id': 17, 'character': 'Dominic Toretto...
# 2  [{'cast_id': 76, 'character': 'Tony Stark / Ir...
# 3  [{'cast_id': 3, 'character': 'Sam Witwicky', '...
# 4  [{'cast_id': 15, 'character': 'Captain Jack Sp...
#
#                                                 crew     revenue      profit
# 0  [{'credit_id': '52fe4495c3a368484e02b1cf', 'de...  1519557910  1299557910
# 1  [{'credit_id': '52fe4cc8c3a36847f823e681', 'de...  1506249360  1316249360
# 2  [{'credit_id': '55d5f7d4c3a3683e7e0016eb', 'de...  1405403694  1125403694
# 3  [{'credit_id': '537f0b740e0a2624b40044d0', 'de...  1123746996   928746996
# 4  [{'credit_id': '566b4f54c3a3683f56005151', 'de...  1045713802   665713802
#
# [5 rows x 21 columns]

# %% [markdown]
# **Create half_runtime by reducing runtime to half**

# %%
# create half_runtime by reducing runtime to half
data.loc[:,'half_runtime']=data.loc[:,'runtime']/2

# %% [markdown]
# The code computes half of the values in the runtime column by dividing it by 2 and stores the result in a new column called half_runtime in the DataFrame.
# *  **data.loc[:,'runtime'] :** fetches runtime column
# * **data.loc[:,'half_runtime']:** creates new halfruntime

# %%
data.head()
# Out:
#      id     budget                                             genres  \
# 0  1127  220000000  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1  1762  190000000                     [{'id': 28, 'name': 'Action'}]
# 2  2771  280000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3  2323  195000000  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 4  2136  380000000  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
#
#      imdb_id orig_lang                               original_title  \
# 0  tt0848228        en                                 The Avengers
# 1  tt2820852        en                                    Furious 7
# 2  tt2395427        en                      Avengers: Age of Ultron
# 3  tt1399103        en               Transformers: Dark of the Moon
# 4  tt1298650        en  Pirates of the Caribbean: On Stranger Tides
#
#                                             overview  popularity  \
# 0  When an unexpected enemy emerges and threatens...   89.887648
# 1  Deckard Shaw seeks revenge against Dominic Tor...   27.275687
# 2  When Tony Stark tries to jumpstart a dormant p...   37.379420
# 3  Sam Witwicky takes his first tenuous steps int...    4.503505
# 4  Captain Jack Sparrow crosses paths with a woma...   27.887720
#
#                                            companies  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1  [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 2  [{'name': 'Marvel Studios', 'id': 420}, {'name...
# 3  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 4  [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
#
#                                            countries  ...  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 1  [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...  ...
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
#
#                                              tagline  \
# 0                            Some assembly required.
# 1                                Vengeance Hits Home
# 2                                A New Age Has Come.
# 3  The invasion we always feared. An enemy we nev...
# 4                        Live Forever Or Die Trying.
#
#                                          title  \
# 0                                 The Avengers
# 1                                    Furious 7
# 2                      Avengers: Age of Ultron
# 3               Transformers: Dark of the Moon
# 4  Pirates of the Caribbean: On Stranger Tides
#
#                                             Keywords  \
# 0  [{'id': 242, 'name': 'new york'}, {'id': 5539,...
# 1  [{'id': 830, 'name': 'car race'}, {'id': 3428,...
# 2  [{'id': 8828, 'name': 'marvel comic'}, {'id': ...
# 3  [{'id': 305, 'name': 'moon'}, {'id': 1612, 'na...
# 4  [{'id': 658, 'name': 'sea'}, {'id': 1316, 'nam...
#
#                                                 cast  \
# 0  [{'cast_id': 46, 'character': 'Tony Stark / Ir...
# 1  [{'cast_id': 17, 'character': 'Dominic Toretto...
# 2  [{'cast_id': 76, 'character': 'Tony Stark / Ir...
# 3  [{'cast_id': 3, 'character': 'Sam Witwicky', '...
# 4  [{'cast_id': 15, 'character': 'Captain Jack Sp...
#
#                                                 crew     revenue      profit  \
# 0  [{'credit_id': '52fe4495c3a368484e02b1cf', 'de...  1519557910  1299557910
# 1  [{'credit_id': '52fe4cc8c3a36847f823e681', 'de...  1506249360  1316249360
# 2  [{'credit_id': '55d5f7d4c3a3683e7e0016eb', 'de...  1405403694  1125403694
# 3  [{'credit_id': '537f0b740e0a2624b40044d0', 'de...  1123746996   928746996
# 4  [{'credit_id': '566b4f54c3a3683f56005151', 'de...  1045713802   665713802
#
#    half_runtime
# 0          71.5
# 1          68.5
# 2          70.5
# 3          77.0
# 4          68.0
#
# [5 rows x 22 columns]

# %%
# to_datetime:convert released_date column into actual date
data.loc[:,'new_released_date']=pd.to_datetime(data.loc[:,'release_date'])
# Out:
# /tmp/ipykernel_57/1831284985.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data.loc[:,'new_released_date']=pd.to_datetime(data.loc[:,'release_date'])

# %% [markdown]
# This code converts the release_date column in the DataFrame to a datetime format and stores the result in a new column called new_released_date.
#
# * **pd.to_datetime()**: Converts the release_date column to a datetime object.
# * **data.loc[:, 'new_released_date']:** Stores the converted dates in a new column new_released_date.

# %%
data.head()
# Out:
#      id     budget                                             genres  \
# 0  1127  220000000  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1  1762  190000000                     [{'id': 28, 'name': 'Action'}]
# 2  2771  280000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3  2323  195000000  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 4  2136  380000000  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
#
#      imdb_id orig_lang                               original_title  \
# 0  tt0848228        en                                 The Avengers
# 1  tt2820852        en                                    Furious 7
# 2  tt2395427        en                      Avengers: Age of Ultron
# 3  tt1399103        en               Transformers: Dark of the Moon
# 4  tt1298650        en  Pirates of the Caribbean: On Stranger Tides
#
#                                             overview  popularity  \
# 0  When an unexpected enemy emerges and threatens...   89.887648
# 1  Deckard Shaw seeks revenge against Dominic Tor...   27.275687
# 2  When Tony Stark tries to jumpstart a dormant p...   37.379420
# 3  Sam Witwicky takes his first tenuous steps int...    4.503505
# 4  Captain Jack Sparrow crosses paths with a woma...   27.887720
#
#                                            companies  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1  [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 2  [{'name': 'Marvel Studios', 'id': 420}, {'name...
# 3  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 4  [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
#
#                                            countries  ...    status  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...  ...  Released
# 1  [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...  ...  Released
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...  ...  Released
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...  ...  Released
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...  ...  Released
#
#                                              tagline  \
# 0                            Some assembly required.
# 1                                Vengeance Hits Home
# 2                                A New Age Has Come.
# 3  The invasion we always feared. An enemy we nev...
# 4                        Live Forever Or Die Trying.
#
#                                          title  \
# 0                                 The Avengers
# 1                                    Furious 7
# 2                      Avengers: Age of Ultron
# 3               Transformers: Dark of the Moon
# 4  Pirates of the Caribbean: On Stranger Tides
#
#                                             Keywords  \
# 0  [{'id': 242, 'name': 'new york'}, {'id': 5539,...
# 1  [{'id': 830, 'name': 'car race'}, {'id': 3428,...
# 2  [{'id': 8828, 'name': 'marvel comic'}, {'id': ...
# 3  [{'id': 305, 'name': 'moon'}, {'id': 1612, 'na...
# 4  [{'id': 658, 'name': 'sea'}, {'id': 1316, 'nam...
#
#                                                 cast  \
# 0  [{'cast_id': 46, 'character': 'Tony Stark / Ir...
# 1  [{'cast_id': 17, 'character': 'Dominic Toretto...
# 2  [{'cast_id': 76, 'character': 'Tony Stark / Ir...
# 3  [{'cast_id': 3, 'character': 'Sam Witwicky', '...
# 4  [{'cast_id': 15, 'character': 'Captain Jack Sp...
#
#                                                 crew     revenue      profit  \
# 0  [{'credit_id': '52fe4495c3a368484e02b1cf', 'de...  1519557910  1299557910
# 1  [{'credit_id': '52fe4cc8c3a36847f823e681', 'de...  1506249360  1316249360
# 2  [{'credit_id': '55d5f7d4c3a3683e7e0016eb', 'de...  1405403694  1125403694
# 3  [{'credit_id': '537f0b740e0a2624b40044d0', 'de...  1123746996   928746996
# 4  [{'credit_id': '566b4f54c3a3683f56005151', 'de...  1045713802   665713802
#
#   half_runtime  new_released_date
# 0         71.5         2012-04-25
# 1         68.5         2015-04-01
# 2         70.5         2015-04-22
# 3         77.0         2011-06-28
# 4         68.0         2011-05-14
#
# [5 rows x 23 columns]

# %% [markdown]
# **Extract year**

# %%
# extract year from released_date(YYYY-MM-DD)
data.loc[:,'year']=data.loc[:,'new_released_date'].dt.year
# datetime:dt

# %% [markdown]
# This code extracts the year from the new_released_date column (which is in datetime format) and stores it in a new column called year.
# * **data.loc[:, 'new_released_date']:** Accesses the column with datetime values.
# * **dt.year:** Extracts the year component from the datetime object.
# * **data.loc[:, 'year']:** Saves the extracted year in a new column named year.

# %%
data.head()
# Out:
#      id     budget                                             genres  \
# 0  1127  220000000  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1  1762  190000000                     [{'id': 28, 'name': 'Action'}]
# 2  2771  280000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3  2323  195000000  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 4  2136  380000000  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
#
#      imdb_id orig_lang                               original_title  \
# 0  tt0848228        en                                 The Avengers
# 1  tt2820852        en                                    Furious 7
# 2  tt2395427        en                      Avengers: Age of Ultron
# 3  tt1399103        en               Transformers: Dark of the Moon
# 4  tt1298650        en  Pirates of the Caribbean: On Stranger Tides
#
#                                             overview  popularity  \
# 0  When an unexpected enemy emerges and threatens...   89.887648
# 1  Deckard Shaw seeks revenge against Dominic Tor...   27.275687
# 2  When Tony Stark tries to jumpstart a dormant p...   37.379420
# 3  Sam Witwicky takes his first tenuous steps int...    4.503505
# 4  Captain Jack Sparrow crosses paths with a woma...   27.887720
#
#                                            companies  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1  [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 2  [{'name': 'Marvel Studios', 'id': 420}, {'name...
# 3  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 4  [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
#
#                                            countries  ...  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 1  [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...  ...
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
#
#                                              tagline  \
# 0                            Some assembly required.
# 1                                Vengeance Hits Home
# 2                                A New Age Has Come.
# 3  The invasion we always feared. An enemy we nev...
# 4                        Live Forever Or Die Trying.
#
#                                          title  \
# 0                                 The Avengers
# 1                                    Furious 7
# 2                      Avengers: Age of Ultron
# 3               Transformers: Dark of the Moon
# 4  Pirates of the Caribbean: On Stranger Tides
#
#                                             Keywords  \
# 0  [{'id': 242, 'name': 'new york'}, {'id': 5539,...
# 1  [{'id': 830, 'name': 'car race'}, {'id': 3428,...
# 2  [{'id': 8828, 'name': 'marvel comic'}, {'id': ...
# 3  [{'id': 305, 'name': 'moon'}, {'id': 1612, 'na...
# 4  [{'id': 658, 'name': 'sea'}, {'id': 1316, 'nam...
#
#                                                 cast  \
# 0  [{'cast_id': 46, 'character': 'Tony Stark / Ir...
# 1  [{'cast_id': 17, 'character': 'Dominic Toretto...
# 2  [{'cast_id': 76, 'character': 'Tony Stark / Ir...
# 3  [{'cast_id': 3, 'character': 'Sam Witwicky', '...
# 4  [{'cast_id': 15, 'character': 'Captain Jack Sp...
#
#                                                 crew     revenue      profit  \
# 0  [{'credit_id': '52fe4495c3a368484e02b1cf', 'de...  1519557910  1299557910
# 1  [{'credit_id': '52fe4cc8c3a36847f823e681', 'de...  1506249360  1316249360
# 2  [{'credit_id': '55d5f7d4c3a3683e7e0016eb', 'de...  1405403694  1125403694
# 3  [{'credit_id': '537f0b740e0a2624b40044d0', 'de...  1123746996   928746996
# 4  [{'credit_id': '566b4f54c3a3683f56005151', 'de...  1045713802   665713802
#
#   half_runtime new_released_date  year
# 0         71.5        2012-04-25  2012
# 1         68.5        2015-04-01  2015
# 2         70.5        2015-04-22  2015
# 3         77.0        2011-06-28  2011
# 4         68.0        2011-05-14  2011
#
# [5 rows x 24 columns]

# %% [markdown]
# **Extract month**

# %%
# extract month
data.loc[:,'month']=data.loc[:,'new_released_date'].dt.month

# %% [markdown]
# This code extracts the month from the new_released_date column (which is in datetime format) and stores it in a new column called month.
# * **data.loc[:, 'new_released_date']:** Accesses the column with datetime values.
# * **dt.month:** Extracts the month component from the datetime object.
# * **data.loc[:, 'month']:** Saves the extracted month in a new column named month.

# %%
data.head()
# Out:
#      id     budget                                             genres  \
# 0  1127  220000000  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1  1762  190000000                     [{'id': 28, 'name': 'Action'}]
# 2  2771  280000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3  2323  195000000  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 4  2136  380000000  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
#
#      imdb_id orig_lang                               original_title  \
# 0  tt0848228        en                                 The Avengers
# 1  tt2820852        en                                    Furious 7
# 2  tt2395427        en                      Avengers: Age of Ultron
# 3  tt1399103        en               Transformers: Dark of the Moon
# 4  tt1298650        en  Pirates of the Caribbean: On Stranger Tides
#
#                                             overview  popularity  \
# 0  When an unexpected enemy emerges and threatens...   89.887648
# 1  Deckard Shaw seeks revenge against Dominic Tor...   27.275687
# 2  When Tony Stark tries to jumpstart a dormant p...   37.379420
# 3  Sam Witwicky takes his first tenuous steps int...    4.503505
# 4  Captain Jack Sparrow crosses paths with a woma...   27.887720
#
#                                            companies  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1  [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 2  [{'name': 'Marvel Studios', 'id': 420}, {'name...
# 3  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 4  [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
#
#                                            countries  ...  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 1  [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...  ...
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
#
#                                          title  \
# 0                                 The Avengers
# 1                                    Furious 7
# 2                      Avengers: Age of Ultron
# 3               Transformers: Dark of the Moon
# 4  Pirates of the Caribbean: On Stranger Tides
#
#                                             Keywords  \
# 0  [{'id': 242, 'name': 'new york'}, {'id': 5539,...
# 1  [{'id': 830, 'name': 'car race'}, {'id': 3428,...
# 2  [{'id': 8828, 'name': 'marvel comic'}, {'id': ...
# 3  [{'id': 305, 'name': 'moon'}, {'id': 1612, 'na...
# 4  [{'id': 658, 'name': 'sea'}, {'id': 1316, 'nam...
#
#                                                 cast  \
# 0  [{'cast_id': 46, 'character': 'Tony Stark / Ir...
# 1  [{'cast_id': 17, 'character': 'Dominic Toretto...
# 2  [{'cast_id': 76, 'character': 'Tony Stark / Ir...
# 3  [{'cast_id': 3, 'character': 'Sam Witwicky', '...
# 4  [{'cast_id': 15, 'character': 'Captain Jack Sp...
#
#                                                 crew     revenue      profit  \
# 0  [{'credit_id': '52fe4495c3a368484e02b1cf', 'de...  1519557910  1299557910
# 1  [{'credit_id': '52fe4cc8c3a36847f823e681', 'de...  1506249360  1316249360
# 2  [{'credit_id': '55d5f7d4c3a3683e7e0016eb', 'de...  1405403694  1125403694
# 3  [{'credit_id': '537f0b740e0a2624b40044d0', 'de...  1123746996   928746996
# 4  [{'credit_id': '566b4f54c3a3683f56005151', 'de...  1045713802   665713802
#
#   half_runtime new_released_date  year  month
# 0         71.5        2012-04-25  2012      4
# 1         68.5        2015-04-01  2015      4
# 2         70.5        2015-04-22  2015      4
# 3         77.0        2011-06-28  2011      6
# 4         68.0        2011-05-14  2011      5
#
# [5 rows x 25 columns]

# %% [markdown]
# **Extract month_name**

# %%
# extract month_name
data.loc[:,'month_name']=data.loc[:,'new_released_date'].dt.month_name()

# %% [markdown]
# This code extracts the full name of the month from the new_released_date column (which is in datetime format) and stores it in a new column called month_name.
# * **data.loc[:, 'new_released_date']:** Accesses the column with datetime values.
# * **dt.month_name():** Extracts the full month name (e.g., "January", "February") from the datetime object.
# * **data.loc[:, 'month_name']:** Stores the extracted month names in a new column named month_name.

# %%
df.head()
# Out:
#      id                              belongs_to_collection   budget  \
# 0   666  [{'id': 86668, 'name': 'Elektra Luxx Collectio...        0
# 1  1564  [{'id': 87186, 'name': 'The Boondock Saints Co...  6000000
# 2  1500  [{'id': 473843, 'name': 'Stake Land Collection...   650000
# 3  2277  [{'id': 286038, 'name': 'Dead Snow Collection'...        0
# 4   515  [{'id': 206559, 'name': 'StreetDance Collectio...        0
#
#                                               genres  \
# 0  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 1  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 2  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 3  [{'id': 27, 'name': 'Horror'}, {'id': 28, 'nam...
# 4  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
#
#                              homepage    imdb_id original_language  \
# 0   http://www.elektraluxx-movie.com/  tt1340773                en
# 1    http://www.theboondocksaints.com  tt0144117                en
# 2    http://www.stakelandthefilm.com/  tt1464580                en
# 3            http://www.deadsnow.com/  tt2832470                no
# 4  http://www.highstrungthemovie.com/  tt3451230                en
#
#         original_title                                           overview  \
# 0         Elektra Luxx  A favor for a woman from her past throws the l...
# 1  The Boondock Saints  With a God-inspired moral obligation to act ag...
# 2           Stake Land  Martin was a normal teenage boy before the cou...
# 3            Død Snø 2  The gruesome Nazi Zombies are back to finish t...
# 4          High Strung  When a hip hop violinist busking in the New Yo...
#
#    popularity  ... release_date runtime  \
# 0    4.118699  ...      3/14/10    98.0
# 1   12.457908  ...      1/22/99   108.0
# 2    7.814255  ...      9/30/10    98.0
# 3   10.287127  ...      2/12/14   100.0
# 4    6.625607  ...       4/8/16    96.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...  Released
# 4           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                       tagline                      title  \
# 0  From adult film star to functioning adult.               Elektra Luxx
# 1         Thy Kingdom Come. Thy Will Be Done.        The Boondock Saints
# 2    The Most Dangerous Thing Is To Be Alive.                 Stake Land
# 3                     Heads up. They're back.  Dead Snow 2: Red vs. Dead
# 4              See the music. Hear the dance.                High Strung
#
#                                             Keywords  \
# 0  [{'id': 10183, 'name': 'independent film'}, {'...
# 1  [{'id': 1679, 'name': 'arbitrary law'}, {'id':...
# 2  [{'id': 255, 'name': 'male nudity'}, {'id': 13...
# 3  [{'id': 2652, 'name': 'nazis'}, {'id': 9663, '...
# 4  [{'id': 1691, 'name': 'dance'}, {'id': 4721, '...
#
#                                                 cast  \
# 0  [{'cast_id': 3, 'character': 'Elektra Luxx', '...
# 1  [{'cast_id': 1, 'character': 'Paul Smecker', '...
# 2  [{'cast_id': 2, 'character': 'Belle', 'credit_...
# 3  [{'cast_id': 19, 'character': 'Martin', 'credi...
# 4  [{'cast_id': 3, 'character': 'Ruby', 'credit_i...
#
#                                                 crew revenue
# 0  [{'credit_id': '52fe48f6c3a36847f818264f', 'de...      10
# 1  [{'credit_id': '52fe44a3c3a36847f80a1a91', 'de...   30471
# 2  [{'credit_id': '537483fcc3a36815180026ee', 'de...   33245
# 3  [{'credit_id': '52fe4ebfc3a36847f82a57f3', 'de...   37473
# 4  [{'credit_id': '56be2f489251417359004545', 'de...   53447
#
# [5 rows x 23 columns]

# %% [markdown]
# df.head()

# %% [markdown]
# # **replace**
# In Pandas, the replace() method is used to substitute specific values in a DataFrame or Series with new values. This is useful for cleaning data, standardizing values, or replacing missing or incorrect data.

# %%
# can you replace en in orig_lang as english
data.loc[:,'orig_lang'].replace({'en':'english'},inplace=True)
# Out:
# /tmp/ipykernel_57/2991815139.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data.loc[:,'orig_lang'].replace({'en':'english'},inplace=True)

# %% [markdown]
# This code replaces the value 'en' in the orig_lang column with 'english' for all rows in the DataFrame, modifying the column in place.
# 1. **data.loc[:, 'orig_lang']:**
# Accesses the orig_lang column in the DataFrame.
# 2. **.replace({'en': 'english'}):**
# Replaces the value 'en' with 'english'.
# 3.**inplace=True:**
# Ensures the changes are made directly to the original DataFrame without creating a new one.

# %%
data.head()
# Out:
#      id     budget                                             genres  \
# 0  1127  220000000  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1  1762  190000000                     [{'id': 28, 'name': 'Action'}]
# 2  2771  280000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3  2323  195000000  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 4  2136  380000000  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
#
#      imdb_id orig_lang                               original_title  \
# 0  tt0848228   english                                 The Avengers
# 1  tt2820852   english                                    Furious 7
# 2  tt2395427   english                      Avengers: Age of Ultron
# 3  tt1399103   english               Transformers: Dark of the Moon
# 4  tt1298650   english  Pirates of the Caribbean: On Stranger Tides
#
#                                             overview  popularity  \
# 0  When an unexpected enemy emerges and threatens...   89.887648
# 1  Deckard Shaw seeks revenge against Dominic Tor...   27.275687
# 2  When Tony Stark tries to jumpstart a dormant p...   37.379420
# 3  Sam Witwicky takes his first tenuous steps int...    4.503505
# 4  Captain Jack Sparrow crosses paths with a woma...   27.887720
#
#                                            companies  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1  [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 2  [{'name': 'Marvel Studios', 'id': 420}, {'name...
# 3  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 4  [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
#
#                                            countries  ...  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 1  [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...  ...
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
#
#                                             Keywords  \
# 0  [{'id': 242, 'name': 'new york'}, {'id': 5539,...
# 1  [{'id': 830, 'name': 'car race'}, {'id': 3428,...
# 2  [{'id': 8828, 'name': 'marvel comic'}, {'id': ...
# 3  [{'id': 305, 'name': 'moon'}, {'id': 1612, 'na...
# 4  [{'id': 658, 'name': 'sea'}, {'id': 1316, 'nam...
#
#                                                 cast  \
# 0  [{'cast_id': 46, 'character': 'Tony Stark / Ir...
# 1  [{'cast_id': 17, 'character': 'Dominic Toretto...
# 2  [{'cast_id': 76, 'character': 'Tony Stark / Ir...
# 3  [{'cast_id': 3, 'character': 'Sam Witwicky', '...
# 4  [{'cast_id': 15, 'character': 'Captain Jack Sp...
#
#                                                 crew     revenue      profit  \
# 0  [{'credit_id': '52fe4495c3a368484e02b1cf', 'de...  1519557910  1299557910
# 1  [{'credit_id': '52fe4cc8c3a36847f823e681', 'de...  1506249360  1316249360
# 2  [{'credit_id': '55d5f7d4c3a3683e7e0016eb', 'de...  1405403694  1125403694
# 3  [{'credit_id': '537f0b740e0a2624b40044d0', 'de...  1123746996   928746996
# 4  [{'credit_id': '566b4f54c3a3683f56005151', 'de...  1045713802   665713802
#
#   half_runtime new_released_date  year month  month_name
# 0         71.5        2012-04-25  2012     4       April
# 1         68.5        2015-04-01  2015     4       April
# 2         70.5        2015-04-22  2015     4       April
# 3         77.0        2011-06-28  2011     6        June
# 4         68.0        2011-05-14  2011     5         May
#
# [5 rows x 26 columns]

# %%
# can you replace hi as hindi
data.loc[:,'orig_lang'].replace({'hi':'hindi'},inplace=True)

# %% [markdown]
# This code replaces the value 'hi' in the orig_lang column with 'hindi' for all rows in the DataFrame, updating the column in place.
# 1. **data.loc[:, 'orig_lang']:**
# Accesses the orig_lang column in the DataFrame.
# 2. **.replace({'hi': 'hindi'}):**
# Replaces all occurrences of 'hi' with 'hindi'.
# 3. **inplace=True:**
# Ensures the changes are applied directly to the original DataFrame without creating a new one.

# %%
data.head()
# Out:
#      id     budget                                             genres  \
# 0  1127  220000000  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1  1762  190000000                     [{'id': 28, 'name': 'Action'}]
# 2  2771  280000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3  2323  195000000  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 4  2136  380000000  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
#
#      imdb_id orig_lang                               original_title  \
# 0  tt0848228   english                                 The Avengers
# 1  tt2820852   english                                    Furious 7
# 2  tt2395427   english                      Avengers: Age of Ultron
# 3  tt1399103   english               Transformers: Dark of the Moon
# 4  tt1298650   english  Pirates of the Caribbean: On Stranger Tides
#
#                                             overview  popularity  \
# 0  When an unexpected enemy emerges and threatens...   89.887648
# 1  Deckard Shaw seeks revenge against Dominic Tor...   27.275687
# 2  When Tony Stark tries to jumpstart a dormant p...   37.379420
# 3  Sam Witwicky takes his first tenuous steps int...    4.503505
# 4  Captain Jack Sparrow crosses paths with a woma...   27.887720
#
#                                            companies  \
# 0  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1  [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 2  [{'name': 'Marvel Studios', 'id': 420}, {'name...
# 3  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 4  [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
#
#                                            countries  ...  \
# 0  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 1  [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...  ...
# 2  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 3  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 4  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
#
#                                             Keywords  \
# 0  [{'id': 242, 'name': 'new york'}, {'id': 5539,...
# 1  [{'id': 830, 'name': 'car race'}, {'id': 3428,...
# 2  [{'id': 8828, 'name': 'marvel comic'}, {'id': ...
# 3  [{'id': 305, 'name': 'moon'}, {'id': 1612, 'na...
# 4  [{'id': 658, 'name': 'sea'}, {'id': 1316, 'nam...
#
#                                                 cast  \
# 0  [{'cast_id': 46, 'character': 'Tony Stark / Ir...
# 1  [{'cast_id': 17, 'character': 'Dominic Toretto...
# 2  [{'cast_id': 76, 'character': 'Tony Stark / Ir...
# 3  [{'cast_id': 3, 'character': 'Sam Witwicky', '...
# 4  [{'cast_id': 15, 'character': 'Captain Jack Sp...
#
#                                                 crew     revenue      profit  \
# 0  [{'credit_id': '52fe4495c3a368484e02b1cf', 'de...  1519557910  1299557910
# 1  [{'credit_id': '52fe4cc8c3a36847f823e681', 'de...  1506249360  1316249360
# 2  [{'credit_id': '55d5f7d4c3a3683e7e0016eb', 'de...  1405403694  1125403694
# 3  [{'credit_id': '537f0b740e0a2624b40044d0', 'de...  1123746996   928746996
# 4  [{'credit_id': '566b4f54c3a3683f56005151', 'de...  1045713802   665713802
#
#   half_runtime new_released_date  year month  month_name
# 0         71.5        2012-04-25  2012     4       April
# 1         68.5        2015-04-01  2015     4       April
# 2         70.5        2015-04-22  2015     4       April
# 3         77.0        2011-06-28  2011     6        June
# 4         68.0        2011-05-14  2011     5         May
#
# [5 rows x 26 columns]

# %% [markdown]
# # **Filter data using boolean indexing**
#
# Boolean indexing is used to filter rows in a DataFrame based on conditions. It returns only the rows where the condition is True.
#
# df[df['Age'] > 25]
#
# **Note:**
#
# Uses True/False conditions
#
# & → AND condition
#
# | → OR condition
#
# Fast and efficient for filtering data

# %% [markdown]
# ### **Filter data using single condition**
# Use comparison operations to filter data based on single condition
#
# **data.loc[df['column_name'] == value]**

# %%
# find all the movies released in english
data.loc[data.loc[:,'orig_lang']=='english']
# Out:
#        id     budget                                             genres  \
# 0    1127  220000000  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1    1762  190000000                     [{'id': 28, 'name': 'Action'}]
# 2    2771  280000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3    2323  195000000  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 4    2136  380000000  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# ..    ...        ...                                                ...
# 197    23          0  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 198   515          0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 200  1500     650000  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 201  1564    6000000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 202   666          0  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
#
#        imdb_id orig_lang                               original_title  \
# 0    tt0848228   english                                 The Avengers
# 1    tt2820852   english                                    Furious 7
# 2    tt2395427   english                      Avengers: Age of Ultron
# 3    tt1399103   english               Transformers: Dark of the Moon
# 4    tt1298650   english  Pirates of the Caribbean: On Stranger Tides
# ..         ...       ...                                          ...
# 197  tt2105044   english                                        V/H/S
# 198  tt3451230   english                                  High Strung
# 200  tt1464580   english                                   Stake Land
# 201  tt0144117   english                          The Boondock Saints
# 202  tt1340773   english                                 Elektra Luxx
#
#                                               overview  popularity  \
# 0    When an unexpected enemy emerges and threatens...   89.887648
# 1    Deckard Shaw seeks revenge against Dominic Tor...   27.275687
# 2    When Tony Stark tries to jumpstart a dormant p...   37.379420
# 3    Sam Witwicky takes his first tenuous steps int...    4.503505
# 4    Captain Jack Sparrow crosses paths with a woma...   27.887720
# ..                                                 ...         ...
# 197  When a group of misfits is hired by an unknown...    7.820787
# 198  When a hip hop violinist busking in the New Yo...    6.625607
# 200  Martin was a normal teenage boy before the cou...    7.814255
# 201  With a God-inspired moral obligation to act ag...   12.457908
# 202  A favor for a woman from her past throws the l...    4.118699
#
#                                              companies  \
# 0    [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1    [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 2    [{'name': 'Marvel Studios', 'id': 420}, {'name...
# 3    [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 4    [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
# ..                                                 ...
# 197  [{'name': 'The Collective', 'id': 15156}, {'na...
# 198  [{'name': 'Castel Film Studio', 'id': 4573}, {...
# 200  [{'name': 'Glass Eye Pix', 'id': 1360}, {'name...
# 201  [{'name': 'Franchise Pictures', 'id': 1403}, {...
# 202         [{'name': 'Gato Negro Films', 'id': 5295}]
#
#                                              countries  ...  \
# 0    [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 1    [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...  ...
# 2    [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 3    [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 4    [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# ..                                                 ...  ...
# 197  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 198  [{'iso_3166_1': 'RO', 'name': 'Romania'}, {'is...  ...
# 200  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 201  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  ...
# 202  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
#
#                                               Keywords  \
# 0    [{'id': 242, 'name': 'new york'}, {'id': 5539,...
# 1    [{'id': 830, 'name': 'car race'}, {'id': 3428,...
# 2    [{'id': 8828, 'name': 'marvel comic'}, {'id': ...
# 3    [{'id': 305, 'name': 'moon'}, {'id': 1612, 'na...
# 4    [{'id': 658, 'name': 'sea'}, {'id': 1316, 'nam...
# ..                                                 ...
# 197  [{'id': 6435, 'name': 'webcam'}, {'id': 9706, ...
# 198  [{'id': 1691, 'name': 'dance'}, {'id': 4721, '...
# 200  [{'id': 255, 'name': 'male nudity'}, {'id': 13...
# 201  [{'id': 1679, 'name': 'arbitrary law'}, {'id':...
# 202  [{'id': 10183, 'name': 'independent film'}, {'...
#
#                                                   cast  \
# 0    [{'cast_id': 46, 'character': 'Tony Stark / Ir...
# 1    [{'cast_id': 17, 'character': 'Dominic Toretto...
# 2    [{'cast_id': 76, 'character': 'Tony Stark / Ir...
# 3    [{'cast_id': 3, 'character': 'Sam Witwicky', '...
# 4    [{'cast_id': 15, 'character': 'Captain Jack Sp...
# ..                                                 ...
# 197  [{'cast_id': 1, 'character': 'Gary', 'credit_i...
# 198  [{'cast_id': 3, 'character': 'Ruby', 'credit_i...
# 200  [{'cast_id': 2, 'character': 'Belle', 'credit_...
# 201  [{'cast_id': 1, 'character': 'Paul Smecker', '...
# 202  [{'cast_id': 3, 'character': 'Elektra Luxx', '...
#
#                                                   crew     revenue  \
# 0    [{'credit_id': '52fe4495c3a368484e02b1cf', 'de...  1519557910
# 1    [{'credit_id': '52fe4cc8c3a36847f823e681', 'de...  1506249360
# 2    [{'credit_id': '55d5f7d4c3a3683e7e0016eb', 'de...  1405403694
# 3    [{'credit_id': '537f0b740e0a2624b40044d0', 'de...  1123746996
# 4    [{'credit_id': '566b4f54c3a3683f56005151', 'de...  1045713802
# ..                                                 ...         ...
# 197  [{'credit_id': '52fe48ee9251416c9109d113', 'de...      100345
# 198  [{'credit_id': '56be2f489251417359004545', 'de...       53447
# 200  [{'credit_id': '537483fcc3a36815180026ee', 'de...       33245
# 201  [{'credit_id': '52fe44a3c3a36847f80a1a91', 'de...       30471
# 202  [{'credit_id': '52fe48f6c3a36847f818264f', 'de...          10
#
#          profit half_runtime new_released_date  year month  month_name
# 0    1299557910         71.5        2012-04-25  2012     4       April
# 1    1316249360         68.5        2015-04-01  2015     4       April
# 2    1125403694         70.5        2015-04-22  2015     4       April
# 3     928746996         77.0        2011-06-28  2011     6        June
# 4     665713802         68.0        2011-05-14  2011     5         May
# ..          ...          ...               ...   ...   ...         ...
# 197      100345         58.0        2012-07-28  2012     7        July
# 198       53447         48.0        2016-04-08  2016     4       April
# 200     -616755         49.0        2010-09-30  2010     9   September
# 201    -5969529         54.0        1999-01-22  1999     1     January
# 202          10         49.0        2010-03-14  2010     3       March
#
# [186 rows x 26 columns]

# %%
#  find all the movies released in hindi
data.loc[data.loc[:,'orig_lang']=='hindi']
# Out:
# Empty DataFrame
# Columns: [id, budget, genres, imdb_id, orig_lang, original_title, overview, popularity, companies, countries, release_date, runtime, spoken_languages, status, tagline, title, Keywords, cast, crew, revenue, profit, half_runtime, new_released_date, year, month, month_name]
# Index: []
#
# [0 rows x 26 columns]

# %%
# find all the movie released after 2014
data.loc[data.loc[:,'year']>2014]
# Out:
#        id     budget                                             genres  \
# 1    1762  190000000                     [{'id': 28, 'name': 'Action'}]
# 2    2771  280000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 5    2563  200000000  [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 15   2738  245000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 17   2127  200000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 22   2327   58000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 32    295  160000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 36   1631  260000000  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 45    212    7000000  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 50   2350    8000000  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 54   1125  105000000  [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 59    838  150000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 62   1716  152000000  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# 67    315  175000000  [{'id': 10751, 'name': 'Family'}, {'id': 35, '...
# 73   2432   40000000                     [{'id': 27, 'name': 'Horror'}]
# 76   1644   61000000                     [{'id': 28, 'name': 'Action'}]
# 85   1039  135000000  [{'id': 14, 'name': 'Fantasy'}, {'id': 28, 'na...
# 86   1094    6000000  [{'id': 18, 'name': 'Drama'}, {'id': 80, 'name...
# 90    819          0  [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...
# 92    810   75000000                   [{'id': 53, 'name': 'Thriller'}]
# 96   2275   60000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 118  2392    5500000  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 125   700   40000000  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 128   352    7200000  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# 131  2031    1200000  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...
# 132  2334    9500000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 138  2891   25000000                     [{'id': 27, 'name': 'Horror'}]
# 140   549    9000000  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 152  1515   10000000                     [{'id': 27, 'name': 'Horror'}]
# 198   515          0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
#
#        imdb_id orig_lang                                    original_title  \
# 1    tt2820852   english                                         Furious 7
# 2    tt2395427   english                           Avengers: Age of Ultron
# 5    tt2277860   english                                      Finding Dory
# 15   tt2379713   english                                           Spectre
# 17   tt3896198   english                    Guardians of the Galaxy Vol. 2
# 22   tt1431045   english                                          Deadpool
# 32   tt1951266   english             The Hunger Games: Mockingjay - Part 2
# 36   tt3371366   english                     Transformers: The Last Knight
# 45   tt0073195   english                                              Jaws
# 50   tt0070047   english                                      The Exorcist
# 54   tt3416828   english                         Ice Age: Collision Course
# 59   tt1392190   english                                Mad Max: Fury Road
# 62   tt3450958   english                    War for the Planet of the Apes
# 67   tt3606752   english                                            Cars 3
# 73   tt3065204   english                                   The Conjuring 2
# 76   tt4046784   english                    Maze Runner: The Scorch Trials
# 85   tt3949660   english  Teenage Mutant Ninja Turtles: Out of the Shadows
# 86   tt0068646   english                                     The Godfather
# 90   tt2974918   english            Alvin and the Chipmunks: The Road Chip
# 92   tt3062096   english                                           Inferno
# 96   tt3300542   english                                 London Has Fallen
# 118  tt0059800   english                                       Thunderball
# 125  tt2869728   english                                      Ride Along 2
# 128  tt0066995   english                              Diamonds Are Forever
# 131  tt0073629   english                     The Rocky Horror Picture Show
# 132  tt0062512   english                               You Only Live Twice
# 138  tt0498381   english                                             Rings
# 140  tt4361050   english                             Ouija: Origin of Evil
# 152  tt2752772   english                                        Sinister 2
# 198  tt3451230   english                                       High Strung
#
#                                               overview  popularity  \
# 1    Deckard Shaw seeks revenge against Dominic Tor...   27.275687
# 2    When Tony Stark tries to jumpstart a dormant p...   37.379420
# 5    Dory is reunited with her friends Nemo and Mar...   14.477677
# 15   A cryptic message from Bond‚Äôs past sends him...   24.926577
# 17   The Guardians must fight to keep their newfoun...  185.330992
# 22   Deadpool tells the origin story of former Spec...  187.860492
# 32   With the nation of Panem in a full scale war, ...   26.628178
# 36   Autobots and Decepticons are at war, with huma...   39.186819
# 45   An insatiable great white shark terrorizes the...   19.726114
# 50   12-year-old Regan MacNeil begins to adapt an e...   12.137595
# 54   Set after the events of Continental Drift, Scr...   20.151037
# 59   An apocalyptic story set in the furthest reach...   29.361780
# 62   Caesar and his apes are forced into a deadly c...  146.161786
# 67   Blindsided by a new generation of blazing-fast...   19.148182
# 73   Lorraine and Ed Warren travel to north London ...   14.767317
# 76   Thomas and his fellow Gladers face their great...   41.225769
# 85   After supervillain Shredder escapes custody, h...   13.047776
# 86   Spanning the years 1945 to 1955, a chronicle o...   41.109264
# 90   Through a series of misunderstandings, Alvin, ...   14.307672
# 92   After waking up in a hospital with amnesia, pr...   18.311054
# 96   In London for the Prime Minister's funeral, Mi...   15.037993
# 118  A criminal organization has obtained two nucle...   10.517835
# 125  As his wedding day approaches, Ben heads to Mi...    9.420931
# 128  Diamonds are stolen only to be sold again in t...   12.004910
# 131  Sweethearts Brad and Janet, stuck with a flat ...    8.699428
# 132  A mysterious space craft kidnaps a Russian and...   10.359669
# 138  Julia becomes worried about her boyfriend, Hol...   24.535733
# 140  In 1965 Los Angeles, a widowed mother and her ...   10.182974
# 152  A young mother and her twin sons move into a r...   17.602928
# 198  When a hip hop violinist busking in the New Yo...    6.625607
#
#                                              companies  \
# 1    [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 2    [{'name': 'Marvel Studios', 'id': 420}, {'name...
# 5    [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
# 15   [{'name': 'Columbia Pictures', 'id': 5}, {'nam...
# 17   [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
# 22   [{'name': 'Twentieth Century Fox Film Corporat...
# 32   [{'name': 'Studio Babelsberg', 'id': 264}, {'n...
# 36   [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 45   [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 50   [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 54   [{'name': 'Blue Sky Studios', 'id': 9383}, {'n...
# 59   [{'name': 'Village Roadshow Pictures', 'id': 7...
# 62     [{'name': 'Chernin Entertainment', 'id': 7076}]
# 67   [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
# 73   [{'name': 'New Line Cinema', 'id': 12}, {'name...
# 76   [{'name': 'Gotham Group', 'id': 3672}, {'name'...
# 85   [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 86   [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 90   [{'name': 'Regency Enterprises', 'id': 508}, {...
# 92   [{'name': 'Columbia Pictures', 'id': 5}, {'nam...
# 96   [{'name': 'Millennium Films', 'id': 10254}, {'...
# 118  [{'name': 'Eon Productions', 'id': 7576}, {'na...
# 125  [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 128  [{'name': 'United Artists', 'id': 60}, {'name'...
# 131  [{'name': 'Twentieth Century Fox Film Corporat...
# 132          [{'name': 'Eon Productions', 'id': 7576}]
# 138  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 140  [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 152  [{'name': 'Alliance Films', 'id': 2514}, {'nam...
# 198  [{'name': 'Castel Film Studio', 'id': 4573}, {...
#
#                                              countries  ...  \
# 1    [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...  ...
# 2    [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 5    [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 15   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...  ...
# 17   [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 22   [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 32   [{'iso_3166_1': 'DE', 'name': 'Germany'}, {'is...  ...
# 36   [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 45   [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 50   [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 54   [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 59   [{'iso_3166_1': 'AU', 'name': 'Australia'}, {'...  ...
# 62   [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  ...
# 67   [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 73   [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  ...
# 76   [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 85   [{'iso_3166_1': 'CN', 'name': 'China'}, {'iso_...  ...
# 86   [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 90   [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 92   [{'iso_3166_1': 'HU', 'name': 'Hungary'}, {'is...  ...
# 96   [{'iso_3166_1': 'BG', 'name': 'Bulgaria'}, {'i...  ...
# 118  [{'iso_3166_1': 'BS', 'name': 'Bahamas'}, {'is...  ...
# 125  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 128  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...  ...
# 131  [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...  ...
# 132   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]  ...
# 138  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 140  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 152  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 198  [{'iso_3166_1': 'RO', 'name': 'Romania'}, {'is...  ...
#
#                                               Keywords  \
# 1    [{'id': 830, 'name': 'car race'}, {'id': 3428,...
# 2    [{'id': 8828, 'name': 'marvel comic'}, {'id': ...
# 5    [{'id': 1357, 'name': 'fish'}, {'id': 1453, 'n...
# 15   [{'id': 470, 'name': 'spy'}, {'id': 818, 'name...
# 17   [{'id': 9663, 'name': 'sequel'}, {'id': 9715, ...
# 22   [{'id': 2095, 'name': 'anti hero'}, {'id': 307...
# 32   [{'id': 2020, 'name': 'revolution'}, {'id': 26...
# 36   [{'id': 10466, 'name': 'knight'}, {'id': 10607...
# 45   [{'id': 1495, 'name': 'fishing'}, {'id': 1913,...
# 50   [{'id': 2626, 'name': 'exorcism'}, {'id': 3649...
# 54   [{'id': 657, 'name': 'fire'}, {'id': 1445, 'na...
# 59   [{'id': 2964, 'name': 'future'}, {'id': 3713, ...
# 62   [{'id': 818, 'name': 'based on novel'}, {'id':...
# 67   [{'id': 10987, 'name': 'cgi'}, {'id': 11500, '...
# 73   [{'id': 212, 'name': 'london england'}, {'id':...
# 76   [{'id': 818, 'name': 'based on novel'}, {'id':...
# 85   [{'id': 380, 'name': 'brother brother relation...
# 86   [{'id': 131, 'name': 'italy'}, {'id': 699, 'na...
# 90   [{'id': 10986, 'name': 'chipmunk'}, {'id': 109...
# 92   [{'id': 131, 'name': 'italy'}, {'id': 818, 'na...
# 96   [{'id': 212, 'name': 'london england'}, {'id':...
# 118  [{'id': 90, 'name': 'paris'}, {'id': 1196, 'na...
# 125  [{'id': 6149, 'name': 'police'}, {'id': 9663, ...
# 128  [{'id': 470, 'name': 'spy'}, {'id': 1721, 'nam...
# 131  [{'id': 108, 'name': 'transvestism'}, {'id': 2...
# 132  [{'id': 212, 'name': 'london england'}, {'id':...
# 138  [{'id': 3298, 'name': 'hallucination'}, {'id':...
# 140  [{'id': 6152, 'name': 'supernatural'}, {'id': ...
# 152  [{'id': 3358, 'name': 'haunted house'}, {'id':...
# 198  [{'id': 1691, 'name': 'dance'}, {'id': 4721, '...
#
#                                                   cast  \
# 1    [{'cast_id': 17, 'character': 'Dominic Toretto...
# 2    [{'cast_id': 76, 'character': 'Tony Stark / Ir...
# 5    [{'cast_id': 2, 'character': 'Dory (voice)', '...
# 15   [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 17   [{'cast_id': 3, 'character': 'Peter Quill / St...
# 22   [{'cast_id': 99, 'character': 'Wade Wilson / D...
# 32   [{'cast_id': 2, 'character': 'Katniss Everdeen...
# 36   [{'cast_id': 2, 'character': 'Cade Yeager', 'c...
# 45   [{'cast_id': 15, 'character': 'Police Chief Ma...
# 50   [{'cast_id': 14, 'character': 'Regan', 'credit...
# 54   [{'cast_id': 7, 'character': 'Manny (voice)', ...
# 59   [{'cast_id': 2, 'character': 'Max Rockatansky'...
# 62   [{'cast_id': 6, 'character': 'Caesar', 'credit...
# 67   [{'cast_id': 1, 'character': 'Lightning McQuee...
# 73   [{'cast_id': 1, 'character': 'Ed Warren', 'cre...
# 76   [{'cast_id': 0, 'character': 'Thomas', 'credit...
# 85   [{'cast_id': 3, 'character': "April O'Neil", '...
# 86   [{'cast_id': 5, 'character': 'Don Vito Corleon...
# 90   [{'cast_id': 16, 'character': 'Dave', 'credit_...
# 92   [{'cast_id': 0, 'character': 'Robert Langdon',...
# 96   [{'cast_id': 3, 'character': 'Mike Banning', '...
# 118  [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 125  [{'cast_id': 1, 'character': 'Ben Barber', 'cr...
# 128  [{'cast_id': 19, 'character': 'James Bond', 'c...
# 131  [{'cast_id': 8, 'character': 'Dr. Frank-N-Furt...
# 132  [{'cast_id': 1, 'character': 'James Bond', 'cr...
# 138  [{'cast_id': 14, 'character': 'Julia', 'credit...
# 140  [{'cast_id': 1, 'character': 'Alice Zander', '...
# 152  [{'cast_id': 1, 'character': 'Courtney Collins...
# 198  [{'cast_id': 3, 'character': 'Ruby', 'credit_i...
#
#                                                   crew     revenue  \
# 1    [{'credit_id': '52fe4cc8c3a36847f823e681', 'de...  1506249360
# 2    [{'credit_id': '55d5f7d4c3a3683e7e0016eb', 'de...  1405403694
# 5    [{'credit_id': '55eb2fbb92514106d60041ab', 'de...  1028570889
# 15   [{'credit_id': '5751eed59251416b60000637', 'de...   880674609
# 17   [{'credit_id': '59171547925141583c0315a6', 'de...   863416141
# 22   [{'credit_id': '57e564fac3a3681beb0000cc', 'de...   783112979
# 32   [{'credit_id': '551e57929251411d8d00029a', 'de...   653428261
# 36   [{'credit_id': '5553e38bc3a368208f000502', 'de...   604942143
# 45   [{'credit_id': '52fe4255c3a36847f801601f', 'de...   470654000
# 50   [{'credit_id': '52fe4508c3a36847f80b865d', 'de...   441306145
# 54   [{'credit_id': '551b875dc3a3687670001d1e', 'de...   408579038
# 59   [{'credit_id': '53d451210e0a262841002dd1', 'de...   378858340
# 62   [{'credit_id': '591f036fc3a368774e036079', 'de...   369907963
# 67   [{'credit_id': '577a76f9c3a3687716000419', 'de...   350170057
# 73   [{'credit_id': '5327f4c99251411a0d001c70', 'de...   320170008
# 76   [{'credit_id': '55fe9c50c3a3681334002f5b', 'de...   311256926
# 85   [{'credit_id': '548315c292514175f5001823', 'de...   245623848
# 86   [{'credit_id': '52fe422bc3a36847f80093db', 'de...   245066411
# 90   [{'credit_id': '547f79b7c3a3683d8e0004fe', 'de...   233755553
# 92   [{'credit_id': '57aead299251410a82001218', 'de...   220021259
# 96   [{'credit_id': '5363c191c3a368157d002773', 'de...   205754447
# 118  [{'credit_id': '52fe4265c3a36847f801b5ad', 'de...   141195658
# 125  [{'credit_id': '54d360749251413fc10034b7', 'de...   124827316
# 128  [{'credit_id': '52fe426ac3a36847f801cc15', 'de...   116019547
# 131  [{'credit_id': '52fe46029251416c91045f0b', 'de...   112892319
# 132  [{'credit_id': '52fe4267c3a36847f801bbd1', 'de...   111584787
# 138  [{'credit_id': '52fe46019251416c75069e25', 'de...    83080890
# 140  [{'credit_id': '56911317c3a3686b550023c4', 'de...    81705746
# 152  [{'credit_id': '5666bb3bc3a36808e6000bb0', 'de...    52882018
# 198  [{'credit_id': '56be2f489251417359004545', 'de...       53447
#
#          profit half_runtime new_released_date  year month  month_name
# 1    1316249360         68.5        2015-04-01  2015     4       April
# 2    1125403694         70.5        2015-04-22  2015     4       April
# 5     828570889         48.5        2016-06-16  2016     6        June
# 15    635674609         74.0        2015-10-26  2015    10     October
# 17    663416141         68.5        2017-04-19  2017     4       April
# 22    725112979         54.0        2016-02-09  2016     2    February
# 32    493428261         68.5        2015-11-18  2015    11    November
# 36    344942143         74.5        2017-06-21  2017     6        June
# 45    463654000         62.0        2075-06-18  2075     6        June
# 50    433306145         61.0        2073-12-26  2073    12    December
# 54    303579038         50.0        2016-06-23  2016     6        June
# 59    228858340         60.0        2015-05-13  2015     5         May
# 62    217907963         70.0        2017-07-11  2017     7        July
# 67    175170057         54.5        2017-06-15  2017     6        June
# 73    280170008         67.0        2016-05-13  2016     5         May
# 76    250256926         66.0        2015-09-09  2015     9   September
# 85    110623848         56.0        2016-06-01  2016     6        June
# 86    239066411         87.5        2072-03-14  2072     3       March
# 90    233755553         46.0        2015-12-17  2015    12    December
# 92    145021259         60.5        2016-10-13  2016    10     October
# 96    145754447         49.5        2016-03-02  2016     3       March
# 118   135695658         65.0        2065-12-16  2065    12    December
# 125    84827316         51.0        2016-01-14  2016     1     January
# 128   108819547         60.0        2071-12-13  2071    12    December
# 131   111692319         50.0        2075-08-14  2075     8      August
# 132   102084787         58.5        2067-06-12  2067     6        June
# 138    58080890         51.0        2017-02-01  2017     2    February
# 140    72705746         49.5        2016-10-20  2016    10     October
# 152    42882018         48.5        2015-08-19  2015     8      August
# 198       53447         48.0        2016-04-08  2016     4       April
#
# [30 rows x 26 columns]

# %%
data.loc[data.loc[:, 'profit']<0]
# Out:
#        id     budget                                             genres  \
# 108  1934  175000000  [{'id': 14, 'name': 'Fantasy'}, {'id': 35, 'na...
# 151  1935   83000000  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 156   815   50000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 166  1352   38000000  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 168  2892   35000000  [{'id': 27, 'name': 'Horror'}, {'id': 878, 'na...
# 175  1604   20000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 180  2810   35000000                  [{'id': 16, 'name': 'Animation'}]
# 181  1067   12000000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 187  1264   15000000  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 190  2689    4500000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 191  2969   25000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 194  1198    5000000  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# 200  1500     650000  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 201  1564    6000000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#        imdb_id orig_lang                              original_title  \
# 108  tt0413099   english                               Evan Almighty
# 151  tt0158622   english          The Flintstones in Viva Rock Vegas
# 156  tt0116225   english                            Escape from L.A.
# 166  tt0454919   english                                       Pulse
# 168  tt0905372   english                                   The Thing
# 175  tt1160368   english                                   12 Rounds
# 180  tt0111333   english                           The Swan Princess
# 181  tt0414852        fr                                 Banlieue 13
# 187  tt0480239   english                       Atlas Shrugged Part I
# 190  tt2265171        id                        The Raid 2: Berandal
# 191  tt0383222   english                                  BloodRayne
# 194  tt2800038   english  Atlas Shrugged Part III: Who is John Galt?
# 200  tt1464580   english                                  Stake Land
# 201  tt0144117   english                         The Boondock Saints
#
#                                               overview  popularity  \
# 108  God contacts Congressman Evan Baxter and tells...    9.156877
# 151  The Flintstones are at it again. The Flintston...    6.053595
# 156  This time, a cataclysmic temblor hits Los Ange...   12.229381
# 166  When their computer hacker friend accidentally...   10.307277
# 168  When paleontologist Kate Lloyd travels to an i...   10.169411
# 175  When New Orleans cop Danny Fisher prevents a b...   13.591485
# 180  The beautiful princess Odette is transformed i...    8.910462
# 181  Set in the ghettos of Paris in 2010, an underc...    7.594102
# 187  A powerful railroad executive, Dagny Taggart, ...    3.494900
# 190  After fighting his way through an apartment bu...    8.434884
# 191  In eighteenth century Romania, Rayne, a dhampi...    6.514132
# 194  Approaching collapse, the nation's economy is ...    1.845554
# 200  Martin was a normal teenage boy before the cou...    7.814255
# 201  With a God-inspired moral obligation to act ag...   12.457908
#
#                                              companies  \
# 108  [{'name': 'Columbia Pictures', 'id': 5}, {'nam...
# 151  [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 156  [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 166          [{'name': 'Dimension Films', 'id': 7405}]
# 168  [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 175  [{'name': 'The Mark Gordon Company', 'id': 155...
# 180   [{'name': 'Rich Animation Studios', 'id': 4108}]
# 181  [{'name': 'Canal Plus', 'id': 104}, {'name': '...
# 187       [{'name': 'Atlas Productions', 'id': 30031}]
# 190  [{'name': 'Pt. Merantau Films', 'id': 12141}, ...
# 191                 [{'name': 'Boll KG', 'id': 15127}]
# 194     [{'name': 'Atlas 3 Productions', 'id': 67480}]
# 200  [{'name': 'Glass Eye Pix', 'id': 1360}, {'name...
# 201  [{'name': 'Franchise Pictures', 'id': 1403}, {...
#
#                                              countries  ...  \
# 108  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 151  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 156  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 166  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 168  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 175  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 180  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 181           [{'iso_3166_1': 'FR', 'name': 'France'}]  ...
# 187  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 190        [{'iso_3166_1': 'ID', 'name': 'Indonesia'}]  ...
# 191  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 194  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 200  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 201  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  ...
#
#                                               Keywords  \
# 108  [{'id': 494, 'name': 'father son relationship'...
# 151  [{'id': 828, 'name': 'waitress'}, {'id': 1459,...
# 156  [{'id': 378, 'name': 'prison'}, {'id': 840, 'n...
# 166  [{'id': 236, 'name': 'suicide'}, {'id': 2157, ...
# 168  [{'id': 2340, 'name': 'paranoia'}, {'id': 4713...
# 175  [{'id': 6149, 'name': 'police'}, {'id': 8233, ...
# 180  [{'id': 7376, 'name': 'princess'}, {'id': 1040...
# 181  [{'id': 90, 'name': 'paris'}, {'id': 258, 'nam...
# 187  [{'id': 2832, 'name': 'recession'}, {'id': 411...
# 190  [{'id': 378, 'name': 'prison'}, {'id': 1568, '...
# 191  [{'id': 3133, 'name': 'vampire'}, {'id': 9259,...
# 194  [{'id': 33452, 'name': 'trilogy'}, {'id': 1732...
# 200  [{'id': 255, 'name': 'male nudity'}, {'id': 13...
# 201  [{'id': 1679, 'name': 'arbitrary law'}, {'id':...
#
#                                                   cast  \
# 108  [{'cast_id': 19, 'character': 'Evan Baxter', '...
# 151  [{'cast_id': 19, 'character': 'Fred Flintstone...
# 156  [{'cast_id': 12, 'character': 'Snake Plissken'...
# 166  [{'cast_id': 1, 'character': 'Mattie', 'credit...
# 168  [{'cast_id': 2, 'character': 'Kate Lloyd', 'cr...
# 175  [{'cast_id': 1, 'character': 'Det. Danny Fishe...
# 180  [{'cast_id': 1, 'character': 'Princess Odette ...
# 181  [{'cast_id': 19, 'character': 'Le√Øto', 'credi...
# 187  [{'cast_id': 4, 'character': 'Dagny Taggart', ...
# 190  [{'cast_id': 3, 'character': 'Rama', 'credit_i...
# 191  [{'cast_id': 3, 'character': 'Rayne', 'credit_...
# 194  [{'cast_id': 6, 'character': 'Ragnar Danneskj√...
# 200  [{'cast_id': 2, 'character': 'Belle', 'credit_...
# 201  [{'cast_id': 1, 'character': 'Paul Smecker', '...
#
#                                                   crew    revenue    profit  \
# 108  [{'credit_id': '52fe4365c3a36847f805145d', 'de...  173000000  -2000000
# 151  [{'credit_id': '52fe4288c3a36847f80263c5', 'de...   59468275 -23531725
# 156  [{'credit_id': '52fe43179251416c7500311d', 'de...   42277365  -7722635
# 166  [{'credit_id': '52fe451bc3a36847f80bcbff', 'de...   29907685  -8092315
# 168  [{'credit_id': '537b713fc3a3682d3c00000e', 'de...   28128670  -6871330
# 175  [{'credit_id': '538ee0730e0a2644b9001141', 'de...   17280326  -2719674
# 180  [{'credit_id': '587fddedc3a36863e7000926', 'de...    9771658 -25228342
# 181  [{'credit_id': '52fe43119251416c7500245d', 'de...    9584131  -2415869
# 187  [{'credit_id': '52fe4912c3a36847f8187c95', 'de...    4627375 -10372625
# 190  [{'credit_id': '52fe4c449251416c75115203', 'de...    2627209  -1872791
# 191  [{'credit_id': '52fe4cd4c3a36847f82407f7', 'de...    2405420 -22594580
# 194  [{'credit_id': '52fe4db79251416c9111f78f', 'de...     846704  -4153296
# 200  [{'credit_id': '537483fcc3a36815180026ee', 'de...      33245   -616755
# 201  [{'credit_id': '52fe44a3c3a36847f80a1a91', 'de...      30471  -5969529
#
#     half_runtime new_released_date  year month  month_name
# 108         48.0        2007-06-09  2007     6        June
# 151         45.0        2000-04-28  2000     4       April
# 156         48.5        1996-08-09  1996     8      August
# 166         45.0        2006-08-11  2006     8      August
# 168         51.5        2011-10-12  2011    10     October
# 175         54.0        2009-03-19  2009     3       March
# 180         44.5        1994-11-18  1994    11    November
# 181         42.0        2004-11-09  2004    11    November
# 187         48.5        2011-04-14  2011     4       April
# 190         75.0        2014-03-27  2014     3       March
# 191         47.5        2005-10-22  2005    10     October
# 194         49.5        2014-09-12  2014     9   September
# 200         49.0        2010-09-30  2010     9   September
# 201         54.0        1999-01-22  1999     1     January
#
# [14 rows x 26 columns]

# %% [markdown]
# # **Filter data using multiple conditions**
# To filter data based on multiple conditions we use logical operators like and(&) , or(|) and not(!=).
#
# **data.loc[(data['column']== condition) operator (data['column']== condition) ]**

# %%
# find all the english movies released in 2012
data.loc[(data.loc[:,'orig_lang']=='english') & (data.loc[:,'year']==2012)]
# Out:
#        id     budget                                             genres  \
# 0    1127  220000000  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 7    2533  250000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 40   2456   50000000  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...
# 44   1393  165000000  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 55   2939  130000000  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 77   2371  150000000                  [{'id': 12, 'name': 'Adventure'}]
# 81   1760  130000000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 89   1499   65000000  [{'id': 28, 'name': 'Action'}, {'id': 27, 'nam...
# 93   1050   60000000  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 129  1013   17000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 183   660    7500000  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 185  2853          0                     [{'id': 35, 'name': 'Comedy'}]
# 197    23          0  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
#
#        imdb_id orig_lang                     original_title  \
# 0    tt0848228   english                       The Avengers
# 7    tt0903624   english  The Hobbit: An Unexpected Journey
# 40   tt1637725   english                                Ted
# 44   tt1772341   english                     Wreck-It Ralph
# 55   tt1446714   english                         Prometheus
# 77   tt1646987   english                Wrath of the Titans
# 81   tt1194173   english                  The Bourne Legacy
# 89   tt1855325   english         Resident Evil: Retribution
# 93   tt0790724   english                       Jack Reacher
# 129  tt1981677   english                      Pitch Perfect
# 183  tt1034314   english                           Iron Sky
# 185  tt1456635   english                               Goon
# 197  tt2105044   english                              V/H/S
#
#                                               overview  popularity  \
# 0    When an unexpected enemy emerges and threatens...   89.887648
# 7    Bilbo Baggins, a hobbit enjoying his quiet lif...   23.253089
# 40   John Bennett, a man whose childhood wish of br...   19.638605
# 44   Wreck-It Ralph is the 9-foot-tall, 643-pound v...   13.697597
# 55   A team of explorers discover a clue to the ori...   16.624854
# 77   A decade after his heroic defeat of the monstr...    7.739904
# 81   New CIA operative, Aaron Cross experiences lif...   14.894990
# 89   The Umbrella Corporation‚Äôs deadly T-virus co...    0.948759
# 93   In an innocent heartland city, five are shot d...   12.789812
# 129  College student Beca knows she does not want t...   11.035950
# 183  In the last moments of World War II, a secret ...   19.561767
# 185  Doug Glatt, a slacker who discovers he has a t...    8.817924
# 197  When a group of misfits is hired by an unknown...    7.820787
#
#                                              companies  \
# 0    [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 7    [{'name': 'WingNut Films', 'id': 11}, {'name':...
# 40   [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 44   [{'name': 'Walt Disney Animation Studios', 'id...
# 55   [{'name': 'Twentieth Century Fox Film Corporat...
# 77   [{'name': 'Legendary Pictures', 'id': 923}, {'...
# 81   [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 89                [{'name': 'Davis-Films', 'id': 342}]
# 93   [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 129  [{'name': 'Brownstone Productions', 'id': 12365}]
# 183  [{'name': 'Blind Spot Pictures Oy', 'id': 7330...
# 185  [{'name': 'Don Carmody Productions', 'id': 425...
# 197  [{'name': 'The Collective', 'id': 15156}, {'na...
#
#                                              countries  ...  \
# 0    [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 7    [{'iso_3166_1': 'NZ', 'name': 'New Zealand'}, ...  ...
# 40   [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 44   [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 55   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...  ...
# 77   [{'iso_3166_1': 'ES', 'name': 'Spain'}, {'iso_...  ...
# 81   [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 89   [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  ...
# 93   [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 129  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 183  [{'iso_3166_1': 'FI', 'name': 'Finland'}, {'is...  ...
# 185  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  ...
# 197  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
#
#                                               Keywords  \
# 0    [{'id': 242, 'name': 'new york'}, {'id': 5539,...
# 7    [{'id': 483, 'name': 'riddle'}, {'id': 603, 'n...
# 40   [{'id': 6054, 'name': 'friendship'}, {'id': 96...
# 44   [{'id': 825, 'name': 'support group'}, {'id': ...
# 55   [{'id': 803, 'name': 'android'}, {'id': 4565, ...
# 77   [{'id': 1449, 'name': 'underworld'}, {'id': 20...
# 81   [{'id': 782, 'name': 'assassin'}, {'id': 1994,...
# 89   [{'id': 1852, 'name': 'mutant'}, {'id': 4565, ...
# 93   [{'id': 818, 'name': 'based on novel'}, {'id':...
# 129  [{'id': 271, 'name': 'competition'}, {'id': 12...
# 183        [{'id': 182824, 'name': 'charlie chaplin'}]
# 185  [{'id': 6075, 'name': 'sport'}, {'id': 6483, '...
# 197  [{'id': 6435, 'name': 'webcam'}, {'id': 9706, ...
#
#                                                   cast  \
# 0    [{'cast_id': 46, 'character': 'Tony Stark / Ir...
# 7    [{'cast_id': 6, 'character': 'Gandalf', 'credi...
# 40   [{'cast_id': 10, 'character': 'John Bennett', ...
# 44   [{'cast_id': 9, 'character': 'Wreck-It Ralph (...
# 55   [{'cast_id': 5, 'character': 'Dr. Elizabeth Sh...
# 77   [{'cast_id': 4, 'character': 'Perseus', 'credi...
# 81   [{'cast_id': 5, 'character': 'Aaron Cross', 'c...
# 89   [{'cast_id': 1, 'character': 'Alice', 'credit_...
# 93   [{'cast_id': 1001, 'character': 'Jack Reacher'...
# 129  [{'cast_id': 7, 'character': 'Beca Mitchell', ...
# 183  [{'cast_id': 4, 'character': 'Renate Richter',...
# 185  [{'cast_id': 3, 'character': 'Doug Glatt', 'cr...
# 197  [{'cast_id': 1, 'character': 'Gary', 'credit_i...
#
#                                                   crew     revenue  \
# 0    [{'credit_id': '52fe4495c3a368484e02b1cf', 'de...  1519557910
# 7    [{'credit_id': '52fe4783c3a36847f8139f7f', 'de...  1021103568
# 40   [{'credit_id': '52fe4858c3a368484e0f4489', 'de...   549368315
# 44   [{'credit_id': '52fe486a9251416c9108bca7', 'de...   471222889
# 55   [{'credit_id': '52fe481dc3a368484e0e9db7', 'de...   403170142
# 77   [{'credit_id': '52fe4926c3a36847f818b96d', 'de...   301000000
# 81   [{'credit_id': '52fe4782c3a36847f8139c3b', 'de...   276572938
# 89   [{'credit_id': '52fe4842c3a368484e0f00b5', 'de...   240159255
# 93   [{'credit_id': '52fe4912c3a368484e1191ab', 'de...   218340595
# 129  [{'credit_id': '52fe4b46c3a36847f81fb7d7', 'de...   115350426
# 183  [{'credit_id': '537621c30e0a263034001c2b', 'de...     8135031
# 185  [{'credit_id': '52fe48c8c3a368484e10abc3', 'de...     6483963
# 197  [{'credit_id': '52fe48ee9251416c9109d113', 'de...      100345
#
#          profit half_runtime new_released_date  year month  month_name
# 0    1299557910         71.5        2012-04-25  2012     4       April
# 7     771103568         84.5        2012-11-26  2012    11    November
# 40    499368315         53.0        2012-06-29  2012     6        June
# 44    306222889         54.0        2012-11-01  2012    11    November
# 55    273170142         62.0        2012-05-30  2012     5         May
# 77    151000000         49.5        2012-03-27  2012     3       March
# 81    146572938         60.0        2012-08-08  2012     8      August
# 89    175159255         47.5        2012-09-12  2012     9   September
# 93    158340595         65.0        2012-12-20  2012    12    December
# 129    98350426         56.0        2012-09-28  2012     9   September
# 183      635031         46.5        2012-03-10  2012     3       March
# 185     6483963         46.0        2012-01-06  2012     1     January
# 197      100345         58.0        2012-07-28  2012     7        July
#
# [13 rows x 26 columns]

# %%
# find all the hindi movies giving negative profit
data.loc[(data.loc[:,'orig_lang']=='hindi') & (data.loc[:,'profit']<0)]
# Out:
# Empty DataFrame
# Columns: [id, budget, genres, imdb_id, orig_lang, original_title, overview, popularity, companies, countries, release_date, runtime, spoken_languages, status, tagline, title, Keywords, cast, crew, revenue, profit, half_runtime, new_released_date, year, month, month_name]
# Index: []
#
# [0 rows x 26 columns]

# %%
# find all movies released in either 2012 or 2013
data.loc[(data.loc[:,'year']==2012) | (data.loc[:,'year']==2013)]
# Out:
#        id     budget                                             genres  \
# 0    1127  220000000  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 7    2533  250000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 10    667  250000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 29   2358  225000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 40   2456   50000000  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...
# 41    764  200000000  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 44   1393  165000000  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# 52   1973  120000000  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 55   2939  130000000  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 68   2059  105000000  [{'id': 14, 'name': 'Fantasy'}, {'id': 10751, ...
# 74    972   13000000  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 77   2371  150000000                  [{'id': 12, 'name': 'Adventure'}]
# 81   1760  130000000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 89   1499   65000000  [{'id': 28, 'name': 'Action'}, {'id': 27, 'nam...
# 93   1050   60000000  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 107  1159   90000000  [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 129  1013   17000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 150   916          0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 183   660    7500000  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 185  2853          0                     [{'id': 35, 'name': 'Comedy'}]
# 197    23          0  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
#
#        imdb_id orig_lang                       original_title  \
# 0    tt0848228   english                         The Avengers
# 7    tt0903624   english    The Hobbit: An Unexpected Journey
# 10   tt1170358   english  The Hobbit: The Desolation of Smaug
# 29   tt0770828   english                         Man of Steel
# 40   tt1637725   english                                  Ted
# 41   tt0816711   english                          World War Z
# 44   tt1772341   english                       Wreck-It Ralph
# 52   tt1430132   english                        The Wolverine
# 55   tt1446714   english                           Prometheus
# 68   tt2017020   english                         The Smurfs 2
# 74   tt1457767   english                        The Conjuring
# 77   tt1646987   english                  Wrath of the Titans
# 81   tt1194173   english                    The Bourne Legacy
# 89   tt1855325   english           Resident Evil: Retribution
# 93   tt0790724   english                         Jack Reacher
# 107  tt1854564   english       Percy Jackson: Sea of Monsters
# 129  tt1981677   english                        Pitch Perfect
# 150  tt1979319        ja                               るろうに剣心
# 183  tt1034314   english                             Iron Sky
# 185  tt1456635   english                                 Goon
# 197  tt2105044   english                                V/H/S
#
#                                               overview  popularity  \
# 0    When an unexpected enemy emerges and threatens...   89.887648
# 7    Bilbo Baggins, a hobbit enjoying his quiet lif...   23.253089
# 10   The Dwarves, Bilbo and Gandalf have successful...   20.644776
# 29   A young boy learns that he has extraordinary p...   18.538834
# 40   John Bennett, a man whose childhood wish of br...   19.638605
# 41   Life for former United Nations investigator Ge...   26.114917
# 44   Wreck-It Ralph is the 9-foot-tall, 643-pound v...   13.697597
# 52   Wolverine faces his ultimate nemesis - and tes...    3.918287
# 55   A team of explorers discover a clue to the ori...   16.624854
# 68   The evil wizard Gargamel creates a couple of m...   10.640864
# 74   Paranormal investigators Ed and Lorraine Warre...   14.901690
# 77   A decade after his heroic defeat of the monstr...    7.739904
# 81   New CIA operative, Aaron Cross experiences lif...   14.894990
# 89   The Umbrella Corporation‚Äôs deadly T-virus co...    0.948759
# 93   In an innocent heartland city, five are shot d...   12.789812
# 107  In their quest to confront the ultimate evil, ...   10.338222
# 129  College student Beca knows she does not want t...   11.035950
# 150  Former legendary assassin Kenshin Himura has n...    7.916658
# 183  In the last moments of World War II, a secret ...   19.561767
# 185  Doug Glatt, a slacker who discovers he has a t...    8.817924
# 197  When a group of misfits is hired by an unknown...    7.820787
#
#                                              companies  \
# 0    [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 7    [{'name': 'WingNut Films', 'id': 11}, {'name':...
# 10   [{'name': 'WingNut Films', 'id': 11}, {'name':...
# 29   [{'name': 'Legendary Pictures', 'id': 923}, {'...
# 40   [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 41   [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 44   [{'name': 'Walt Disney Animation Studios', 'id...
# 52   [{'name': 'Twentieth Century Fox Film Corporat...
# 55   [{'name': 'Twentieth Century Fox Film Corporat...
# 68   [{'name': 'Columbia Pictures', 'id': 5}, {'nam...
# 74   [{'name': 'New Line Cinema', 'id': 12}, {'name...
# 77   [{'name': 'Legendary Pictures', 'id': 923}, {'...
# 81   [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 89                [{'name': 'Davis-Films', 'id': 342}]
# 93   [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 107  [{'name': '1492 Pictures', 'id': 436}, {'name'...
# 129  [{'name': 'Brownstone Productions', 'id': 12365}]
# 150  [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 183  [{'name': 'Blind Spot Pictures Oy', 'id': 7330...
# 185  [{'name': 'Don Carmody Productions', 'id': 425...
# 197  [{'name': 'The Collective', 'id': 15156}, {'na...
#
#                                              countries  ...  \
# 0    [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 7    [{'iso_3166_1': 'NZ', 'name': 'New Zealand'}, ...  ...
# 10   [{'iso_3166_1': 'NZ', 'name': 'New Zealand'}, ...  ...
# 29   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...  ...
# 40   [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 41   [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 44   [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 52   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...  ...
# 55   [{'iso_3166_1': 'GB', 'name': 'United Kingdom'...  ...
# 68   [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 74   [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 77   [{'iso_3166_1': 'ES', 'name': 'Spain'}, {'iso_...  ...
# 81   [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 89   [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  ...
# 93   [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 107  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 129  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 150            [{'iso_3166_1': 'JP', 'name': 'Japan'}]  ...
# 183  [{'iso_3166_1': 'FI', 'name': 'Finland'}, {'is...  ...
# 185  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  ...
# 197  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
#
#                                               Keywords  \
# 0    [{'id': 242, 'name': 'new york'}, {'id': 5539,...
# 7    [{'id': 483, 'name': 'riddle'}, {'id': 603, 'n...
# 10   [{'id': 603, 'name': 'elves'}, {'id': 604, 'na...
# 29   [{'id': 83, 'name': 'saving the world'}, {'id'...
# 40   [{'id': 6054, 'name': 'friendship'}, {'id': 96...
# 41   [{'id': 4565, 'name': 'dystopia'}, {'id': 1233...
# 44   [{'id': 825, 'name': 'support group'}, {'id': ...
# 52   [{'id': 233, 'name': 'japan'}, {'id': 1462, 'n...
# 55   [{'id': 803, 'name': 'android'}, {'id': 4565, ...
# 68   [{'id': 10244, 'name': 'based on cartoon'}, {'...
# 74   [{'id': 1156, 'name': 'sister sister relations...
# 77   [{'id': 1449, 'name': 'underworld'}, {'id': 20...
# 81   [{'id': 782, 'name': 'assassin'}, {'id': 1994,...
# 89   [{'id': 1852, 'name': 'mutant'}, {'id': 4565, ...
# 93   [{'id': 818, 'name': 'based on novel'}, {'id':...
# 107  [{'id': 351, 'name': 'poison'}, {'id': 2034, '...
# 129  [{'id': 271, 'name': 'competition'}, {'id': 12...
# 150  [{'id': 1462, 'name': 'samurai'}, {'id': 10564...
# 183        [{'id': 182824, 'name': 'charlie chaplin'}]
# 185  [{'id': 6075, 'name': 'sport'}, {'id': 6483, '...
# 197  [{'id': 6435, 'name': 'webcam'}, {'id': 9706, ...
#
#                                                   cast  \
# 0    [{'cast_id': 46, 'character': 'Tony Stark / Ir...
# 7    [{'cast_id': 6, 'character': 'Gandalf', 'credi...
# 10   [{'cast_id': 3, 'character': 'Bilbo Baggins', ...
# 29   [{'cast_id': 2, 'character': 'Clark Kent / Kal...
# 40   [{'cast_id': 10, 'character': 'John Bennett', ...
# 41   [{'cast_id': 4, 'character': 'Gerry Lane', 'cr...
# 44   [{'cast_id': 9, 'character': 'Wreck-It Ralph (...
# 52   [{'cast_id': 37, 'character': 'Logan / Wolveri...
# 55   [{'cast_id': 5, 'character': 'Dr. Elizabeth Sh...
# 68   [{'cast_id': 5, 'character': 'Gargamel', 'cred...
# 74   [{'cast_id': 7, 'character': 'Ed Warren', 'cre...
# 77   [{'cast_id': 4, 'character': 'Perseus', 'credi...
# 81   [{'cast_id': 5, 'character': 'Aaron Cross', 'c...
# 89   [{'cast_id': 1, 'character': 'Alice', 'credit_...
# 93   [{'cast_id': 1001, 'character': 'Jack Reacher'...
# 107  [{'cast_id': 2, 'character': 'Percy Jackson', ...
# 129  [{'cast_id': 7, 'character': 'Beca Mitchell', ...
# 150  [{'cast_id': 5, 'character': 'Kenshin Himura',...
# 183  [{'cast_id': 4, 'character': 'Renate Richter',...
# 185  [{'cast_id': 3, 'character': 'Doug Glatt', 'cr...
# 197  [{'cast_id': 1, 'character': 'Gary', 'credit_i...
#
#                                                   crew     revenue  \
# 0    [{'credit_id': '52fe4495c3a368484e02b1cf', 'de...  1519557910
# 7    [{'credit_id': '52fe4783c3a36847f8139f7f', 'de...  1021103568
# 10   [{'credit_id': '5350e7b0c3a3681d93000e5d', 'de...   958400000
# 29   [{'credit_id': '52fe4799c3a36847f813e601', 'de...   662845518
# 40   [{'credit_id': '52fe4858c3a368484e0f4489', 'de...   549368315
# 41   [{'credit_id': '570bbe9ec3a3684b50000391', 'de...   531865000
# 44   [{'credit_id': '52fe486a9251416c9108bca7', 'de...   471222889
# 52   [{'credit_id': '5612aac3c3a368681f0141ac', 'de...   415440673
# 55   [{'credit_id': '52fe481dc3a368484e0e9db7', 'de...   403170142
# 68   [{'credit_id': '52fe4983c3a368484e12f5a3', 'de...   347434178
# 74   [{'credit_id': '52fe4c56c3a368484e1b324f', 'de...   318000141
# 77   [{'credit_id': '52fe4926c3a36847f818b96d', 'de...   301000000
# 81   [{'credit_id': '52fe4782c3a36847f8139c3b', 'de...   276572938
# 89   [{'credit_id': '52fe4842c3a368484e0f00b5', 'de...   240159255
# 93   [{'credit_id': '52fe4912c3a368484e1191ab', 'de...   218340595
# 107  [{'credit_id': '56a01066c3a36858c800aa63', 'de...   174578751
# 129  [{'credit_id': '52fe4b46c3a36847f81fb7d7', 'de...   115350426
# 150  [{'credit_id': '52fe4afdc3a368484e17188f', 'de...    61700000
# 183  [{'credit_id': '537621c30e0a263034001c2b', 'de...     8135031
# 185  [{'credit_id': '52fe48c8c3a368484e10abc3', 'de...     6483963
# 197  [{'credit_id': '52fe48ee9251416c9109d113', 'de...      100345
#
#          profit half_runtime new_released_date  year month  month_name
# 0    1299557910         71.5        2012-04-25  2012     4       April
# 7     771103568         84.5        2012-11-26  2012    11    November
# 10    708400000         80.5        2013-12-11  2013    12    December
# 29    437845518         71.5        2013-06-12  2013     6        June
# 40    499368315         53.0        2012-06-29  2012     6        June
# 41    331865000         58.0        2013-06-20  2013     6        June
# 44    306222889         54.0        2012-11-01  2012    11    November
# 52    295440673         63.0        2013-07-23  2013     7        July
# 55    273170142         62.0        2012-05-30  2012     5         May
# 68    242434178         52.5        2013-07-30  2013     7        July
# 74    305000141         56.0        2013-07-18  2013     7        July
# 77    151000000         49.5        2012-03-27  2012     3       March
# 81    146572938         60.0        2012-08-08  2012     8      August
# 89    175159255         47.5        2012-09-12  2012     9   September
# 93    158340595         65.0        2012-12-20  2012    12    December
# 107    84578751         53.0        2013-08-07  2013     8      August
# 129    98350426         56.0        2012-09-28  2012     9   September
# 150    61700000         67.0        2012-08-25  2012     8      August
# 183      635031         46.5        2012-03-10  2012     3       March
# 185     6483963         46.0        2012-01-06  2012     1     January
# 197      100345         58.0        2012-07-28  2012     7        July
#
# [21 rows x 26 columns]

# %%
# find all movies released in either english or hindi
data.loc[(data.loc[:,'orig_lang']=='hindi') |(data.loc[:,'orig_lang']=='english')]
# Out:
#        id     budget                                             genres  \
# 0    1127  220000000  [{'id': 878, 'name': 'Science Fiction'}, {'id'...
# 1    1762  190000000                     [{'id': 28, 'name': 'Action'}]
# 2    2771  280000000  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 3    2323  195000000  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...
# 4    2136  380000000  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...
# ..    ...        ...                                                ...
# 197    23          0  [{'id': 53, 'name': 'Thriller'}, {'id': 27, 'n...
# 198   515          0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 200  1500     650000  [{'id': 18, 'name': 'Drama'}, {'id': 27, 'name...
# 201  1564    6000000  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 202   666          0  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
#
#        imdb_id orig_lang                               original_title  \
# 0    tt0848228   english                                 The Avengers
# 1    tt2820852   english                                    Furious 7
# 2    tt2395427   english                      Avengers: Age of Ultron
# 3    tt1399103   english               Transformers: Dark of the Moon
# 4    tt1298650   english  Pirates of the Caribbean: On Stranger Tides
# ..         ...       ...                                          ...
# 197  tt2105044   english                                        V/H/S
# 198  tt3451230   english                                  High Strung
# 200  tt1464580   english                                   Stake Land
# 201  tt0144117   english                          The Boondock Saints
# 202  tt1340773   english                                 Elektra Luxx
#
#                                               overview  popularity  \
# 0    When an unexpected enemy emerges and threatens...   89.887648
# 1    Deckard Shaw seeks revenge against Dominic Tor...   27.275687
# 2    When Tony Stark tries to jumpstart a dormant p...   37.379420
# 3    Sam Witwicky takes his first tenuous steps int...    4.503505
# 4    Captain Jack Sparrow crosses paths with a woma...   27.887720
# ..                                                 ...         ...
# 197  When a group of misfits is hired by an unknown...    7.820787
# 198  When a hip hop violinist busking in the New Yo...    6.625607
# 200  Martin was a normal teenage boy before the cou...    7.814255
# 201  With a God-inspired moral obligation to act ag...   12.457908
# 202  A favor for a woman from her past throws the l...    4.118699
#
#                                              companies  \
# 0    [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 1    [{'name': 'Universal Pictures', 'id': 33}, {'n...
# 2    [{'name': 'Marvel Studios', 'id': 420}, {'name...
# 3    [{'name': 'Paramount Pictures', 'id': 4}, {'na...
# 4    [{'name': 'Walt Disney Pictures', 'id': 2}, {'...
# ..                                                 ...
# 197  [{'name': 'The Collective', 'id': 15156}, {'na...
# 198  [{'name': 'Castel Film Studio', 'id': 4573}, {...
# 200  [{'name': 'Glass Eye Pix', 'id': 1360}, {'name...
# 201  [{'name': 'Franchise Pictures', 'id': 1403}, {...
# 202         [{'name': 'Gato Negro Films', 'id': 5295}]
#
#                                              countries  ...  \
# 0    [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 1    [{'iso_3166_1': 'JP', 'name': 'Japan'}, {'iso_...  ...
# 2    [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 3    [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 4    [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# ..                                                 ...  ...
# 197  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 198  [{'iso_3166_1': 'RO', 'name': 'Romania'}, {'is...  ...
# 200  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
# 201  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  ...
# 202  [{'iso_3166_1': 'US', 'name': 'United States o...  ...
#
#                                               Keywords  \
# 0    [{'id': 242, 'name': 'new york'}, {'id': 5539,...
# 1    [{'id': 830, 'name': 'car race'}, {'id': 3428,...
# 2    [{'id': 8828, 'name': 'marvel comic'}, {'id': ...
# 3    [{'id': 305, 'name': 'moon'}, {'id': 1612, 'na...
# 4    [{'id': 658, 'name': 'sea'}, {'id': 1316, 'nam...
# ..                                                 ...
# 197  [{'id': 6435, 'name': 'webcam'}, {'id': 9706, ...
# 198  [{'id': 1691, 'name': 'dance'}, {'id': 4721, '...
# 200  [{'id': 255, 'name': 'male nudity'}, {'id': 13...
# 201  [{'id': 1679, 'name': 'arbitrary law'}, {'id':...
# 202  [{'id': 10183, 'name': 'independent film'}, {'...
#
#                                                   cast  \
# 0    [{'cast_id': 46, 'character': 'Tony Stark / Ir...
# 1    [{'cast_id': 17, 'character': 'Dominic Toretto...
# 2    [{'cast_id': 76, 'character': 'Tony Stark / Ir...
# 3    [{'cast_id': 3, 'character': 'Sam Witwicky', '...
# 4    [{'cast_id': 15, 'character': 'Captain Jack Sp...
# ..                                                 ...
# 197  [{'cast_id': 1, 'character': 'Gary', 'credit_i...
# 198  [{'cast_id': 3, 'character': 'Ruby', 'credit_i...
# 200  [{'cast_id': 2, 'character': 'Belle', 'credit_...
# 201  [{'cast_id': 1, 'character': 'Paul Smecker', '...
# 202  [{'cast_id': 3, 'character': 'Elektra Luxx', '...
#
#                                                   crew     revenue  \
# 0    [{'credit_id': '52fe4495c3a368484e02b1cf', 'de...  1519557910
# 1    [{'credit_id': '52fe4cc8c3a36847f823e681', 'de...  1506249360
# 2    [{'credit_id': '55d5f7d4c3a3683e7e0016eb', 'de...  1405403694
# 3    [{'credit_id': '537f0b740e0a2624b40044d0', 'de...  1123746996
# 4    [{'credit_id': '566b4f54c3a3683f56005151', 'de...  1045713802
# ..                                                 ...         ...
# 197  [{'credit_id': '52fe48ee9251416c9109d113', 'de...      100345
# 198  [{'credit_id': '56be2f489251417359004545', 'de...       53447
# 200  [{'credit_id': '537483fcc3a36815180026ee', 'de...       33245
# 201  [{'credit_id': '52fe44a3c3a36847f80a1a91', 'de...       30471
# 202  [{'credit_id': '52fe48f6c3a36847f818264f', 'de...          10
#
#          profit half_runtime new_released_date  year month  month_name
# 0    1299557910         71.5        2012-04-25  2012     4       April
# 1    1316249360         68.5        2015-04-01  2015     4       April
# 2    1125403694         70.5        2015-04-22  2015     4       April
# 3     928746996         77.0        2011-06-28  2011     6        June
# 4     665713802         68.0        2011-05-14  2011     5         May
# ..          ...          ...               ...   ...   ...         ...
# 197      100345         58.0        2012-07-28  2012     7        July
# 198       53447         48.0        2016-04-08  2016     4       April
# 200     -616755         49.0        2010-09-30  2010     9   September
# 201    -5969529         54.0        1999-01-22  1999     1     January
# 202          10         49.0        2010-03-14  2010     3       March
#
# [186 rows x 26 columns]

# %% [markdown]
# ## **Hurrah! 🎉🎉🎉**
#
# 🎉 Congratulations on reaching the end! 🙌
#
# You've learned the essential Pandas tools for working with structured data—from indexing and filtering to aggregation and analysis. With these skills, you can efficiently clean, transform, explore, and derive insights from complex datasets.
#
# Keep practicing, experimenting, and exploring new techniques. The more you work with data, the more powerful your analysis skills will become. 🚀
#
# In the next lesson, we'll dive into advanced Pandas techniques to help you take your data wrangling abilities to the next level.
#
# **Happy Data Wrangling! 🤓👨‍💻** 📊✨

# %% [markdown]
# ### Pandas Cheatsheet:

# %% [markdown]
# ![image.png](attachment:a9782da6-76e9-4c32-a542-496d6c30edbe.png)
